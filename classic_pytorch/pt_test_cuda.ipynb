# %% [markdown]
# # Demo: Test if GPU+CUDA is available
#
# By: Jacob Cybulski<br>
# Date: October 2023<br>

# %%
# !pip list | grep torch
# Out:
# torch                         2.1.0
# torchaudio                    2.1.0
# torchsummary                  1.5.1
# torchvision                   0.16.0

# %%
import torch

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')
# Out:
# Selected device: cuda

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Software</th><th>Version</th></tr><tr><td><code>qiskit</code></td><td>0.44.2</td></tr><tr><td><code>qiskit-terra</code></td><td>0.25.2</td></tr><tr><th colspan='2'>System information</th></tr><tr><td>Python version</td><td>3.10.13</td></tr><tr><td>Python compiler</td><td>GCC 11.2.0</td></tr><tr><td>Python build</td><td>main, Sep 11 2023 13:44:35</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>24</td></tr><tr><td>Memory (Gb)</td><td>62.5989990234375</td></tr><tr><td colspan='2'>Tue Oct 10 19:34:37 2023 AEDT</td></tr></table>
