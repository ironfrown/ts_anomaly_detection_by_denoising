# %% [markdown]
# # Demo: Building Denoising Autoencoders in Pytorch (MNIST)
#
# Adapted from: https://github.com/eugeniaring/Medium-Articles/blob/main/Pytorch/denAE.ipynb
#
# By: Jacob Cybulski<br>
# Date: July 2023<br>
# Comment: *Lots of bugs fixed, works with Torch 2, on both CPU and GPU*
#
# Adapted From: Eugenia Anello, Denoising Autoencoder in Pytorch on MNIST dataset, Dataseries (Medium)<br>
# Date: Jun 28, 2021

# %%
# !pip list | grep torch
# Out:
# torch                         2.0.1+cpu
# torchaudio                    2.0.2+cpu
# torchsummary                  1.5.1
# torchvision                   0.15.2+cpu

# %%
import matplotlib.pyplot as plt
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd # this module is useful to work with tabular data
import random # this module will be used to select random samples from a collection
import os # this module will be used just to create directories in the local filesystem
from tqdm import tqdm # this module is useful to plot progress bars

import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary

from sklearn.manifold import TSNE

# %% [markdown]
# ## Prelims: Get data and create tensor data loaders

# %%
data_dir = '../dataset'
### With these commands the train and test datasets, respectively, are downloaded
### automatically and stored in the local "data_dir" directory.
train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)

# %%
fig, axs = plt.subplots(5, 5, figsize=(8,8))
for ax in axs.flatten():
    # random.choice allows to randomly sample from a list-like object (basically anything that can be accessed with an index, like our dataset)
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
train_transform = transforms.Compose([
    transforms.ToTensor(),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Set the train transform
train_dataset.transform = train_transform

# Set the test transform
test_dataset.transform = test_transform

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)])

batch_size=256

# The dataloaders handle shuffling, batching, etc...
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %% [markdown]
# ## 1 Define Encoder and Decoder classes

# %%
class Encoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        
        ### Convolutional section
        self.encoder_cnn = nn.Sequential(
            
            # First convolutional layer
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            #nn.BatchNorm2d(8),
            nn.ReLU(True),
            
            # Second convolutional layer
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            
            # Third convolutional layer
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            #nn.BatchNorm2d(32),
            nn.ReLU(True)
        )
        
        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        ### Linear section
        self.encoder_lin = nn.Sequential(
            
            # First linear layer
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            
            # Second linear layer
            nn.Linear(128, encoded_space_dim)
        )
        
    def forward(self, x):
        
        # Apply convolutions
        x = self.encoder_cnn(x)
        
        # Flatten
        x = self.flatten(x)
        
        # Apply linear layers
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()

        ### Linear section
        self.decoder_lin = nn.Sequential(
            
            # First linear layer
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            
            # Second linear layer
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        ### Unflatten
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))

        ### Convolutional section
        self.decoder_conv = nn.Sequential(
            
            # First transposed convolution
            nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            
            # Second transposed convolution
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            
            # Third transposed convolution
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )
        
    def forward(self, x):
        
        # Apply linear layers
        x = self.decoder_lin(x)
        
        # Unflatten
        x = self.unflatten(x)
        
        # Apply transposed convolutions
        x = self.decoder_conv(x)
        
        # Apply a sigmoid to force the output to be between 0 and 1 (valid pixel values)
        x = torch.sigmoid(x)
        return x

# %% [markdown]
# ## 2 initialize models, loss and optimizer
# *Note that "d" is the size of a latent space*

# %%
### Set the random seed for reproducible results
torch.manual_seed(0)

### Initialize the two networks
d = 4

encoder = Encoder(encoded_space_dim=d,fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=d,fc2_input_dim=128)

# %%
### Define the loss function
loss_fn = torch.nn.MSELoss()

### Define an optimizer (both for the encoder and the decoder!)
lr= 0.001 # Learning rate


params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

optim = torch.optim.Adam(params_to_optimize, lr=lr)

# Move both the encoder and the decoder to the selected device
encoder.to(device)
decoder.to(device)
print(encoder)
print(decoder)
# Out:
# Selected device: cpu
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %% [markdown]
# ## 3 Train model

# %%
im = test_dataset[0][0].unsqueeze(0)
a = im + torch.randn_like(im)*0.3
print(a)
# Out:
# tensor([[[[-2.6186e-01, -5.2741e-01,  1.4207e-01, -3.4364e-02, -8.2293e-01,
#            -3.7285e-01, -1.8820e-01,  4.0052e-01, -1.9379e-01,  1.9511e-01,
#             5.5844e-02,  1.5201e-01, -2.4522e-01, -1.7641e-01, -2.5315e-01,
#            -1.7867e-01, -2.1425e-01, -1.4516e-01, -4.0096e-01,  7.6207e-02,
#             2.9988e-01,  3.7973e-01, -1.2842e-03,  5.4212e-01,  4.1303e-01,
#            -2.4690e-01, -3.0636e-01,  4.5861e-01],
#           [-6.7076e-02, -1.4981e-01, -5.0485e-02,  4.1239e-02,  5.7786e-02,
#            -4.0090e-02,  1.7192e-01,  5.4917e-01,  4.0920e-01,  4.1377e-01,
#            -7.3474e-01,  1.7478e-01,  2.6263e-01,  2.3820e-01,  4.0751e-01,
#            -2.1979e-02, -1.1016e-01,  3.2486e-01,  2.2441e-01,  1.3555e-01,
#             8.9648e-02,  5.4989e-01, -2.0372e-01,  7.9197e-03,  2.4757e-01,
#             1.2877e-01,  4.0095e-01,  4.0813e-02],
#           [ 2.8814e-01,  5.3218e-01, -2.7910e-01, -9.0633e-03,  1.3595e-01,
#            -8.3562e-02,  4.1258e-01,  2.7265e-01, -4.4007e-01, -6.4523e-02,
#             7.6248e-02, -7.4228e-01,  9.1430e-02, -1.7635e-01,  5.1759e-01,
#             2.5020e-01,  2.3402e-02,  3.3008e-01,  3.1474e-01,  1.1642e-01,
#            -3.7376e-01,  5.3011e-01,  7.2140e-02, -2.8760e-01, -3.9452e-01,
#            -3.9308e-01,  1.2560e-01, -1.9912e-02],
#           [ 1.7887e-01,  2.8238e-01, -5.6227e-01,  2.2989e-01, -1.9243e-01,
#             6.9751e-01, -7.5933e-01, -2.5750e-01, -3.5065e-01, -4.7100e-02,
#            -3.0549e-03,  1.9131e-01, -3.6431e-02, -7.0241e-02, -7.0511e-01,
#             6.0408e-01, -2.3368e-01, -5.1974e-01, -1.9339e-01, -1.6088e-02,
#            -3.0600e-01,  3.8468e-01,  4.1228e-01, -1.4019e-01, -1.6932e-02,
#             3.8533e-01, -2.8044e-01, -6.7900e-01],
#           [ 1.3231e-01,  1.2665e-01,  2.0258e-01, -4.7132e-01, -2.9620e-01,
 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.2490, 0.4266, 0.0000, 0.0000,
#            0.0000, 0.1056, 0.4432, 0.0000, 0.0000, 0.5718, 0.2353, 1.0000,
#            0.5631, 0.4060, 0.0000, 0.6403, 0.0000, 0.0000, 0.0000, 0.0155,
#            0.0000, 0.2619, 0.4040, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.8220, 0.0000, 0.0000, 0.0000, 0.2870,
#            0.0000, 0.0000, 0.3779, 0.0000, 0.1577, 0.1743, 1.0000, 0.8046,
#            0.7526, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1978, 0.0000,
#            0.0000, 0.0964, 0.0000, 0.2267],
#           [0.0000, 0.0091, 0.0000, 0.0513, 0.1403, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.4202, 0.1299, 0.4431, 0.3700, 0.7250, 0.9903,
#            0.2185, 0.0729, 0.1467, 0.3140, 0.2993, 0.1469, 0.1968, 0.0000,
#            0.2543, 0.0000, 0.0000, 0.1150],
#           [0.2628, 0.0000, 0.1236, 0.2650, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.1334, 0.0000, 0.4342, 0.6495, 1.0000, 1.0000, 0.4852,
#            0.0000, 0.0000, 0.0872, 0.0000, 0.0000, 0.4760, 0.2144, 0.0000,
#            0.0832, 0.2579, 0.0000, 0.3321],
#           [0.0000, 0.0000, 0.1633, 0.5112, 0.0000, 0.0965, 0.1727, 0.0000,
#            0.0130, 0.4138, 0.0945, 0.1994, 1.0000, 0.9637, 0.2011, 0.5428,
#            0.1878, 0.0000, 0.3377, 0.4496, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.3424],
#           [0.1297, 0.0000, 0.2043, 0.1313, 0.2623, 0.0000, 0.1170, 0.6928,
#            0.7620, 0.0219, 0.1681, 1.0000, 0.7078, 0.8286, 0.2026, 0.0000,
#            0.0000, 0.0000, 0.2106, 0.0000, 0.2074, 0.0000, 0.1066, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.1821, 0.0000, 0.0000, 0.1629, 0.0554, 0.1364, 0.0000, 0.0319,
#            0.0000, 0.0000, 0.4039, 0.9183, 0.8118, 1.0000, 0.5315, 0.0341,
#            0.2168, 0.0000, 0.0184, 0.0000, 0.5444, 0.0000, 0.0718, 0.0000,
#            0.0000, 0.0678, 0.0000, 0.3577],
#           [0.0361, 0.1304, 0.0000, 0.0000, 0.1641, 0.2864, 0.0000, 0.0000,
#            0.0776, 0.2579, 0.5119, 0.4855, 0.9704, 0.4720, 0.0787, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.3940, 0.2396, 0.2513, 0.0000,
#            0.0939, 0.1652, 0.0519, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0102, 0.0504, 0.0000, 0.0000,
#            0.0000, 0.2234, 0.0807, 1.0000, 0.7304, 0.1483, 0.0000, 0.1171,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0789, 0.2058, 0.0000,
#            0.0000, 0.0000, 0.5194, 0.0000],
#           [0.1300, 0.0000, 0.0000, 0.3004, 0.0000, 0.0000, 0.1241, 0.0000,
#            0.0269, 0.0000, 0.4369, 0.0000, 0.0000, 0.0000, 0.0151, 0.1334,
#            0.0000, 0.0000, 0.4297, 0.0000, 0.0137, 0.0685, 0.0000, 0.0167,
#            0.2035, 0.1674, 0.1090, 0.0588]]]])

# %%
def add_noise(inputs,noise_factor=0.3):
     noise = inputs+torch.randn_like(inputs)*noise_factor
     noise = torch.clip(noise,0.,1.)
     return noise

# %%
### Training function
def train_epoch_den(encoder, decoder, device, dataloader, loss_fn, optimizer, noise_factor=0.3):
    
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader:
        
        # Move tensor to the proper device
        image_noisy = add_noise(image_batch,noise_factor)
        image_noisy = image_noisy.to(device)    
        
        # Encode data
        encoded_data = encoder(image_noisy)
        
        # Decode data
        decoded_data = decoder(encoded_data)
        
        # Evaluate loss
        loss = loss_fn(decoded_data, image_noisy)
        
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Print batch loss
        print('\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)

# %%
### Testing function
def test_epoch_den(encoder, decoder, device, dataloader, loss_fn,noise_factor=0.3):
    
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    
    with torch.no_grad(): # No need to track the gradients
        
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        
        for image_batch, _ in dataloader:
            
            # Move tensor to the proper device
            image_noisy = add_noise(image_batch,noise_factor)
            image_noisy = image_noisy.to(device)
            
            # Encode data
            encoded_data = encoder(image_noisy)
            
            # Decode data
            decoded_data = decoder(encoded_data)
            
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
            
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
        
    return val_loss.data

# %%
def plot_ae_outputs_den(encoder,decoder,n=5,noise_factor=0.3):
    plt.figure(figsize=(10,4.5))
    for i in range(n):

        ax = plt.subplot(3,n,i+1)
        img = test_dataset[i][0].unsqueeze(0)
        image_noisy = add_noise(img,noise_factor)     
        image_noisy = image_noisy.to(device)

        encoder.eval()
        decoder.eval()

        with torch.no_grad():
            rec_img  = decoder(encoder(image_noisy))

        plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Original images')
            
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(image_noisy.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Corrupted images')

        ax = plt.subplot(3, n, i + 1 + n + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')  
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Reconstructed images')
            
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.7, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)     
    plt.show()

# %%
### Training cycle
noise_factor = 0.3
num_epochs = 30
history_da={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    print('EPOCH %d/%d' % (epoch + 1, num_epochs))
    
    ### Training (use the training function)
    train_loss=train_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=train_loader, 
        loss_fn=loss_fn, 
        optimizer=optim,noise_factor=noise_factor)
    
    ### Validation  (use the testing function)
    val_loss = test_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=valid_loader, 
        loss_fn=loss_fn,noise_factor=noise_factor)
    
    # Print Validationloss
    history_da['train_loss'].append(train_loss)
    history_da['val_loss'].append(val_loss)
    print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
    plot_ae_outputs_den(encoder,decoder,noise_factor=noise_factor)
# Out:
# EPOCH 1/30
# 	 partial train loss (single batch): 0.189798
# 	 partial train loss (single batch): 0.183832
# 	 partial train loss (single batch): 0.178869
# 	 partial train loss (single batch): 0.175436
# 	 partial train loss (single batch): 0.172752
# 	 partial train loss (single batch): 0.169561
# 	 partial train loss (single batch): 0.167927
# 	 partial train loss (single batch): 0.165227
# 	 partial train loss (single batch): 0.163723
# 	 partial train loss (single batch): 0.161798
# 	 partial train loss (single batch): 0.160195
# 	 partial train loss (single batch): 0.158240
# 	 partial train loss (single batch): 0.157177
# 	 partial train loss (single batch): 0.155942
# 	 partial train loss (single batch): 0.154339
# 	 partial train loss (single batch): 0.152543
# 	 partial train loss (single batch): 0.151269
# 	 partial train loss (single batch): 0.149921
# 	 partial train loss (single batch): 0.148096
# 	 partial train loss (single batch): 0.146541
# 	 partial train loss (single batch): 0.145438
# 	 partial train loss (single batch): 0.144275
# 	 partial train loss (single batch): 0.142955
# 	 partial train loss (single batch): 0.141851
# 	 partial train loss (single batch): 0.140148
# 	 partial train loss (single batch): 0.139305
# 	 partial train loss (single batch): 0.138216
# 	 partial train loss (single batch): 0.136949
# 	 partial train loss (single batch): 0.135772
# 	 partial train loss (single batch): 0.134442
# 	 partial train loss (single batch): 0.133393
# 	 partial train loss (single batch): 0.132751
# 	 partial train loss (single batch): 0.131926
# 	 partial train loss (single batch): 0.130760
# 	 partial train loss (single batch): 0.129494
# 	 partial train loss (single batch): 0.128650
# 	 partial train loss (single batch): 0.127837
# 	 partial train loss (single batch): 0.126748
# 	 partial train loss (single batch): 0.126107
# 	 partial train loss (single batch): 0.124884
# 	 partial train loss (single batch): 0.123540
# 	 partial train loss (single batch): 0.122708
# 	 partial train loss (single batch): 0.122276
# 	 partial train loss (single batch): 0.121267
# 	 partial train loss (single batch): 0.120325
# 	 partial train loss (single batch): 0.119650
# 	 partial train loss (single batch): 0.118900
# 	 partial train loss (single batch): 0.117826
# 	 partial train loss (single batch): 0.117117
# 	 partial train loss (single batch): 0.115899
# 	 partial train loss (single batch): 0.114932
# 	 partial train loss (single batch): 0.114813
# 	 partial train loss (single batch): 0.114067
# 	 partial train loss (single batch): 0.113549
# 	 partial train loss (single batch): 0.112103
# 	 partial train loss (single batch): 0.111389
# 	 partial train loss (single batch): 0.110995
# 	 partial train loss (single batch): 0.110493
# 	 partial train loss (single batch): 0.109574
# 	 partial train loss (single batch): 0.109009
# 	 partial train loss (single batch): 0.108071
# 	 partial train loss (single batch): 0.107484
# 	 partial train loss (single batch): 0.107029
# 	 partial train loss (single batch): 0.105704
# 	 partial train loss (single batch): 0.105715
# 	 partial train loss (single batch): 0.105104
# 	 partial train loss (single batch): 0.104197
# 	 partial train loss (single batch): 0.103570
# 	 partial train loss (single batch): 0.102895
# 	 partial train loss (single batch): 0.102252
# 	 partial train loss (single batch): 0.101687
# 	 partial train loss (single batch): 0.101371
# 	 partial train loss (single batch): 0.100765
# 	 partial train loss (single batch): 0.099718
# 	 partial train loss (single batch): 0.099594
# 	 partial train loss (single batch): 0.098157
# 	 partial train loss (single batch): 0.098186
# 	 partial train loss (single batch): 0.097756
# 	 partial train loss (single batch): 0.096417
# 	 partial train loss (single batch): 0.096761
# 	 partial train loss (single batch): 0.095404
# 	 partial train loss (single batch): 0.095417
# 	 partial train loss (single batch): 0.094949
# 	 partial train loss (single batch): 0.094320
# 	 partial train loss (single batch): 0.094440
# 	 partial train loss (single batch): 0.093596
# 	 partial train loss (single batch): 0.093099
# 	 partial train loss (single batch): 0.092092
# 	 partial train loss (single batch): 0.092058
# 	 partial train loss (single batch): 0.091376
# 	 partial train loss (single batch): 0.090645
# 	 partial train loss (single batch): 0.089968
# 	 partial train loss (single batch): 0.089615
# 	 partial train loss (single batch): 0.089572
# 	 partial train loss (single batch): 0.089017
# 	 partial train loss (single batch): 0.088509
# 	 partial train loss (single batch): 0.087441
# 	 partial train loss (single batch): 0.087402
# 	 partial train loss (single batch): 0.087294
# 	 partial train loss (single batch): 0.086821
# 	 partial train loss (single batch): 0.086628
# 	 partial train loss (single batch): 0.086320
# 	 partial train loss (single batch): 0.085510
# 	 partial train loss (single batch): 0.085273
# 	 partial train loss (single batch): 0.084590
# 	 partial train loss (single batch): 0.084496
# 	 partial train loss (single batch): 0.083505
# 	 partial train loss (single batch): 0.083533
# 	 partial train loss (single batch): 0.084052
# 	 partial train loss (single batch): 0.083071
# 	 partial train loss (single batch): 0.082805
# 	 partial train loss (single batch): 0.082341
# 	 partial train loss (single batch): 0.082424
# 	 partial train loss (single batch): 0.082020
# 	 partial train loss (single batch): 0.081330
# 	 partial train loss (single batch): 0.081006
# 	 partial train loss (single batch): 0.080568
# 	 partial train loss (single batch): 0.080166
# 	 partial train loss (single batch): 0.081074
# 	 partial train loss (single batch): 0.079980
# 	 partial train loss (single batch): 0.080037
# 	 partial train loss (single batch): 0.079405
# 	 partial train loss (single batch): 0.078477
# 	 partial train loss (single batch): 0.078077
# 	 partial train loss (single batch): 0.078033
# 	 partial train loss (single batch): 0.078197
# 	 partial train loss (single batch): 0.078045
# 	 partial train loss (single batch): 0.077891
# 	 partial train loss (single batch): 0.077396
# 	 partial train loss (single batch): 0.077356
# 	 partial train loss (single batch): 0.076408
# 	 partial train loss (single batch): 0.076413
# 	 partial train loss (single batch): 0.075720
# 	 partial train loss (single batch): 0.076181
# 	 partial train loss (single batch): 0.075837
# 	 partial train loss (single batch): 0.075200
# 	 partial train loss (single batch): 0.075417
# 	 partial train loss (single batch): 0.075552
# 	 partial train loss (single batch): 0.074615
# 	 partial train loss (single batch): 0.074059
# 	 partial train loss (single batch): 0.074051
# 	 partial train loss (single batch): 0.073468
# 	 partial train loss (single batch): 0.074669
# 	 partial train loss (single batch): 0.073636
# 	 partial train loss (single batch): 0.074690
# 	 partial train loss (single batch): 0.072441
# 	 partial train loss (single batch): 0.072779
# 	 partial train loss (single batch): 0.073114
# 	 partial train loss (single batch): 0.072481
# 	 partial train loss (single batch): 0.073152
# 	 partial train loss (single batch): 0.071875
# 	 partial train loss (single batch): 0.071945
# 	 partial train loss (single batch): 0.073085
# 	 partial train loss (single batch): 0.071640
# 	 partial train loss (single batch): 0.070766
# 	 partial train loss (single batch): 0.071290
# 	 partial train loss (single batch): 0.071737
# 	 partial train loss (single batch): 0.070004
# 	 partial train loss (single batch): 0.071209
# 	 partial train loss (single batch): 0.070502
# 	 partial train loss (single batch): 0.070964
# 	 partial train loss (single batch): 0.070703
# 	 partial train loss (single batch): 0.070126
# 	 partial train loss (single batch): 0.070432
# 	 partial train loss (single batch): 0.071121
# 	 partial train loss (single batch): 0.069666
# 	 partial train loss (single batch): 0.070635
# 	 partial train loss (single batch): 0.069983
# 	 partial train loss (single batch): 0.069838
# 	 partial train loss (single batch): 0.069324
# 	 partial train loss (single batch): 0.069110
# 	 partial train loss (single batch): 0.069274
# 	 partial train loss (single batch): 0.069005
# 	 partial train loss (single batch): 0.068611
# 	 partial train loss (single batch): 0.069035
# 	 partial train loss (single batch): 0.068735
# 	 partial train loss (single batch): 0.069308
# 	 partial train loss (single batch): 0.069083
# 	 partial train loss (single batch): 0.067327
# 	 partial train loss (single batch): 0.068274
# 	 partial train loss (single batch): 0.068634
# 	 partial train loss (single batch): 0.068298
# 	 partial train loss (single batch): 0.068085
# 	 partial train loss (single batch): 0.066885
# 	 partial train loss (single batch): 0.068773
# 	 partial train loss (single batch): 0.067193
# 	 partial train loss (single batch): 0.067402
# 	 partial train loss (single batch): 0.066737
#
#  EPOCH 1/30 	 train loss 0.100 	 val loss 0.071
# EPOCH 2/30
# 	 partial train loss (single batch): 0.067004
# 	 partial train loss (single batch): 0.067396
# 	 partial train loss (single batch): 0.067440
# 	 partial train loss (single batch): 0.067167
# 	 partial train loss (single batch): 0.066489
# 	 partial train loss (single batch): 0.067363
# 	 partial train loss (single batch): 0.066498
# 	 partial train loss (single batch): 0.066986
# 	 partial train loss (single batch): 0.065996
# 	 partial train loss (single batch): 0.066353
# 	 partial train loss (single batch): 0.066112
# 	 partial train loss (single batch): 0.066785
# 	 partial train loss (single batch): 0.066694
# 	 partial train loss (single batch): 0.066642
# 	 partial train loss (single batch): 0.066115
# 	 partial train loss (single batch): 0.066086
# 	 partial train loss (single batch): 0.066599
# 	 partial train loss (single batch): 0.065761
# 	 partial train loss (single batch): 0.066732
# 	 partial train loss (single batch): 0.066078
# 	 partial train loss (single batch): 0.065905
# 	 partial train loss (single batch): 0.065580
# 	 partial train loss (single batch): 0.066192
# 	 partial train loss (single batch): 0.064952
# 	 partial train loss (single batch): 0.064753
# 	 partial train loss (single batch): 0.065717
# 	 partial train loss (single batch): 0.065409
# 	 partial train loss (single batch): 0.064609
# 	 partial train loss (single batch): 0.064277
# 	 partial train loss (single batch): 0.065438
# 	 partial train loss (single batch): 0.064591
# 	 partial train loss (single batch): 0.065120
# 	 partial train loss (single batch): 0.065820
# 	 partial train loss (single batch): 0.065747
# 	 partial train loss (single batch): 0.064416
# 	 partial train loss (single batch): 0.064342
# 	 partial train loss (single batch): 0.064483
# 	 partial train loss (single batch): 0.064005
# 	 partial train loss (single batch): 0.064696
# 	 partial train loss (single batch): 0.063769
# 	 partial train loss (single batch): 0.063412
# 	 partial train loss (single batch): 0.063761
# 	 partial train loss (single batch): 0.064745
# 	 partial train loss (single batch): 0.063681
# 	 partial train loss (single batch): 0.064537
# 	 partial train loss (single batch): 0.064184
# 	 partial train loss (single batch): 0.063591
# 	 partial train loss (single batch): 0.063799
# 	 partial train loss (single batch): 0.063613
# 	 partial train loss (single batch): 0.064186
# 	 partial train loss (single batch): 0.063379
# 	 partial train loss (single batch): 0.064191
# 	 partial train loss (single batch): 0.063279
# 	 partial train loss (single batch): 0.063938
# 	 partial train loss (single batch): 0.062975
# 	 partial train loss (single batch): 0.063628
# 	 partial train loss (single batch): 0.063261
# 	 partial train loss (single batch): 0.063823
# 	 partial train loss (single batch): 0.063853
# 	 partial train loss (single batch): 0.064406
# 	 partial train loss (single batch): 0.062904
# 	 partial train loss (single batch): 0.063663
# 	 partial train loss (single batch): 0.062925
# 	 partial train loss (single batch): 0.063587
# 	 partial train loss (single batch): 0.064193
# 	 partial train loss (single batch): 0.062754
# 	 partial train loss (single batch): 0.063769
# 	 partial train loss (single batch): 0.063626
# 	 partial train loss (single batch): 0.063399
# 	 partial train loss (single batch): 0.062925
# 	 partial train loss (single batch): 0.062679
# 	 partial train loss (single batch): 0.063304
# 	 partial train loss (single batch): 0.063732
# 	 partial train loss (single batch): 0.062354
# 	 partial train loss (single batch): 0.062509
# 	 partial train loss (single batch): 0.061614
# 	 partial train loss (single batch): 0.062499
# 	 partial train loss (single batch): 0.063298
# 	 partial train loss (single batch): 0.061725
# 	 partial train loss (single batch): 0.063690
# 	 partial train loss (single batch): 0.062404
# 	 partial train loss (single batch): 0.062912
# 	 partial train loss (single batch): 0.062541
# 	 partial train loss (single batch): 0.062855
# 	 partial train loss (single batch): 0.063539
# 	 partial train loss (single batch): 0.063412
# 	 partial train loss (single batch): 0.063202
# 	 partial train loss (single batch): 0.062100
# 	 partial train loss (single batch): 0.063347
# 	 partial train loss (single batch): 0.061646
# 	 partial train loss (single batch): 0.061825
# 	 partial train loss (single batch): 0.062185
# 	 partial train loss (single batch): 0.061166
# 	 partial train loss (single batch): 0.061965
# 	 partial train loss (single batch): 0.062179
# 	 partial train loss (single batch): 0.061722
# 	 partial train loss (single batch): 0.061539
# 	 partial train loss (single batch): 0.061809
# 	 partial train loss (single batch): 0.061823
# 	 partial train loss (single batch): 0.062524
# 	 partial train loss (single batch): 0.062275
# 	 partial train loss (single batch): 0.062309
# 	 partial train loss (single batch): 0.061819
# 	 partial train loss (single batch): 0.062566
# 	 partial train loss (single batch): 0.062067
# 	 partial train loss (single batch): 0.062252
# 	 partial train loss (single batch): 0.060194
# 	 partial train loss (single batch): 0.061633
# 	 partial train loss (single batch): 0.062913
# 	 partial train loss (single batch): 0.061985
# 	 partial train loss (single batch): 0.061146
# 	 partial train loss (single batch): 0.062349
# 	 partial train loss (single batch): 0.061551
# 	 partial train loss (single batch): 0.062749
# 	 partial train loss (single batch): 0.061515
# 	 partial train loss (single batch): 0.062169
# 	 partial train loss (single batch): 0.061224
# 	 partial train loss (single batch): 0.061616
# 	 partial train loss (single batch): 0.062779
# 	 partial train loss (single batch): 0.061682
# 	 partial train loss (single batch): 0.062680
# 	 partial train loss (single batch): 0.062372
# 	 partial train loss (single batch): 0.061063
# 	 partial train loss (single batch): 0.060751
# 	 partial train loss (single batch): 0.061265
# 	 partial train loss (single batch): 0.061322
# 	 partial train loss (single batch): 0.061342
# 	 partial train loss (single batch): 0.061860
# 	 partial train loss (single batch): 0.061569
# 	 partial train loss (single batch): 0.061975
# 	 partial train loss (single batch): 0.061239
# 	 partial train loss (single batch): 0.061043
# 	 partial train loss (single batch): 0.060301
# 	 partial train loss (single batch): 0.061178
# 	 partial train loss (single batch): 0.061199
# 	 partial train loss (single batch): 0.061271
# 	 partial train loss (single batch): 0.060990
# 	 partial train loss (single batch): 0.061703
# 	 partial train loss (single batch): 0.060697
# 	 partial train loss (single batch): 0.059875
# 	 partial train loss (single batch): 0.060199
# 	 partial train loss (single batch): 0.060722
# 	 partial train loss (single batch): 0.061780
# 	 partial train loss (single batch): 0.060855
# 	 partial train loss (single batch): 0.062171
# 	 partial train loss (single batch): 0.059552
# 	 partial train loss (single batch): 0.060350
# 	 partial train loss (single batch): 0.060732
# 	 partial train loss (single batch): 0.061191
# 	 partial train loss (single batch): 0.061198
# 	 partial train loss (single batch): 0.061204
# 	 partial train loss (single batch): 0.060250
# 	 partial train loss (single batch): 0.061856
# 	 partial train loss (single batch): 0.060927
# 	 partial train loss (single batch): 0.060015
# 	 partial train loss (single batch): 0.060527
# 	 partial train loss (single batch): 0.060814
# 	 partial train loss (single batch): 0.059346
# 	 partial train loss (single batch): 0.060996
# 	 partial train loss (single batch): 0.060505
# 	 partial train loss (single batch): 0.061060
# 	 partial train loss (single batch): 0.060181
# 	 partial train loss (single batch): 0.060294
# 	 partial train loss (single batch): 0.060373
# 	 partial train loss (single batch): 0.061182
# 	 partial train loss (single batch): 0.060448
# 	 partial train loss (single batch): 0.060716
# 	 partial train loss (single batch): 0.061258
# 	 partial train loss (single batch): 0.060958
# 	 partial train loss (single batch): 0.059599
# 	 partial train loss (single batch): 0.059769
# 	 partial train loss (single batch): 0.060322
# 	 partial train loss (single batch): 0.060242
# 	 partial train loss (single batch): 0.059898
# 	 partial train loss (single batch): 0.059594
# 	 partial train loss (single batch): 0.060329
# 	 partial train loss (single batch): 0.061158
# 	 partial train loss (single batch): 0.060742
# 	 partial train loss (single batch): 0.059658
# 	 partial train loss (single batch): 0.060286
# 	 partial train loss (single batch): 0.060523
# 	 partial train loss (single batch): 0.060035
# 	 partial train loss (single batch): 0.060156
# 	 partial train loss (single batch): 0.058864
# 	 partial train loss (single batch): 0.060580
# 	 partial train loss (single batch): 0.059422
# 	 partial train loss (single batch): 0.059758
# 	 partial train loss (single batch): 0.059607
#
#  EPOCH 2/30 	 train loss 0.063 	 val loss 0.055
# EPOCH 3/30
# 	 partial train loss (single batch): 0.059267
# 	 partial train loss (single batch): 0.059501
# 	 partial train loss (single batch): 0.060239
# 	 partial train loss (single batch): 0.059918
# 	 partial train loss (single batch): 0.058917
# 	 partial train loss (single batch): 0.059882
# 	 partial train loss (single batch): 0.059362
# 	 partial train loss (single batch): 0.059220
# 	 partial train loss (single batch): 0.058570
# 	 partial train loss (single batch): 0.059463
# 	 partial train loss (single batch): 0.058436
# 	 partial train loss (single batch): 0.060070
# 	 partial train loss (single batch): 0.059748
# 	 partial train loss (single batch): 0.059296
# 	 partial train loss (single batch): 0.059265
# 	 partial train loss (single batch): 0.058982
# 	 partial train loss (single batch): 0.059957
# 	 partial train loss (single batch): 0.059071
# 	 partial train loss (single batch): 0.059916
# 	 partial train loss (single batch): 0.059215
# 	 partial train loss (single batch): 0.059531
# 	 partial train loss (single batch): 0.058758
# 	 partial train loss (single batch): 0.059234
# 	 partial train loss (single batch): 0.058786
# 	 partial train loss (single batch): 0.058081
# 	 partial train loss (single batch): 0.059405
# 	 partial train loss (single batch): 0.059404
# 	 partial train loss (single batch): 0.058110
# 	 partial train loss (single batch): 0.058062
# 	 partial train loss (single batch): 0.059191
# 	 partial train loss (single batch): 0.058541
# 	 partial train loss (single batch): 0.058431
# 	 partial train loss (single batch): 0.059764
# 	 partial train loss (single batch): 0.059408
# 	 partial train loss (single batch): 0.058407
# 	 partial train loss (single batch): 0.058162
# 	 partial train loss (single batch): 0.059164
# 	 partial train loss (single batch): 0.058256
# 	 partial train loss (single batch): 0.058638
# 	 partial train loss (single batch): 0.057730
# 	 partial train loss (single batch): 0.057394
# 	 partial train loss (single batch): 0.058022
# 	 partial train loss (single batch): 0.058891
# 	 partial train loss (single batch): 0.057757
# 	 partial train loss (single batch): 0.059097
# 	 partial train loss (single batch): 0.058056
# 	 partial train loss (single batch): 0.058141
# 	 partial train loss (single batch): 0.057633
# 	 partial train loss (single batch): 0.058003
# 	 partial train loss (single batch): 0.058620
# 	 partial train loss (single batch): 0.058067
# 	 partial train loss (single batch): 0.058362
# 	 partial train loss (single batch): 0.057805
# 	 partial train loss (single batch): 0.058095
# 	 partial train loss (single batch): 0.057261
# 	 partial train loss (single batch): 0.057563
# 	 partial train loss (single batch): 0.058029
# 	 partial train loss (single batch): 0.058543
# 	 partial train loss (single batch): 0.058077
# 	 partial train loss (single batch): 0.059077
# 	 partial train loss (single batch): 0.057528
# 	 partial train loss (single batch): 0.058060
# 	 partial train loss (single batch): 0.056962
# 	 partial train loss (single batch): 0.058123
# 	 partial train loss (single batch): 0.058282
# 	 partial train loss (single batch): 0.056952
# 	 partial train loss (single batch): 0.058346
# 	 partial train loss (single batch): 0.057903
# 	 partial train loss (single batch): 0.057637
# 	 partial train loss (single batch): 0.057523
# 	 partial train loss (single batch): 0.056919
# 	 partial train loss (single batch): 0.058115
# 	 partial train loss (single batch): 0.058290
# 	 partial train loss (single batch): 0.056209
# 	 partial train loss (single batch): 0.057142
# 	 partial train loss (single batch): 0.056261
# 	 partial train loss (single batch): 0.057167
# 	 partial train loss (single batch): 0.058126
# 	 partial train loss (single batch): 0.056368
# 	 partial train loss (single batch): 0.058361
# 	 partial train loss (single batch): 0.056963
# 	 partial train loss (single batch): 0.057797
# 	 partial train loss (single batch): 0.057422
# 	 partial train loss (single batch): 0.057585
# 	 partial train loss (single batch): 0.058262
# 	 partial train loss (single batch): 0.057704
# 	 partial train loss (single batch): 0.057658
# 	 partial train loss (single batch): 0.056228
# 	 partial train loss (single batch): 0.058406
# 	 partial train loss (single batch): 0.056769
# 	 partial train loss (single batch): 0.056270
# 	 partial train loss (single batch): 0.056591
# 	 partial train loss (single batch): 0.056111
# 	 partial train loss (single batch): 0.056662
# 	 partial train loss (single batch): 0.057686
# 	 partial train loss (single batch): 0.056943
# 	 partial train loss (single batch): 0.056622
# 	 partial train loss (single batch): 0.056746
# 	 partial train loss (single batch): 0.056035
# 	 partial train loss (single batch): 0.057410
# 	 partial train loss (single batch): 0.056959
# 	 partial train loss (single batch): 0.056785
# 	 partial train loss (single batch): 0.056760
# 	 partial train loss (single batch): 0.057023
# 	 partial train loss (single batch): 0.056956
# 	 partial train loss (single batch): 0.057203
# 	 partial train loss (single batch): 0.054780
# 	 partial train loss (single batch): 0.056338
# 	 partial train loss (single batch): 0.057566
# 	 partial train loss (single batch): 0.056217
# 	 partial train loss (single batch): 0.056170
# 	 partial train loss (single batch): 0.057501
# 	 partial train loss (single batch): 0.056584
# 	 partial train loss (single batch): 0.057876
# 	 partial train loss (single batch): 0.056134
# 	 partial train loss (single batch): 0.057137
# 	 partial train loss (single batch): 0.056163
# 	 partial train loss (single batch): 0.056553
# 	 partial train loss (single batch): 0.057791
# 	 partial train loss (single batch): 0.056781
# 	 partial train loss (single batch): 0.057837
# 	 partial train loss (single batch): 0.057915
# 	 partial train loss (single batch): 0.056299
# 	 partial train loss (single batch): 0.055455
# 	 partial train loss (single batch): 0.056047
# 	 partial train loss (single batch): 0.056509
# 	 partial train loss (single batch): 0.055924
# 	 partial train loss (single batch): 0.056780
# 	 partial train loss (single batch): 0.056312
# 	 partial train loss (single batch): 0.056737
# 	 partial train loss (single batch): 0.056208
# 	 partial train loss (single batch): 0.056093
# 	 partial train loss (single batch): 0.055345
# 	 partial train loss (single batch): 0.056516
# 	 partial train loss (single batch): 0.056382
# 	 partial train loss (single batch): 0.056397
# 	 partial train loss (single batch): 0.056259
# 	 partial train loss (single batch): 0.056878
# 	 partial train loss (single batch): 0.055744
# 	 partial train loss (single batch): 0.054766
# 	 partial train loss (single batch): 0.055129
# 	 partial train loss (single batch): 0.056014
# 	 partial train loss (single batch): 0.056380
# 	 partial train loss (single batch): 0.055778
# 	 partial train loss (single batch): 0.057017
# 	 partial train loss (single batch): 0.054838
# 	 partial train loss (single batch): 0.054879
# 	 partial train loss (single batch): 0.056150
# 	 partial train loss (single batch): 0.056607
# 	 partial train loss (single batch): 0.056283
# 	 partial train loss (single batch): 0.056324
# 	 partial train loss (single batch): 0.055680
# 	 partial train loss (single batch): 0.056837
# 	 partial train loss (single batch): 0.056007
# 	 partial train loss (single batch): 0.055108
# 	 partial train loss (single batch): 0.055143
# 	 partial train loss (single batch): 0.055766
# 	 partial train loss (single batch): 0.055152
# 	 partial train loss (single batch): 0.055900
# 	 partial train loss (single batch): 0.056089
# 	 partial train loss (single batch): 0.055986
# 	 partial train loss (single batch): 0.055301
# 	 partial train loss (single batch): 0.055157
# 	 partial train loss (single batch): 0.055471
# 	 partial train loss (single batch): 0.056122
# 	 partial train loss (single batch): 0.055149
# 	 partial train loss (single batch): 0.056290
# 	 partial train loss (single batch): 0.056861
# 	 partial train loss (single batch): 0.056085
# 	 partial train loss (single batch): 0.055310
# 	 partial train loss (single batch): 0.055108
# 	 partial train loss (single batch): 0.055678
# 	 partial train loss (single batch): 0.055554
# 	 partial train loss (single batch): 0.055563
# 	 partial train loss (single batch): 0.054852
# 	 partial train loss (single batch): 0.055193
# 	 partial train loss (single batch): 0.056636
# 	 partial train loss (single batch): 0.055898
# 	 partial train loss (single batch): 0.054986
# 	 partial train loss (single batch): 0.055307
# 	 partial train loss (single batch): 0.055373
# 	 partial train loss (single batch): 0.055826
# 	 partial train loss (single batch): 0.055314
# 	 partial train loss (single batch): 0.054155
# 	 partial train loss (single batch): 0.056010
# 	 partial train loss (single batch): 0.054288
# 	 partial train loss (single batch): 0.055435
# 	 partial train loss (single batch): 0.055525
#
#  EPOCH 3/30 	 train loss 0.057 	 val loss 0.047
# EPOCH 4/30
# 	 partial train loss (single batch): 0.054625
# 	 partial train loss (single batch): 0.055512
# 	 partial train loss (single batch): 0.055414
# 	 partial train loss (single batch): 0.055146
# 	 partial train loss (single batch): 0.054799
# 	 partial train loss (single batch): 0.055427
# 	 partial train loss (single batch): 0.054663
# 	 partial train loss (single batch): 0.054887
# 	 partial train loss (single batch): 0.054301
# 	 partial train loss (single batch): 0.055311
# 	 partial train loss (single batch): 0.054401
# 	 partial train loss (single batch): 0.056051
# 	 partial train loss (single batch): 0.054914
# 	 partial train loss (single batch): 0.054626
# 	 partial train loss (single batch): 0.055047
# 	 partial train loss (single batch): 0.054671
# 	 partial train loss (single batch): 0.055550
# 	 partial train loss (single batch): 0.054888
# 	 partial train loss (single batch): 0.055804
# 	 partial train loss (single batch): 0.054951
# 	 partial train loss (single batch): 0.054559
# 	 partial train loss (single batch): 0.055099
# 	 partial train loss (single batch): 0.055137
# 	 partial train loss (single batch): 0.054728
# 	 partial train loss (single batch): 0.054104
# 	 partial train loss (single batch): 0.054940
# 	 partial train loss (single batch): 0.055103
# 	 partial train loss (single batch): 0.053968
# 	 partial train loss (single batch): 0.053744
# 	 partial train loss (single batch): 0.054805
# 	 partial train loss (single batch): 0.054061
# 	 partial train loss (single batch): 0.054648
# 	 partial train loss (single batch): 0.055111
# 	 partial train loss (single batch): 0.054795
# 	 partial train loss (single batch): 0.054139
# 	 partial train loss (single batch): 0.054556
# 	 partial train loss (single batch): 0.055175
# 	 partial train loss (single batch): 0.053982
# 	 partial train loss (single batch): 0.054905
# 	 partial train loss (single batch): 0.054051
# 	 partial train loss (single batch): 0.053336
# 	 partial train loss (single batch): 0.053857
# 	 partial train loss (single batch): 0.055019
# 	 partial train loss (single batch): 0.053815
# 	 partial train loss (single batch): 0.055051
# 	 partial train loss (single batch): 0.054091
# 	 partial train loss (single batch): 0.054921
# 	 partial train loss (single batch): 0.053629
# 	 partial train loss (single batch): 0.054341
# 	 partial train loss (single batch): 0.054658
# 	 partial train loss (single batch): 0.054210
# 	 partial train loss (single batch): 0.054729
# 	 partial train loss (single batch): 0.054095
# 	 partial train loss (single batch): 0.054109
# 	 partial train loss (single batch): 0.053708
# 	 partial train loss (single batch): 0.054215
# 	 partial train loss (single batch): 0.054295
# 	 partial train loss (single batch): 0.054672
# 	 partial train loss (single batch): 0.054283
# 	 partial train loss (single batch): 0.055628
# 	 partial train loss (single batch): 0.054189
# 	 partial train loss (single batch): 0.054389
# 	 partial train loss (single batch): 0.053556
# 	 partial train loss (single batch): 0.055110
# 	 partial train loss (single batch): 0.054722
# 	 partial train loss (single batch): 0.053530
# 	 partial train loss (single batch): 0.054813
# 	 partial train loss (single batch): 0.054448
# 	 partial train loss (single batch): 0.053838
# 	 partial train loss (single batch): 0.054115
# 	 partial train loss (single batch): 0.053444
# 	 partial train loss (single batch): 0.054628
# 	 partial train loss (single batch): 0.054708
# 	 partial train loss (single batch): 0.053112
# 	 partial train loss (single batch): 0.053792
# 	 partial train loss (single batch): 0.053441
# 	 partial train loss (single batch): 0.053852
# 	 partial train loss (single batch): 0.054747
# 	 partial train loss (single batch): 0.053216
# 	 partial train loss (single batch): 0.054768
# 	 partial train loss (single batch): 0.054418
# 	 partial train loss (single batch): 0.054695
# 	 partial train loss (single batch): 0.054094
# 	 partial train loss (single batch): 0.054381
# 	 partial train loss (single batch): 0.055060
# 	 partial train loss (single batch): 0.053736
# 	 partial train loss (single batch): 0.054778
# 	 partial train loss (single batch): 0.053356
# 	 partial train loss (single batch): 0.055398
# 	 partial train loss (single batch): 0.053880
# 	 partial train loss (single batch): 0.053206
# 	 partial train loss (single batch): 0.053982
# 	 partial train loss (single batch): 0.053304
# 	 partial train loss (single batch): 0.053540
# 	 partial train loss (single batch): 0.054197
# 	 partial train loss (single batch): 0.054150
# 	 partial train loss (single batch): 0.053592
# 	 partial train loss (single batch): 0.054252
# 	 partial train loss (single batch): 0.053484
# 	 partial train loss (single batch): 0.054898
# 	 partial train loss (single batch): 0.054425
# 	 partial train loss (single batch): 0.053864
# 	 partial train loss (single batch): 0.053728
# 	 partial train loss (single batch): 0.054243
# 	 partial train loss (single batch): 0.053865
# 	 partial train loss (single batch): 0.054181
# 	 partial train loss (single batch): 0.051829
# 	 partial train loss (single batch): 0.054142
# 	 partial train loss (single batch): 0.054608
# 	 partial train loss (single batch): 0.053251
# 	 partial train loss (single batch): 0.053010
# 	 partial train loss (single batch): 0.054839
# 	 partial train loss (single batch): 0.053659
# 	 partial train loss (single batch): 0.054611
# 	 partial train loss (single batch): 0.053683
# 	 partial train loss (single batch): 0.054478
# 	 partial train loss (single batch): 0.053475
# 	 partial train loss (single batch): 0.054034
# 	 partial train loss (single batch): 0.055107
# 	 partial train loss (single batch): 0.053780
# 	 partial train loss (single batch): 0.055021
# 	 partial train loss (single batch): 0.055214
# 	 partial train loss (single batch): 0.053565
# 	 partial train loss (single batch): 0.052953
# 	 partial train loss (single batch): 0.053266
# 	 partial train loss (single batch): 0.054127
# 	 partial train loss (single batch): 0.053206
# 	 partial train loss (single batch): 0.054414
# 	 partial train loss (single batch): 0.054075
# 	 partial train loss (single batch): 0.053861
# 	 partial train loss (single batch): 0.054028
# 	 partial train loss (single batch): 0.054207
# 	 partial train loss (single batch): 0.052799
# 	 partial train loss (single batch): 0.053972
# 	 partial train loss (single batch): 0.053700
# 	 partial train loss (single batch): 0.054418
# 	 partial train loss (single batch): 0.054392
# 	 partial train loss (single batch): 0.054079
# 	 partial train loss (single batch): 0.053320
# 	 partial train loss (single batch): 0.052501
# 	 partial train loss (single batch): 0.052892
# 	 partial train loss (single batch): 0.053736
# 	 partial train loss (single batch): 0.054134
# 	 partial train loss (single batch): 0.053617
# 	 partial train loss (single batch): 0.055077
# 	 partial train loss (single batch): 0.052356
# 	 partial train loss (single batch): 0.052663
# 	 partial train loss (single batch): 0.053767
# 	 partial train loss (single batch): 0.053576
# 	 partial train loss (single batch): 0.054327
# 	 partial train loss (single batch): 0.054381
# 	 partial train loss (single batch): 0.053556
# 	 partial train loss (single batch): 0.055045
# 	 partial train loss (single batch): 0.053948
# 	 partial train loss (single batch): 0.052882
# 	 partial train loss (single batch): 0.053461
# 	 partial train loss (single batch): 0.053703
# 	 partial train loss (single batch): 0.053308
# 	 partial train loss (single batch): 0.053994
# 	 partial train loss (single batch): 0.054113
# 	 partial train loss (single batch): 0.054216
# 	 partial train loss (single batch): 0.053540
# 	 partial train loss (single batch): 0.052927
# 	 partial train loss (single batch): 0.053535
# 	 partial train loss (single batch): 0.054100
# 	 partial train loss (single batch): 0.053367
# 	 partial train loss (single batch): 0.054698
# 	 partial train loss (single batch): 0.054707
# 	 partial train loss (single batch): 0.053920
# 	 partial train loss (single batch): 0.053021
# 	 partial train loss (single batch): 0.053151
# 	 partial train loss (single batch): 0.054056
# 	 partial train loss (single batch): 0.053567
# 	 partial train loss (single batch): 0.053636
# 	 partial train loss (single batch): 0.052974
# 	 partial train loss (single batch): 0.053503
# 	 partial train loss (single batch): 0.054656
# 	 partial train loss (single batch): 0.054241
# 	 partial train loss (single batch): 0.053248
# 	 partial train loss (single batch): 0.054053
# 	 partial train loss (single batch): 0.053809
# 	 partial train loss (single batch): 0.054109
# 	 partial train loss (single batch): 0.053386
# 	 partial train loss (single batch): 0.052979
# 	 partial train loss (single batch): 0.053855
# 	 partial train loss (single batch): 0.052745
# 	 partial train loss (single batch): 0.053678
# 	 partial train loss (single batch): 0.053525
#
#  EPOCH 4/30 	 train loss 0.054 	 val loss 0.044
# EPOCH 5/30
# 	 partial train loss (single batch): 0.052920
# 	 partial train loss (single batch): 0.053527
# 	 partial train loss (single batch): 0.053554
# 	 partial train loss (single batch): 0.053335
# 	 partial train loss (single batch): 0.053018
# 	 partial train loss (single batch): 0.053650
# 	 partial train loss (single batch): 0.053139
# 	 partial train loss (single batch): 0.053477
# 	 partial train loss (single batch): 0.052696
# 	 partial train loss (single batch): 0.053526
# 	 partial train loss (single batch): 0.052937
# 	 partial train loss (single batch): 0.054191
# 	 partial train loss (single batch): 0.053303
# 	 partial train loss (single batch): 0.052862
# 	 partial train loss (single batch): 0.053684
# 	 partial train loss (single batch): 0.053243
# 	 partial train loss (single batch): 0.053705
# 	 partial train loss (single batch): 0.053413
# 	 partial train loss (single batch): 0.053960
# 	 partial train loss (single batch): 0.053489
# 	 partial train loss (single batch): 0.053482
# 	 partial train loss (single batch): 0.053370
# 	 partial train loss (single batch): 0.054103
# 	 partial train loss (single batch): 0.053136
# 	 partial train loss (single batch): 0.052772
# 	 partial train loss (single batch): 0.053413
# 	 partial train loss (single batch): 0.053499
# 	 partial train loss (single batch): 0.052463
# 	 partial train loss (single batch): 0.052321
# 	 partial train loss (single batch): 0.053393
# 	 partial train loss (single batch): 0.052287
# 	 partial train loss (single batch): 0.053376
# 	 partial train loss (single batch): 0.053857
# 	 partial train loss (single batch): 0.053452
# 	 partial train loss (single batch): 0.052686
# 	 partial train loss (single batch): 0.053227
# 	 partial train loss (single batch): 0.053662
# 	 partial train loss (single batch): 0.052539
# 	 partial train loss (single batch): 0.053414
# 	 partial train loss (single batch): 0.052345
# 	 partial train loss (single batch): 0.051820
# 	 partial train loss (single batch): 0.052961
# 	 partial train loss (single batch): 0.053699
# 	 partial train loss (single batch): 0.052506
# 	 partial train loss (single batch): 0.053830
# 	 partial train loss (single batch): 0.052991
# 	 partial train loss (single batch): 0.053244
# 	 partial train loss (single batch): 0.052146
# 	 partial train loss (single batch): 0.052976
# 	 partial train loss (single batch): 0.053092
# 	 partial train loss (single batch): 0.053084
# 	 partial train loss (single batch): 0.053534
# 	 partial train loss (single batch): 0.053073
# 	 partial train loss (single batch): 0.053282
# 	 partial train loss (single batch): 0.052754
# 	 partial train loss (single batch): 0.052900
# 	 partial train loss (single batch): 0.053351
# 	 partial train loss (single batch): 0.053959
# 	 partial train loss (single batch): 0.053027
# 	 partial train loss (single batch): 0.054341
# 	 partial train loss (single batch): 0.053206
# 	 partial train loss (single batch): 0.053100
# 	 partial train loss (single batch): 0.052366
# 	 partial train loss (single batch): 0.053716
# 	 partial train loss (single batch): 0.053146
# 	 partial train loss (single batch): 0.052272
# 	 partial train loss (single batch): 0.053616
# 	 partial train loss (single batch): 0.053401
# 	 partial train loss (single batch): 0.052727
# 	 partial train loss (single batch): 0.053105
# 	 partial train loss (single batch): 0.052013
# 	 partial train loss (single batch): 0.053297
# 	 partial train loss (single batch): 0.053731
# 	 partial train loss (single batch): 0.051846
# 	 partial train loss (single batch): 0.052694
# 	 partial train loss (single batch): 0.051963
# 	 partial train loss (single batch): 0.052949
# 	 partial train loss (single batch): 0.053430
# 	 partial train loss (single batch): 0.051983
# 	 partial train loss (single batch): 0.053839
# 	 partial train loss (single batch): 0.053052
# 	 partial train loss (single batch): 0.053608
# 	 partial train loss (single batch): 0.052980
# 	 partial train loss (single batch): 0.052971
# 	 partial train loss (single batch): 0.053694
# 	 partial train loss (single batch): 0.052938
# 	 partial train loss (single batch): 0.053673
# 	 partial train loss (single batch): 0.052573
# 	 partial train loss (single batch): 0.054151
# 	 partial train loss (single batch): 0.052620
# 	 partial train loss (single batch): 0.052126
# 	 partial train loss (single batch): 0.052757
# 	 partial train loss (single batch): 0.052119
# 	 partial train loss (single batch): 0.052553
# 	 partial train loss (single batch): 0.053329
# 	 partial train loss (single batch): 0.052978
# 	 partial train loss (single batch): 0.052604
# 	 partial train loss (single batch): 0.053226
# 	 partial train loss (single batch): 0.052551
# 	 partial train loss (single batch): 0.053755
# 	 partial train loss (single batch): 0.053427
# 	 partial train loss (single batch): 0.052906
# 	 partial train loss (single batch): 0.052939
# 	 partial train loss (single batch): 0.052993
# 	 partial train loss (single batch): 0.053010
# 	 partial train loss (single batch): 0.052867
# 	 partial train loss (single batch): 0.050888
# 	 partial train loss (single batch): 0.053031
# 	 partial train loss (single batch): 0.053486
# 	 partial train loss (single batch): 0.052418
# 	 partial train loss (single batch): 0.051887
# 	 partial train loss (single batch): 0.053863
# 	 partial train loss (single batch): 0.052697
# 	 partial train loss (single batch): 0.053911
# 	 partial train loss (single batch): 0.052758
# 	 partial train loss (single batch): 0.053470
# 	 partial train loss (single batch): 0.052219
# 	 partial train loss (single batch): 0.052822
# 	 partial train loss (single batch): 0.053757
# 	 partial train loss (single batch): 0.052998
# 	 partial train loss (single batch): 0.054728
# 	 partial train loss (single batch): 0.054528
# 	 partial train loss (single batch): 0.052510
# 	 partial train loss (single batch): 0.052267
# 	 partial train loss (single batch): 0.053015
# 	 partial train loss (single batch): 0.053552
# 	 partial train loss (single batch): 0.052433
# 	 partial train loss (single batch): 0.053622
# 	 partial train loss (single batch): 0.053248
# 	 partial train loss (single batch): 0.053209
# 	 partial train loss (single batch): 0.052997
# 	 partial train loss (single batch): 0.052837
# 	 partial train loss (single batch): 0.052083
# 	 partial train loss (single batch): 0.053208
# 	 partial train loss (single batch): 0.053077
# 	 partial train loss (single batch): 0.052930
# 	 partial train loss (single batch): 0.053437
# 	 partial train loss (single batch): 0.053156
# 	 partial train loss (single batch): 0.052645
# 	 partial train loss (single batch): 0.051541
# 	 partial train loss (single batch): 0.052140
# 	 partial train loss (single batch): 0.053005
# 	 partial train loss (single batch): 0.052900
# 	 partial train loss (single batch): 0.052973
# 	 partial train loss (single batch): 0.053604
# 	 partial train loss (single batch): 0.052087
# 	 partial train loss (single batch): 0.051764
# 	 partial train loss (single batch): 0.052981
# 	 partial train loss (single batch): 0.052996
# 	 partial train loss (single batch): 0.053230
# 	 partial train loss (single batch): 0.053404
# 	 partial train loss (single batch): 0.052358
# 	 partial train loss (single batch): 0.054074
# 	 partial train loss (single batch): 0.053273
# 	 partial train loss (single batch): 0.052125
# 	 partial train loss (single batch): 0.051942
# 	 partial train loss (single batch): 0.052830
# 	 partial train loss (single batch): 0.052393
# 	 partial train loss (single batch): 0.052897
# 	 partial train loss (single batch): 0.053226
# 	 partial train loss (single batch): 0.052933
# 	 partial train loss (single batch): 0.052574
# 	 partial train loss (single batch): 0.051722
# 	 partial train loss (single batch): 0.052626
# 	 partial train loss (single batch): 0.053297
# 	 partial train loss (single batch): 0.052646
# 	 partial train loss (single batch): 0.053851
# 	 partial train loss (single batch): 0.053631
# 	 partial train loss (single batch): 0.053411
# 	 partial train loss (single batch): 0.052829
# 	 partial train loss (single batch): 0.052415
# 	 partial train loss (single batch): 0.053292
# 	 partial train loss (single batch): 0.052709
# 	 partial train loss (single batch): 0.052970
# 	 partial train loss (single batch): 0.052027
# 	 partial train loss (single batch): 0.052537
# 	 partial train loss (single batch): 0.053912
# 	 partial train loss (single batch): 0.053654
# 	 partial train loss (single batch): 0.052223
# 	 partial train loss (single batch): 0.053147
# 	 partial train loss (single batch): 0.052815
# 	 partial train loss (single batch): 0.053288
# 	 partial train loss (single batch): 0.052867
# 	 partial train loss (single batch): 0.051972
# 	 partial train loss (single batch): 0.053301
# 	 partial train loss (single batch): 0.051729
# 	 partial train loss (single batch): 0.053001
# 	 partial train loss (single batch): 0.053434
#
#  EPOCH 5/30 	 train loss 0.053 	 val loss 0.043
# EPOCH 6/30
# 	 partial train loss (single batch): 0.052485
# 	 partial train loss (single batch): 0.052992
# 	 partial train loss (single batch): 0.053095
# 	 partial train loss (single batch): 0.052446
# 	 partial train loss (single batch): 0.052216
# 	 partial train loss (single batch): 0.052589
# 	 partial train loss (single batch): 0.052547
# 	 partial train loss (single batch): 0.052635
# 	 partial train loss (single batch): 0.051650
# 	 partial train loss (single batch): 0.053067
# 	 partial train loss (single batch): 0.051941
# 	 partial train loss (single batch): 0.053493
# 	 partial train loss (single batch): 0.052619
# 	 partial train loss (single batch): 0.052581
# 	 partial train loss (single batch): 0.052461
# 	 partial train loss (single batch): 0.052501
# 	 partial train loss (single batch): 0.052745
# 	 partial train loss (single batch): 0.052274
# 	 partial train loss (single batch): 0.053257
# 	 partial train loss (single batch): 0.052691
# 	 partial train loss (single batch): 0.052642
# 	 partial train loss (single batch): 0.052614
# 	 partial train loss (single batch): 0.052982
# 	 partial train loss (single batch): 0.052151
# 	 partial train loss (single batch): 0.051831
# 	 partial train loss (single batch): 0.052645
# 	 partial train loss (single batch): 0.052865
# 	 partial train loss (single batch): 0.051892
# 	 partial train loss (single batch): 0.051598
# 	 partial train loss (single batch): 0.052263
# 	 partial train loss (single batch): 0.051755
# 	 partial train loss (single batch): 0.052664
# 	 partial train loss (single batch): 0.052940
# 	 partial train loss (single batch): 0.052772
# 	 partial train loss (single batch): 0.051825
# 	 partial train loss (single batch): 0.052485
# 	 partial train loss (single batch): 0.052979
# 	 partial train loss (single batch): 0.051737
# 	 partial train loss (single batch): 0.052979
# 	 partial train loss (single batch): 0.051634
# 	 partial train loss (single batch): 0.051251
# 	 partial train loss (single batch): 0.052455
# 	 partial train loss (single batch): 0.052858
# 	 partial train loss (single batch): 0.052100
# 	 partial train loss (single batch): 0.052916
# 	 partial train loss (single batch): 0.051868
# 	 partial train loss (single batch): 0.052469
# 	 partial train loss (single batch): 0.051580
# 	 partial train loss (single batch): 0.052039
# 	 partial train loss (single batch): 0.052843
# 	 partial train loss (single batch): 0.052451
# 	 partial train loss (single batch): 0.052475
# 	 partial train loss (single batch): 0.052059
# 	 partial train loss (single batch): 0.052090
# 	 partial train loss (single batch): 0.051943
# 	 partial train loss (single batch): 0.052196
# 	 partial train loss (single batch): 0.052415
# 	 partial train loss (single batch): 0.052897
# 	 partial train loss (single batch): 0.052697
# 	 partial train loss (single batch): 0.053658
# 	 partial train loss (single batch): 0.052196
# 	 partial train loss (single batch): 0.052927
# 	 partial train loss (single batch): 0.051994
# 	 partial train loss (single batch): 0.052992
# 	 partial train loss (single batch): 0.052944
# 	 partial train loss (single batch): 0.051737
# 	 partial train loss (single batch): 0.053096
# 	 partial train loss (single batch): 0.052686
# 	 partial train loss (single batch): 0.051835
# 	 partial train loss (single batch): 0.052404
# 	 partial train loss (single batch): 0.051319
# 	 partial train loss (single batch): 0.053142
# 	 partial train loss (single batch): 0.052696
# 	 partial train loss (single batch): 0.051142
# 	 partial train loss (single batch): 0.051827
# 	 partial train loss (single batch): 0.051812
# 	 partial train loss (single batch): 0.052252
# 	 partial train loss (single batch): 0.052663
# 	 partial train loss (single batch): 0.051752
# 	 partial train loss (single batch): 0.053186
# 	 partial train loss (single batch): 0.052516
# 	 partial train loss (single batch): 0.052749
# 	 partial train loss (single batch): 0.052255
# 	 partial train loss (single batch): 0.052164
# 	 partial train loss (single batch): 0.052954
# 	 partial train loss (single batch): 0.052351
# 	 partial train loss (single batch): 0.052425
# 	 partial train loss (single batch): 0.052077
# 	 partial train loss (single batch): 0.054001
# 	 partial train loss (single batch): 0.052157
# 	 partial train loss (single batch): 0.051387
# 	 partial train loss (single batch): 0.052106
# 	 partial train loss (single batch): 0.051625
# 	 partial train loss (single batch): 0.051780
# 	 partial train loss (single batch): 0.053021
# 	 partial train loss (single batch): 0.052481
# ...
# 	 partial train loss (single batch): 0.049136
# 	 partial train loss (single batch): 0.049676
# 	 partial train loss (single batch): 0.049527
# 	 partial train loss (single batch): 0.049234
# 	 partial train loss (single batch): 0.049218
# 	 partial train loss (single batch): 0.050045
# 	 partial train loss (single batch): 0.048941
# 	 partial train loss (single batch): 0.050018
# 	 partial train loss (single batch): 0.048741
# 	 partial train loss (single batch): 0.048360
# 	 partial train loss (single batch): 0.049004
# 	 partial train loss (single batch): 0.050019
# 	 partial train loss (single batch): 0.048821
# 	 partial train loss (single batch): 0.049858
# 	 partial train loss (single batch): 0.049090
# 	 partial train loss (single batch): 0.049390
# 	 partial train loss (single batch): 0.048505
# 	 partial train loss (single batch): 0.049241
# 	 partial train loss (single batch): 0.049061
# 	 partial train loss (single batch): 0.049521
# 	 partial train loss (single batch): 0.049627
# 	 partial train loss (single batch): 0.049242
# 	 partial train loss (single batch): 0.049106
# 	 partial train loss (single batch): 0.049327
# 	 partial train loss (single batch): 0.048538
# 	 partial train loss (single batch): 0.049684
# 	 partial train loss (single batch): 0.049372
# 	 partial train loss (single batch): 0.049372
# 	 partial train loss (single batch): 0.050401
# 	 partial train loss (single batch): 0.049708
# 	 partial train loss (single batch): 0.049311
# 	 partial train loss (single batch): 0.048805
# 	 partial train loss (single batch): 0.050466
# 	 partial train loss (single batch): 0.049895
# 	 partial train loss (single batch): 0.048642
# 	 partial train loss (single batch): 0.050014
# 	 partial train loss (single batch): 0.049516
# 	 partial train loss (single batch): 0.049280
# 	 partial train loss (single batch): 0.049311
# 	 partial train loss (single batch): 0.048527
# 	 partial train loss (single batch): 0.049797
# 	 partial train loss (single batch): 0.049820
# 	 partial train loss (single batch): 0.048065
# 	 partial train loss (single batch): 0.049202
# 	 partial train loss (single batch): 0.049248
# 	 partial train loss (single batch): 0.049354
# 	 partial train loss (single batch): 0.049749
# 	 partial train loss (single batch): 0.048635
# 	 partial train loss (single batch): 0.050336
# 	 partial train loss (single batch): 0.049448
# 	 partial train loss (single batch): 0.050683
# 	 partial train loss (single batch): 0.049514
# 	 partial train loss (single batch): 0.049035
# 	 partial train loss (single batch): 0.050122
# 	 partial train loss (single batch): 0.049447
# 	 partial train loss (single batch): 0.049840
# 	 partial train loss (single batch): 0.048944
# 	 partial train loss (single batch): 0.050610
# 	 partial train loss (single batch): 0.049178
# 	 partial train loss (single batch): 0.048822
# 	 partial train loss (single batch): 0.049496
# 	 partial train loss (single batch): 0.049261
# 	 partial train loss (single batch): 0.049547
# 	 partial train loss (single batch): 0.049885
# 	 partial train loss (single batch): 0.048898
# 	 partial train loss (single batch): 0.049245
# 	 partial train loss (single batch): 0.049484
# 	 partial train loss (single batch): 0.049376
# 	 partial train loss (single batch): 0.050052
# 	 partial train loss (single batch): 0.049752
# 	 partial train loss (single batch): 0.049068
# 	 partial train loss (single batch): 0.049724
# 	 partial train loss (single batch): 0.049919
# 	 partial train loss (single batch): 0.050010
# 	 partial train loss (single batch): 0.049303
# 	 partial train loss (single batch): 0.047700
# 	 partial train loss (single batch): 0.049821
# 	 partial train loss (single batch): 0.049420
# 	 partial train loss (single batch): 0.048910
# 	 partial train loss (single batch): 0.048452
# 	 partial train loss (single batch): 0.050513
# 	 partial train loss (single batch): 0.049170
# 	 partial train loss (single batch): 0.050452
# 	 partial train loss (single batch): 0.049346
# 	 partial train loss (single batch): 0.049877
# 	 partial train loss (single batch): 0.049092
# 	 partial train loss (single batch): 0.049468
# 	 partial train loss (single batch): 0.050266
# 	 partial train loss (single batch): 0.049588
# 	 partial train loss (single batch): 0.051244
# 	 partial train loss (single batch): 0.050743
# 	 partial train loss (single batch): 0.049452
# 	 partial train loss (single batch): 0.049427
# 	 partial train loss (single batch): 0.049388
# 	 partial train loss (single batch): 0.050280
# 	 partial train loss (single batch): 0.049838
# 	 partial train loss (single batch): 0.049986
# 	 partial train loss (single batch): 0.049946
# 	 partial train loss (single batch): 0.049722
# 	 partial train loss (single batch): 0.049123
# 	 partial train loss (single batch): 0.049588
# 	 partial train loss (single batch): 0.049508
# 	 partial train loss (single batch): 0.049339
# 	 partial train loss (single batch): 0.049480
# 	 partial train loss (single batch): 0.049600
# 	 partial train loss (single batch): 0.050072
# 	 partial train loss (single batch): 0.050163
# 	 partial train loss (single batch): 0.049737
# 	 partial train loss (single batch): 0.048163
# 	 partial train loss (single batch): 0.049026
# 	 partial train loss (single batch): 0.049392
# 	 partial train loss (single batch): 0.049598
# 	 partial train loss (single batch): 0.049165
# 	 partial train loss (single batch): 0.050175
# 	 partial train loss (single batch): 0.048412
# 	 partial train loss (single batch): 0.048882
# 	 partial train loss (single batch): 0.049512
# 	 partial train loss (single batch): 0.049404
# 	 partial train loss (single batch): 0.050116
# 	 partial train loss (single batch): 0.050171
# 	 partial train loss (single batch): 0.048997
# 	 partial train loss (single batch): 0.050395
# 	 partial train loss (single batch): 0.049730
# 	 partial train loss (single batch): 0.049413
# 	 partial train loss (single batch): 0.049108
# 	 partial train loss (single batch): 0.049744
# 	 partial train loss (single batch): 0.049433
# 	 partial train loss (single batch): 0.049590
# 	 partial train loss (single batch): 0.050008
# 	 partial train loss (single batch): 0.050134
# 	 partial train loss (single batch): 0.050049
# 	 partial train loss (single batch): 0.048953
# 	 partial train loss (single batch): 0.049304
# 	 partial train loss (single batch): 0.049818
# 	 partial train loss (single batch): 0.049487
# 	 partial train loss (single batch): 0.049993
# 	 partial train loss (single batch): 0.050572
# 	 partial train loss (single batch): 0.049957
# 	 partial train loss (single batch): 0.049720
# 	 partial train loss (single batch): 0.049501
# 	 partial train loss (single batch): 0.050505
# 	 partial train loss (single batch): 0.049563
# 	 partial train loss (single batch): 0.049847
# 	 partial train loss (single batch): 0.048889
# 	 partial train loss (single batch): 0.049687
# 	 partial train loss (single batch): 0.050812
# 	 partial train loss (single batch): 0.049948
# 	 partial train loss (single batch): 0.048729
# 	 partial train loss (single batch): 0.050332
# 	 partial train loss (single batch): 0.049611
# 	 partial train loss (single batch): 0.049998
# 	 partial train loss (single batch): 0.049524
# 	 partial train loss (single batch): 0.048930
# 	 partial train loss (single batch): 0.049675
# 	 partial train loss (single batch): 0.049017
# 	 partial train loss (single batch): 0.049400
# 	 partial train loss (single batch): 0.050496
#
#  EPOCH 29/30 	 train loss 0.050 	 val loss 0.038
# EPOCH 30/30
# 	 partial train loss (single batch): 0.049295
# 	 partial train loss (single batch): 0.050164
# 	 partial train loss (single batch): 0.050050
# 	 partial train loss (single batch): 0.049197
# 	 partial train loss (single batch): 0.049272
# 	 partial train loss (single batch): 0.049345
# 	 partial train loss (single batch): 0.049732
# 	 partial train loss (single batch): 0.049701
# 	 partial train loss (single batch): 0.048361
# 	 partial train loss (single batch): 0.049977
# 	 partial train loss (single batch): 0.049729
# 	 partial train loss (single batch): 0.050464
# 	 partial train loss (single batch): 0.049617
# 	 partial train loss (single batch): 0.049750
# 	 partial train loss (single batch): 0.049646
# 	 partial train loss (single batch): 0.048771
# 	 partial train loss (single batch): 0.049605
# 	 partial train loss (single batch): 0.049457
# 	 partial train loss (single batch): 0.050041
# 	 partial train loss (single batch): 0.049166
# 	 partial train loss (single batch): 0.049976
# 	 partial train loss (single batch): 0.050017
# 	 partial train loss (single batch): 0.049727
# 	 partial train loss (single batch): 0.048936
# 	 partial train loss (single batch): 0.049165
# 	 partial train loss (single batch): 0.049965
# 	 partial train loss (single batch): 0.049646
# 	 partial train loss (single batch): 0.048850
# 	 partial train loss (single batch): 0.048414
# 	 partial train loss (single batch): 0.049091
# 	 partial train loss (single batch): 0.049322
# 	 partial train loss (single batch): 0.048756
# 	 partial train loss (single batch): 0.049860
# 	 partial train loss (single batch): 0.049368
# 	 partial train loss (single batch): 0.049328
# 	 partial train loss (single batch): 0.048743
# 	 partial train loss (single batch): 0.049949
# 	 partial train loss (single batch): 0.049152
# 	 partial train loss (single batch): 0.050285
# 	 partial train loss (single batch): 0.049007
# 	 partial train loss (single batch): 0.048438
# 	 partial train loss (single batch): 0.049062
# 	 partial train loss (single batch): 0.049997
# 	 partial train loss (single batch): 0.048858
# 	 partial train loss (single batch): 0.049943
# 	 partial train loss (single batch): 0.049084
# 	 partial train loss (single batch): 0.049078
# 	 partial train loss (single batch): 0.048879
# 	 partial train loss (single batch): 0.049300
# 	 partial train loss (single batch): 0.049383
# 	 partial train loss (single batch): 0.049762
# 	 partial train loss (single batch): 0.049545
# 	 partial train loss (single batch): 0.049292
# 	 partial train loss (single batch): 0.049269
# 	 partial train loss (single batch): 0.048821
# 	 partial train loss (single batch): 0.048961
# 	 partial train loss (single batch): 0.049715
# 	 partial train loss (single batch): 0.049955
# 	 partial train loss (single batch): 0.049328
# 	 partial train loss (single batch): 0.050137
# 	 partial train loss (single batch): 0.049713
# 	 partial train loss (single batch): 0.049328
# 	 partial train loss (single batch): 0.048913
# 	 partial train loss (single batch): 0.050031
# 	 partial train loss (single batch): 0.049908
# 	 partial train loss (single batch): 0.049251
# 	 partial train loss (single batch): 0.050217
# 	 partial train loss (single batch): 0.049543
# 	 partial train loss (single batch): 0.049206
# 	 partial train loss (single batch): 0.049289
# 	 partial train loss (single batch): 0.048397
# 	 partial train loss (single batch): 0.050519
# 	 partial train loss (single batch): 0.049682
# 	 partial train loss (single batch): 0.048467
# 	 partial train loss (single batch): 0.049230
# 	 partial train loss (single batch): 0.049203
# 	 partial train loss (single batch): 0.049403
# 	 partial train loss (single batch): 0.049649
# 	 partial train loss (single batch): 0.048444
# 	 partial train loss (single batch): 0.050186
# 	 partial train loss (single batch): 0.048835
# 	 partial train loss (single batch): 0.050799
# 	 partial train loss (single batch): 0.049347
# 	 partial train loss (single batch): 0.049462
# 	 partial train loss (single batch): 0.049441
# 	 partial train loss (single batch): 0.049966
# 	 partial train loss (single batch): 0.049786
# 	 partial train loss (single batch): 0.049046
# 	 partial train loss (single batch): 0.050612
# 	 partial train loss (single batch): 0.049442
# 	 partial train loss (single batch): 0.048862
# 	 partial train loss (single batch): 0.049900
# 	 partial train loss (single batch): 0.049060
# 	 partial train loss (single batch): 0.049470
# 	 partial train loss (single batch): 0.049972
# 	 partial train loss (single batch): 0.048777
# 	 partial train loss (single batch): 0.049195
# 	 partial train loss (single batch): 0.049550
# 	 partial train loss (single batch): 0.049419
# 	 partial train loss (single batch): 0.049901
# 	 partial train loss (single batch): 0.049736
# 	 partial train loss (single batch): 0.049133
# 	 partial train loss (single batch): 0.049565
# 	 partial train loss (single batch): 0.049461
# 	 partial train loss (single batch): 0.049643
# 	 partial train loss (single batch): 0.049267
# 	 partial train loss (single batch): 0.047407
# 	 partial train loss (single batch): 0.049784
# 	 partial train loss (single batch): 0.049626
# 	 partial train loss (single batch): 0.049236
# 	 partial train loss (single batch): 0.048235
# 	 partial train loss (single batch): 0.050650
# 	 partial train loss (single batch): 0.049568
# 	 partial train loss (single batch): 0.050042
# 	 partial train loss (single batch): 0.049520
# 	 partial train loss (single batch): 0.049878
# 	 partial train loss (single batch): 0.049110
# 	 partial train loss (single batch): 0.049615
# 	 partial train loss (single batch): 0.050264
# 	 partial train loss (single batch): 0.049431
# 	 partial train loss (single batch): 0.051165
# 	 partial train loss (single batch): 0.050877
# 	 partial train loss (single batch): 0.049152
# 	 partial train loss (single batch): 0.049251
# 	 partial train loss (single batch): 0.049342
# 	 partial train loss (single batch): 0.049984
# 	 partial train loss (single batch): 0.049598
# 	 partial train loss (single batch): 0.049948
# 	 partial train loss (single batch): 0.049847
# 	 partial train loss (single batch): 0.049811
# 	 partial train loss (single batch): 0.049337
# 	 partial train loss (single batch): 0.049413
# 	 partial train loss (single batch): 0.049409
# 	 partial train loss (single batch): 0.049613
# 	 partial train loss (single batch): 0.049564
# 	 partial train loss (single batch): 0.049782
# 	 partial train loss (single batch): 0.050127
# 	 partial train loss (single batch): 0.050031
# 	 partial train loss (single batch): 0.049311
# 	 partial train loss (single batch): 0.048212
# 	 partial train loss (single batch): 0.048554
# 	 partial train loss (single batch): 0.049829
# 	 partial train loss (single batch): 0.049612
# 	 partial train loss (single batch): 0.048841
# 	 partial train loss (single batch): 0.050136
# 	 partial train loss (single batch): 0.048308
# 	 partial train loss (single batch): 0.048883
# 	 partial train loss (single batch): 0.049758
# 	 partial train loss (single batch): 0.049533
# 	 partial train loss (single batch): 0.050156
# 	 partial train loss (single batch): 0.050009
# 	 partial train loss (single batch): 0.049387
# 	 partial train loss (single batch): 0.050434
# 	 partial train loss (single batch): 0.049645
# 	 partial train loss (single batch): 0.049279
# 	 partial train loss (single batch): 0.049089
# 	 partial train loss (single batch): 0.049568
# 	 partial train loss (single batch): 0.049048
# 	 partial train loss (single batch): 0.049551
# 	 partial train loss (single batch): 0.050342
# 	 partial train loss (single batch): 0.050152
# 	 partial train loss (single batch): 0.049721
# 	 partial train loss (single batch): 0.049182
# 	 partial train loss (single batch): 0.049125
# 	 partial train loss (single batch): 0.049901
# 	 partial train loss (single batch): 0.049807
# 	 partial train loss (single batch): 0.049990
# 	 partial train loss (single batch): 0.050384
# 	 partial train loss (single batch): 0.049950
# 	 partial train loss (single batch): 0.049906
# 	 partial train loss (single batch): 0.049377
# 	 partial train loss (single batch): 0.050662
# 	 partial train loss (single batch): 0.050066
# 	 partial train loss (single batch): 0.049747
# 	 partial train loss (single batch): 0.048590
# 	 partial train loss (single batch): 0.049591
# 	 partial train loss (single batch): 0.050775
# 	 partial train loss (single batch): 0.049790
# 	 partial train loss (single batch): 0.049110
# 	 partial train loss (single batch): 0.050324
# 	 partial train loss (single batch): 0.049508
# 	 partial train loss (single batch): 0.050080
# 	 partial train loss (single batch): 0.049489
# 	 partial train loss (single batch): 0.048660
# 	 partial train loss (single batch): 0.049846
# 	 partial train loss (single batch): 0.048794
# 	 partial train loss (single batch): 0.049871
# 	 partial train loss (single batch): 0.050266
#
#  EPOCH 30/30 	 train loss 0.050 	 val loss 0.038

# %%
# Plot training performance
test_epoch_den(encoder,decoder,device,test_loader,loss_fn).item()# Plot losses
plt.figure(figsize=(10,8))
plt.semilogy(history_da['train_loss'], label='Train')
plt.semilogy(history_da['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 4 Visualize latent space

# %%
def plot_results(encoder, decoder, data, rx=(-5, 5), ry=(-5, 5), model_name='VAE'):

    # Encode all data samples
    encoded_samples = []
    for sample in tqdm(data):
        
        # Separate image data from its label 
        img = sample[0].unsqueeze(0).to(device)
        label = sample[1]
        
        # Encode image
        encoder.eval()
        with torch.no_grad():
            encoded_img  = encoder(img)
        
        # Append to list
        encoded_img = encoded_img.flatten().cpu().numpy()
        encoded_sample = {f"Enc. Variable {i}": enc for i, enc in enumerate(encoded_img)}
        encoded_sample['label'] = label
        encoded_samples.append(encoded_sample)
        
        # Find latend dimension from decoded image
        latent_dim = len(encoded_img)
        
    encoded_samples = pd.DataFrame(encoded_samples)

    # Create a TSNE model and plot it
    tsne = TSNE(n_components=2)
    tsne_results = tsne.fit_transform(encoded_samples.drop(['label'],axis=1))
    
    plt.figure(figsize=(17, 9))
    plt.scatter(tsne_results[:,0], tsne_results[:,1], c=encoded_samples.label, cmap='tab10', s=3)
    plt.xlabel('tsne-2d-one')
    plt.ylabel('tsne-2d-two')
    plt.title(f'Digit separation produced by {model_name}')
    plt.colorbar()
    plt.show()
    
    # Prepare a n x n 2D matrix of digits
    n = 30
    digit_size = 28
    figure = np.zeros((digit_size * n, digit_size * n))
    
    # Create a linearly spaced coordinates of 2D digit classes in latent space
    grid_x = np.linspace(*rx, n)
    grid_y = np.linspace(*ry, n)[::-1]

    # Populate the matrix with images decoded from latent space
    for i, yi in enumerate(grid_y):
        for j, xj in enumerate(grid_x):
            # coords = [xj, yi, 0, 0] # Use latent_dim
            coords = list(np.zeros(latent_dim))
            coords[0] = xj
            coords[1] = yi
            z = torch.Tensor([coords]).to(device)
            x_hat = decoder(z)
            digit = x_hat.reshape(digit_size, digit_size).to('cpu').detach().numpy()
            figure[i * digit_size: (i + 1) * digit_size,
                   j * digit_size: (j + 1) * digit_size] = digit

    # Plot the matrix of "fake" sample digits
    plt.figure(figsize=(8, 8))
    start_range = digit_size // 2
    end_range = (n - 1) * digit_size + start_range + 1
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.title(f'Sample of digits recovered from {model_name} latent space')
    plt.imshow(figure, cmap='Greys')
    # plt.savefig(filename)
    plt.show()

plot_results(encoder, decoder, test_dataset, rx=(-1, 1), ry=(-1, 1), model_name="Noisy Autoencoder")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:02<00:00, 3918.59it/s]

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.24.1</td></tr><tr><td><code>qiskit-aer</code></td><td>0.12.1</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.20.2</td></tr><tr><td><code>qiskit</code></td><td>0.43.2</td></tr><tr><td><code>qiskit-nature</code></td><td>0.6.2</td></tr><tr><td><code>qiskit-finance</code></td><td>0.3.4</td></tr><tr><td><code>qiskit-optimization</code></td><td>0.5.0</td></tr><tr><td><code>qiskit-machine-learning</code></td><td>0.6.1</td></tr><tr><th>System information</th></tr><tr><td>Python version</td><td>3.9.17</td></tr><tr><td>Python compiler</td><td>GCC 11.2.0</td></tr><tr><td>Python build</td><td>main, Jul  5 2023 20:41:20</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>31.067867279052734</td></tr><tr><td colspan='2'>Sun Jul 16 23:45:35 2023 AEST</td></tr></table>
