# %% [markdown]
# # Demo: Building Denoising Autoencoders in Pytorch (CIFAR10)
#
# By: Jacob Cybulski<br>
# Date: July 2023<br>
# Comment: *Lots of bugs fixed, works with Torch 2, on both CPU and GPU*
#
# Sources:
# <ol>
# <li>Eugenia Anello, Denoising Autoencoder in Pytorch on MNIST dataset, Dataseries (Medium), Jun 28, 2021.</li>
# <li>Eugenia Anello, <a href="https://github.com/eugeniaring/Medium-Articles/blob/main/Pytorch/denAE.ipynb">GitHub</a>, Jun 28, 2021.</li>
# <li>Phillip Lippe, Tutorial 9: Deep Autoencoders, UvA Deep Learning Tutorials, Fall 2022.</li>
# </ol>

# %%
# !pip list | grep torch
# Out:
# torch                         2.0.1+cpu
# torchaudio                    2.0.2+cpu
# torchsummary                  1.5.1
# torchvision                   0.15.2+cpu

# %%
import matplotlib.pyplot as plt
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd # this module is useful to work with tabular data
import random # this module will be used to select random samples from a collection
import os # this module will be used just to create directories in the local filesystem
from tqdm import tqdm # this module is useful to plot progress bars

import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
from torchsummary import summary
import torch.nn.functional as F
import torch.optim as optim
from sklearn.manifold import TSNE

# %% [markdown]
# ## Prelims: Get data and create tensor data loaders

# %%
data_dir = 'dataset'
train_dataset = torchvision.datasets.CIFAR10(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.CIFAR10(data_dir, train=False, download=True)

print('Training data shape:', train_dataset.data.shape)
print('Test data shape:', test_dataset.data.shape)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
fig, axs = plt.subplots(5, 5, figsize=(10,10))
for ax in axs.flatten():
    # random.choice allows to randomly sample from a list-like object (basically anything that can be accessed with an index, like our dataset)
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img))
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
train_transform = transforms.Compose([
    transforms.ToTensor(),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Set the train transform
train_dataset.transform = train_transform

# Set the test transform
test_dataset.transform = test_transform

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)])

batch_size=256

# The dataloaders handle shuffling, batching, etc...
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %% [markdown]
# ## 1 Define Encoder and Decoder classes

# %%
test_dataset.data.shape
# Out:
# (10000, 32, 32, 3)

# %%
# Images are (N, W, H)
B = batch_size                 # Batch size
N = test_dataset.data.shape[0] # Examples
W = test_dataset.data.shape[1] # Width
H = test_dataset.data.shape[2] # Height
C = test_dataset.data.shape[3] # Channels
BC = W                         # Base channels
D = W * H * C                  # Features
classes = 10                   # Label classes

# Input of shape (C, W)

# Filters of shape (C, K)
kernels = 12                   # Number of kernels
K = 3                          # Size of kernels
d = 256                        # Latent dimension

# %%
class Encoder(nn.Module):
    
    def __init__(self, 
                 num_input_channels : int, 
                 base_channel_size : int, 
                 latent_dim : int, 
                 act_fn : object = nn.GELU):
        """
        Inputs: 
            - num_input_channels : Number of input channels of the image. For CIFAR, this parameter is 3
            - base_channel_size : Number of channels we use in the first convolutional layers. Deeper layers might use a duplicate of it.
            - latent_dim : Dimensionality of latent representation z
            - act_fn : Activation function used throughout the encoder network
        """
        super().__init__()
        c_hid = base_channel_size
        self.net = nn.Sequential(
            nn.Conv2d(num_input_channels, c_hid, kernel_size=3, padding=1, stride=2), # 32x32 => 16x16
            act_fn(),
            nn.Conv2d(c_hid, c_hid, kernel_size=3, padding=1),
            act_fn(),
            nn.Conv2d(c_hid, 2*c_hid, kernel_size=3, padding=1, stride=2), # 16x16 => 8x8
            act_fn(),
            nn.Conv2d(2*c_hid, 2*c_hid, kernel_size=3, padding=1),
            act_fn(),
            nn.Conv2d(2*c_hid, 2*c_hid, kernel_size=3, padding=1, stride=2), # 8x8 => 4x4
            act_fn(),
            nn.Flatten(), # Image grid to single feature vector
            nn.Linear(2*16*c_hid, latent_dim)
        )
    
    def forward(self, x):
        return self.net(x)

# %%
class Decoder(nn.Module):
    
    def __init__(self, 
                 num_input_channels : int, 
                 base_channel_size : int, 
                 latent_dim : int, 
                 act_fn : object = nn.GELU):
        """
        Inputs: 
            - num_input_channels : Number of channels of the image to reconstruct. For CIFAR, this parameter is 3
            - base_channel_size : Number of channels we use in the last convolutional layers. Early layers might use a duplicate of it.
            - latent_dim : Dimensionality of latent representation z
            - act_fn : Activation function used throughout the decoder network
        """
        super().__init__()
        c_hid = base_channel_size
        self.linear = nn.Sequential(
            nn.Linear(latent_dim, 2*16*c_hid),
            act_fn()
        )
        self.net = nn.Sequential(
            nn.ConvTranspose2d(2*c_hid, 2*c_hid, kernel_size=3, output_padding=1, padding=1, stride=2), # 4x4 => 8x8
            act_fn(),
            nn.Conv2d(2*c_hid, 2*c_hid, kernel_size=3, padding=1),
            act_fn(),
            nn.ConvTranspose2d(2*c_hid, c_hid, kernel_size=3, output_padding=1, padding=1, stride=2), # 8x8 => 16x16
            act_fn(),
            nn.Conv2d(c_hid, c_hid, kernel_size=3, padding=1),
            act_fn(),
            nn.ConvTranspose2d(c_hid, num_input_channels, kernel_size=3, output_padding=1, padding=1, stride=2), # 16x16 => 32x32
            nn.Tanh() # The input images is scaled between -1 and 1, hence the output has to be bounded as well
        )
    
    def forward(self, x):
        x = self.linear(x)
        x = x.reshape(x.shape[0], -1, 4, 4)
        x = self.net(x)
        return x

# %% [markdown]
# ## 2 initialize models, loss and optimizer
# *Note that "d" is the size of a latent space*

# %%
### Set the random seed for reproducible results
torch.manual_seed(0)

### Initialize the two networks
# encoder = Encoder(encoded_space_dim=d,fc2_input_dim=128)
encoder = Encoder(C, BC, d)
decoder = Decoder(C, BC, d)

# %%
summary(encoder, (C, W, H))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 16, 16]             896
#               GELU-2           [-1, 32, 16, 16]               0
#             Conv2d-3           [-1, 32, 16, 16]           9,248
#               GELU-4           [-1, 32, 16, 16]               0
#             Conv2d-5             [-1, 64, 8, 8]          18,496
#               GELU-6             [-1, 64, 8, 8]               0
#             Conv2d-7             [-1, 64, 8, 8]          36,928
#               GELU-8             [-1, 64, 8, 8]               0
#             Conv2d-9             [-1, 64, 4, 4]          36,928
#              GELU-10             [-1, 64, 4, 4]               0
#           Flatten-11                 [-1, 1024]               0
#            Linear-12                  [-1, 256]         262,400
# ================================================================
# Total params: 364,896
# Trainable params: 364,896
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.40
# Params size (MB): 1.39
# Estimated Total Size (MB): 1.80
# ----------------------------------------------------------------

# %%
### Define the loss function
loss_fn = torch.nn.MSELoss()

### Define an optimizer (both for the encoder and the decoder!)
lr= 0.001 # Learning rate


params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

optim = torch.optim.Adam(params_to_optimize, lr=lr)

# Move both the encoder and the decoder to the selected device
encoder.to(device)
decoder.to(device)
print(encoder)
print(decoder)
# Out:
# Selected device: cpu
# Encoder(
#   (net): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): GELU(approximate='none')
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): GELU(approximate='none')
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): GELU(approximate='none')
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): GELU(approximate='none')
#     (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (9): GELU(approximate='none')
#     (10): Flatten(start_dim=1, end_dim=-1)
#     (11): Linear(in_features=1024, out_features=256, bias=True)
#   )
# )
# Decoder(
#   (linear): Sequential(
#     (0): Linear(in_features=256, out_features=1024, bias=True)
#     (1): GELU(approximate='none')
#   )
#   (net): Sequential(
#     (0): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): GELU(approximate='none')
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): GELU(approximate='none')
#     (4): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (5): GELU(approximate='none')
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): GELU(approximate='none')
#     (8): ConvTranspose2d(32, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (9): Tanh()
#   )
# )

# %% [markdown]
# ## 3 Train model

# %%
im = test_dataset[0][0].unsqueeze(0)
a = im + torch.randn_like(im)*0.3
print(a)
# Out:
# tensor([[[[ 1.0375, -0.0116,  0.7286,  ..., -0.0842,  0.0397, -0.1588],
#           [ 0.2882,  0.3894,  0.4410,  ...,  0.7752,  0.7680,  0.1383],
#           [ 0.6423,  0.8301,  0.5576,  ...,  0.8912,  0.3900,  0.5280],
#           ...,
#           [-0.1048,  0.3528,  0.4401,  ...,  0.0363,  0.0886,  0.1694],
#           [ 0.2688,  0.3059, -0.2780,  ...,  0.2084,  0.4330, -0.0546],
#           [ 0.7676,  0.6820,  0.0276,  ..., -0.0169,  0.3940,  0.1158]],
#
#          [[ 0.5710,  0.5936,  0.3155,  ..., -0.3224,  0.2479,  0.5240],
#           [ 0.7533,  0.8610,  0.9392,  ...,  0.7438,  0.7241,  0.0382],
#           [ 1.0142,  0.3999,  0.1086,  ...,  0.4331,  0.0145,  0.1561],
#           ...,
#           [ 0.1511,  0.0333,  0.3207,  ...,  0.2895,  0.2425,  0.4365],
#           [ 0.3960,  0.5389,  0.5022,  ...,  0.7697,  0.0950,  0.3148],
#           [ 0.3126,  0.0440,  0.0126,  ...,  0.6296,  0.3453,  0.1175]],
#
#          [[-0.0458,  0.5102,  0.1012,  ...,  0.3878,  0.2135, -0.2497],
#           [-0.3645,  0.3492, -0.0895,  ...,  0.0058,  0.7263,  0.1949],
#           [ 0.5656,  0.2348, -0.1335,  ...,  0.2100,  0.0928,  0.0636],
#           ...,
#           [ 0.3605,  0.5306,  0.5712,  ...,  0.9414,  0.5369,  0.6201],
#           [ 0.5338,  0.6285,  0.4013,  ...,  0.5584, -0.0333,  0.7504],
#           [ 0.6610, -0.1525,  0.0669,  ...,  0.3030,  0.5495,  0.3651]]]])

# %%
b = torch.clip(a,0.,1.)
print(b)
# Out:
# tensor([[[[1.0000, 0.0000, 0.7286,  ..., 0.0000, 0.0397, 0.0000],
#           [0.2882, 0.3894, 0.4410,  ..., 0.7752, 0.7680, 0.1383],
#           [0.6423, 0.8301, 0.5576,  ..., 0.8912, 0.3900, 0.5280],
#           ...,
#           [0.0000, 0.3528, 0.4401,  ..., 0.0363, 0.0886, 0.1694],
#           [0.2688, 0.3059, 0.0000,  ..., 0.2084, 0.4330, 0.0000],
#           [0.7676, 0.6820, 0.0276,  ..., 0.0000, 0.3940, 0.1158]],
#
#          [[0.5710, 0.5936, 0.3155,  ..., 0.0000, 0.2479, 0.5240],
#           [0.7533, 0.8610, 0.9392,  ..., 0.7438, 0.7241, 0.0382],
#           [1.0000, 0.3999, 0.1086,  ..., 0.4331, 0.0145, 0.1561],
#           ...,
#           [0.1511, 0.0333, 0.3207,  ..., 0.2895, 0.2425, 0.4365],
#           [0.3960, 0.5389, 0.5022,  ..., 0.7697, 0.0950, 0.3148],
#           [0.3126, 0.0440, 0.0126,  ..., 0.6296, 0.3453, 0.1175]],
#
#          [[0.0000, 0.5102, 0.1012,  ..., 0.3878, 0.2135, 0.0000],
#           [0.0000, 0.3492, 0.0000,  ..., 0.0058, 0.7263, 0.1949],
#           [0.5656, 0.2348, 0.0000,  ..., 0.2100, 0.0928, 0.0636],
#           ...,
#           [0.3605, 0.5306, 0.5712,  ..., 0.9414, 0.5369, 0.6201],
#           [0.5338, 0.6285, 0.4013,  ..., 0.5584, 0.0000, 0.7504],
#           [0.6610, 0.0000, 0.0669,  ..., 0.3030, 0.5495, 0.3651]]]])

# %%
def add_noise(inputs,noise_factor=0.3):
     noise = inputs+torch.randn_like(inputs)*noise_factor
     noise = torch.clip(noise,0.,1.)
     return noise

# %%
### Training function
def train_epoch_den(encoder, decoder, device, dataloader, loss_fn, optimizer, noise_factor=0.3):
    
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader:
        
        # Move tensor to the proper device
        image_noisy = add_noise(image_batch,noise_factor)
        image_noisy = image_noisy.to(device)    
        
        # Encode data
        encoded_data = encoder(image_noisy)
        
        # Decode data
        decoded_data = decoder(encoded_data)
        
        # Evaluate loss
        loss = loss_fn(decoded_data, image_noisy)
        
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Print batch loss
        print('\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)

# %%
### Testing function
def test_epoch_den(encoder, decoder, device, dataloader, loss_fn,noise_factor=0.3):
    
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    
    with torch.no_grad(): # No need to track the gradients
        
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        
        for image_batch, _ in dataloader:
            
            # Move tensor to the proper device
            image_noisy = add_noise(image_batch,noise_factor)
            image_noisy = image_noisy.to(device)
            
            # Encode data
            encoded_data = encoder(image_noisy)
            
            # Decode data
            decoded_data = decoder(encoded_data)
            
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
            
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
        
    return val_loss.data

# %% [markdown]
# **Note that image axes must have been incorrectly assigned in the process of its encoding and decoding, the correction was applied in image plotting**

# %%
def plot_ae_outputs_den(encoder,decoder,n=5,noise_factor=0.3):
    plt.figure(figsize=(10,4.5))
    for i in range(n):

        ax = plt.subplot(3,n,i+1)
        img = test_dataset[i][0].unsqueeze(0)
        image_noisy = add_noise(img,noise_factor)     
        image_noisy = image_noisy.to(device)

        encoder.eval()
        decoder.eval()

        with torch.no_grad():
            rec_img  = decoder(encoder(image_noisy))

        img_sel = img.cpu().squeeze().numpy()
        img_sel = img_sel.swapaxes(0,1)
        img_sel = img_sel.swapaxes(1,2)
        plt.imshow(img_sel, cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Original images')
            
        ax = plt.subplot(3, n, i + 1 + n)
        img_sel = image_noisy.cpu().squeeze().numpy()
        img_sel = img_sel.swapaxes(0,1)
        img_sel = img_sel.swapaxes(1,2)
        plt.imshow(img_sel, cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Corrupted images')

        ax = plt.subplot(3, n, i + 1 + n + n)
        img_sel = rec_img.cpu().squeeze().numpy()
        img_sel = img_sel.swapaxes(0,1)
        img_sel = img_sel.swapaxes(1,2)
        plt.imshow(img_sel, cmap='gist_gray')  
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Reconstructed images')
            
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.7, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)     
    plt.show()

# %%
### Training cycle
noise_factor = 0.3
num_epochs = 30
history_da={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    print('EPOCH %d/%d' % (epoch + 1, num_epochs))
    
    ### Training (use the training function)
    train_loss=train_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=train_loader, 
        loss_fn=loss_fn, 
        optimizer=optim,noise_factor=noise_factor)
    
    ### Validation  (use the testing function)
    val_loss = test_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=valid_loader, 
        loss_fn=loss_fn,noise_factor=noise_factor)
    
    # Print Validationloss
    history_da['train_loss'].append(train_loss)
    history_da['val_loss'].append(val_loss)
    print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
    plot_ae_outputs_den(encoder,decoder,noise_factor=noise_factor)
# Out:
# EPOCH 1/30
# 	 partial train loss (single batch): 0.231807
# 	 partial train loss (single batch): 0.235140
# 	 partial train loss (single batch): 0.220227
# 	 partial train loss (single batch): 0.226253
# 	 partial train loss (single batch): 0.219983
# 	 partial train loss (single batch): 0.208010
# 	 partial train loss (single batch): 0.208934
# 	 partial train loss (single batch): 0.204395
# 	 partial train loss (single batch): 0.194981
# 	 partial train loss (single batch): 0.172408
# 	 partial train loss (single batch): 0.164620
# 	 partial train loss (single batch): 0.167144
# 	 partial train loss (single batch): 0.152909
# 	 partial train loss (single batch): 0.150056
# 	 partial train loss (single batch): 0.144365
# 	 partial train loss (single batch): 0.145724
# 	 partial train loss (single batch): 0.137958
# 	 partial train loss (single batch): 0.131086
# 	 partial train loss (single batch): 0.123899
# 	 partial train loss (single batch): 0.119755
# 	 partial train loss (single batch): 0.117475
# 	 partial train loss (single batch): 0.116401
# 	 partial train loss (single batch): 0.113930
# 	 partial train loss (single batch): 0.112677
# 	 partial train loss (single batch): 0.112065
# 	 partial train loss (single batch): 0.112822
# 	 partial train loss (single batch): 0.112635
# 	 partial train loss (single batch): 0.108835
# 	 partial train loss (single batch): 0.106943
# 	 partial train loss (single batch): 0.110139
# 	 partial train loss (single batch): 0.107549
# 	 partial train loss (single batch): 0.106183
# 	 partial train loss (single batch): 0.107200
# 	 partial train loss (single batch): 0.104342
# 	 partial train loss (single batch): 0.102243
# 	 partial train loss (single batch): 0.103036
# 	 partial train loss (single batch): 0.102201
# 	 partial train loss (single batch): 0.101961
# 	 partial train loss (single batch): 0.100901
# 	 partial train loss (single batch): 0.100064
# 	 partial train loss (single batch): 0.099185
# 	 partial train loss (single batch): 0.098806
# 	 partial train loss (single batch): 0.097438
# 	 partial train loss (single batch): 0.098590
# 	 partial train loss (single batch): 0.096269
# 	 partial train loss (single batch): 0.098939
# 	 partial train loss (single batch): 0.097345
# 	 partial train loss (single batch): 0.095498
# 	 partial train loss (single batch): 0.096440
# 	 partial train loss (single batch): 0.096440
# 	 partial train loss (single batch): 0.096439
# 	 partial train loss (single batch): 0.096144
# 	 partial train loss (single batch): 0.095018
# 	 partial train loss (single batch): 0.094812
# 	 partial train loss (single batch): 0.094011
# 	 partial train loss (single batch): 0.093659
# 	 partial train loss (single batch): 0.093726
# 	 partial train loss (single batch): 0.094232
# 	 partial train loss (single batch): 0.092223
# 	 partial train loss (single batch): 0.093664
# 	 partial train loss (single batch): 0.091683
# 	 partial train loss (single batch): 0.092271
# 	 partial train loss (single batch): 0.091090
# 	 partial train loss (single batch): 0.089307
# 	 partial train loss (single batch): 0.089951
# 	 partial train loss (single batch): 0.090858
# 	 partial train loss (single batch): 0.089624
# 	 partial train loss (single batch): 0.090664
# 	 partial train loss (single batch): 0.090821
# 	 partial train loss (single batch): 0.089025
# 	 partial train loss (single batch): 0.090688
# 	 partial train loss (single batch): 0.089484
# 	 partial train loss (single batch): 0.089721
# 	 partial train loss (single batch): 0.089652
# 	 partial train loss (single batch): 0.088723
# 	 partial train loss (single batch): 0.087762
# 	 partial train loss (single batch): 0.089470
# 	 partial train loss (single batch): 0.088270
# 	 partial train loss (single batch): 0.088235
# 	 partial train loss (single batch): 0.088452
# 	 partial train loss (single batch): 0.087645
# 	 partial train loss (single batch): 0.087402
# 	 partial train loss (single batch): 0.087222
# 	 partial train loss (single batch): 0.087494
# 	 partial train loss (single batch): 0.087275
# 	 partial train loss (single batch): 0.087721
# 	 partial train loss (single batch): 0.086635
# 	 partial train loss (single batch): 0.086882
# 	 partial train loss (single batch): 0.085934
# 	 partial train loss (single batch): 0.086085
# 	 partial train loss (single batch): 0.085637
# 	 partial train loss (single batch): 0.084421
# 	 partial train loss (single batch): 0.084464
# 	 partial train loss (single batch): 0.085230
# 	 partial train loss (single batch): 0.085441
# 	 partial train loss (single batch): 0.085735
# 	 partial train loss (single batch): 0.084718
# 	 partial train loss (single batch): 0.085986
# 	 partial train loss (single batch): 0.085203
# 	 partial train loss (single batch): 0.083923
# 	 partial train loss (single batch): 0.084261
# 	 partial train loss (single batch): 0.085409
# 	 partial train loss (single batch): 0.085042
# 	 partial train loss (single batch): 0.084358
# 	 partial train loss (single batch): 0.084498
# 	 partial train loss (single batch): 0.084037
# 	 partial train loss (single batch): 0.084505
# 	 partial train loss (single batch): 0.084881
# 	 partial train loss (single batch): 0.083325
# 	 partial train loss (single batch): 0.083914
# 	 partial train loss (single batch): 0.083448
# 	 partial train loss (single batch): 0.083511
# 	 partial train loss (single batch): 0.083110
# 	 partial train loss (single batch): 0.083872
# 	 partial train loss (single batch): 0.084204
# 	 partial train loss (single batch): 0.083608
# 	 partial train loss (single batch): 0.083617
# 	 partial train loss (single batch): 0.082832
# 	 partial train loss (single batch): 0.082827
# 	 partial train loss (single batch): 0.082847
# 	 partial train loss (single batch): 0.083798
# 	 partial train loss (single batch): 0.082927
# 	 partial train loss (single batch): 0.083207
# 	 partial train loss (single batch): 0.082488
# 	 partial train loss (single batch): 0.081457
# 	 partial train loss (single batch): 0.081944
# 	 partial train loss (single batch): 0.082545
# 	 partial train loss (single batch): 0.082159
# 	 partial train loss (single batch): 0.082455
# 	 partial train loss (single batch): 0.081660
# 	 partial train loss (single batch): 0.082360
# 	 partial train loss (single batch): 0.082418
# 	 partial train loss (single batch): 0.082255
# 	 partial train loss (single batch): 0.084931
# 	 partial train loss (single batch): 0.084845
# 	 partial train loss (single batch): 0.088248
# 	 partial train loss (single batch): 0.081284
# 	 partial train loss (single batch): 0.085536
# 	 partial train loss (single batch): 0.085163
# 	 partial train loss (single batch): 0.084496
# 	 partial train loss (single batch): 0.084430
# 	 partial train loss (single batch): 0.082494
# 	 partial train loss (single batch): 0.085145
# 	 partial train loss (single batch): 0.081363
# 	 partial train loss (single batch): 0.084993
# 	 partial train loss (single batch): 0.081373
# 	 partial train loss (single batch): 0.083223
# 	 partial train loss (single batch): 0.081063
# 	 partial train loss (single batch): 0.082532
# 	 partial train loss (single batch): 0.082131
# 	 partial train loss (single batch): 0.082221
# 	 partial train loss (single batch): 0.081744
# 	 partial train loss (single batch): 0.082836
# 	 partial train loss (single batch): 0.081767
# 	 partial train loss (single batch): 0.082041
# 	 partial train loss (single batch): 0.081828
# 	 partial train loss (single batch): 0.081327
#
#  EPOCH 1/30 	 train loss 0.101 	 val loss 0.030
# EPOCH 2/30
# 	 partial train loss (single batch): 0.080524
# 	 partial train loss (single batch): 0.081484
# 	 partial train loss (single batch): 0.081063
# 	 partial train loss (single batch): 0.081898
# 	 partial train loss (single batch): 0.081093
# 	 partial train loss (single batch): 0.081447
# 	 partial train loss (single batch): 0.081511
# 	 partial train loss (single batch): 0.080918
# 	 partial train loss (single batch): 0.081588
# 	 partial train loss (single batch): 0.081546
# 	 partial train loss (single batch): 0.081003
# 	 partial train loss (single batch): 0.081063
# 	 partial train loss (single batch): 0.082239
# 	 partial train loss (single batch): 0.081528
# 	 partial train loss (single batch): 0.081815
# 	 partial train loss (single batch): 0.080966
# 	 partial train loss (single batch): 0.080962
# 	 partial train loss (single batch): 0.081163
# 	 partial train loss (single batch): 0.080234
# 	 partial train loss (single batch): 0.080392
# 	 partial train loss (single batch): 0.081455
# 	 partial train loss (single batch): 0.081491
# 	 partial train loss (single batch): 0.080779
# 	 partial train loss (single batch): 0.080423
# 	 partial train loss (single batch): 0.081162
# 	 partial train loss (single batch): 0.079934
# 	 partial train loss (single batch): 0.079921
# 	 partial train loss (single batch): 0.080283
# 	 partial train loss (single batch): 0.079519
# 	 partial train loss (single batch): 0.080366
# 	 partial train loss (single batch): 0.079686
# 	 partial train loss (single batch): 0.079594
# 	 partial train loss (single batch): 0.079724
# 	 partial train loss (single batch): 0.079775
# 	 partial train loss (single batch): 0.079715
# 	 partial train loss (single batch): 0.078772
# 	 partial train loss (single batch): 0.078485
# 	 partial train loss (single batch): 0.079555
# 	 partial train loss (single batch): 0.079444
# 	 partial train loss (single batch): 0.080427
# 	 partial train loss (single batch): 0.079131
# 	 partial train loss (single batch): 0.078824
# 	 partial train loss (single batch): 0.078828
# 	 partial train loss (single batch): 0.079705
# 	 partial train loss (single batch): 0.078744
# 	 partial train loss (single batch): 0.079692
# 	 partial train loss (single batch): 0.079168
# 	 partial train loss (single batch): 0.078895
# 	 partial train loss (single batch): 0.079915
# 	 partial train loss (single batch): 0.078917
# 	 partial train loss (single batch): 0.079398
# 	 partial train loss (single batch): 0.079337
# 	 partial train loss (single batch): 0.079052
# 	 partial train loss (single batch): 0.079103
# 	 partial train loss (single batch): 0.078720
# 	 partial train loss (single batch): 0.078822
# 	 partial train loss (single batch): 0.078817
# 	 partial train loss (single batch): 0.079404
# 	 partial train loss (single batch): 0.078274
# 	 partial train loss (single batch): 0.078381
# 	 partial train loss (single batch): 0.078334
# 	 partial train loss (single batch): 0.079164
# 	 partial train loss (single batch): 0.078335
# 	 partial train loss (single batch): 0.078267
# 	 partial train loss (single batch): 0.078005
# 	 partial train loss (single batch): 0.078659
# 	 partial train loss (single batch): 0.078203
# 	 partial train loss (single batch): 0.078752
# 	 partial train loss (single batch): 0.079214
# 	 partial train loss (single batch): 0.078619
# 	 partial train loss (single batch): 0.078824
# 	 partial train loss (single batch): 0.078329
# 	 partial train loss (single batch): 0.077908
# 	 partial train loss (single batch): 0.078557
# 	 partial train loss (single batch): 0.078337
# 	 partial train loss (single batch): 0.078358
# 	 partial train loss (single batch): 0.077999
# 	 partial train loss (single batch): 0.077648
# 	 partial train loss (single batch): 0.078831
# 	 partial train loss (single batch): 0.078015
# 	 partial train loss (single batch): 0.078186
# 	 partial train loss (single batch): 0.077443
# 	 partial train loss (single batch): 0.077604
# 	 partial train loss (single batch): 0.078041
# 	 partial train loss (single batch): 0.077754
# 	 partial train loss (single batch): 0.078073
# 	 partial train loss (single batch): 0.077002
# 	 partial train loss (single batch): 0.077641
# 	 partial train loss (single batch): 0.077707
# 	 partial train loss (single batch): 0.077958
# 	 partial train loss (single batch): 0.077289
# 	 partial train loss (single batch): 0.076578
# 	 partial train loss (single batch): 0.076718
# 	 partial train loss (single batch): 0.077228
# 	 partial train loss (single batch): 0.077422
# 	 partial train loss (single batch): 0.077301
# 	 partial train loss (single batch): 0.076779
# 	 partial train loss (single batch): 0.077613
# 	 partial train loss (single batch): 0.078380
# 	 partial train loss (single batch): 0.077804
# 	 partial train loss (single batch): 0.078990
# 	 partial train loss (single batch): 0.079760
# 	 partial train loss (single batch): 0.080351
# 	 partial train loss (single batch): 0.077186
# 	 partial train loss (single batch): 0.078021
# 	 partial train loss (single batch): 0.078787
# 	 partial train loss (single batch): 0.078083
# 	 partial train loss (single batch): 0.078837
# 	 partial train loss (single batch): 0.078144
# 	 partial train loss (single batch): 0.077306
# 	 partial train loss (single batch): 0.077975
# 	 partial train loss (single batch): 0.077699
# 	 partial train loss (single batch): 0.077035
# 	 partial train loss (single batch): 0.079033
# 	 partial train loss (single batch): 0.078490
# 	 partial train loss (single batch): 0.077208
# 	 partial train loss (single batch): 0.078460
# 	 partial train loss (single batch): 0.078178
# 	 partial train loss (single batch): 0.076597
# 	 partial train loss (single batch): 0.077645
# 	 partial train loss (single batch): 0.077854
# 	 partial train loss (single batch): 0.077373
# 	 partial train loss (single batch): 0.078962
# 	 partial train loss (single batch): 0.077543
# 	 partial train loss (single batch): 0.076848
# 	 partial train loss (single batch): 0.077287
# 	 partial train loss (single batch): 0.076856
# 	 partial train loss (single batch): 0.076909
# 	 partial train loss (single batch): 0.076981
# 	 partial train loss (single batch): 0.077134
# 	 partial train loss (single batch): 0.076809
# 	 partial train loss (single batch): 0.077104
# 	 partial train loss (single batch): 0.076688
# 	 partial train loss (single batch): 0.076722
# 	 partial train loss (single batch): 0.076430
# 	 partial train loss (single batch): 0.077742
# 	 partial train loss (single batch): 0.076442
# 	 partial train loss (single batch): 0.076527
# 	 partial train loss (single batch): 0.076296
# 	 partial train loss (single batch): 0.076975
# 	 partial train loss (single batch): 0.075846
# 	 partial train loss (single batch): 0.076601
# 	 partial train loss (single batch): 0.076707
# 	 partial train loss (single batch): 0.076123
# 	 partial train loss (single batch): 0.077336
# 	 partial train loss (single batch): 0.075905
# 	 partial train loss (single batch): 0.076521
# 	 partial train loss (single batch): 0.075985
# 	 partial train loss (single batch): 0.076747
# 	 partial train loss (single batch): 0.076295
# 	 partial train loss (single batch): 0.076194
# 	 partial train loss (single batch): 0.076141
# 	 partial train loss (single batch): 0.077211
# 	 partial train loss (single batch): 0.076348
# 	 partial train loss (single batch): 0.076592
# 	 partial train loss (single batch): 0.076383
# 	 partial train loss (single batch): 0.076323
#
#  EPOCH 2/30 	 train loss 0.079 	 val loss 0.023
# EPOCH 3/30
# 	 partial train loss (single batch): 0.075270
# 	 partial train loss (single batch): 0.076421
# 	 partial train loss (single batch): 0.075648
# 	 partial train loss (single batch): 0.076777
# 	 partial train loss (single batch): 0.075730
# 	 partial train loss (single batch): 0.076495
# 	 partial train loss (single batch): 0.076054
# 	 partial train loss (single batch): 0.076011
# 	 partial train loss (single batch): 0.076425
# 	 partial train loss (single batch): 0.076435
# 	 partial train loss (single batch): 0.075991
# 	 partial train loss (single batch): 0.076051
# 	 partial train loss (single batch): 0.076439
# 	 partial train loss (single batch): 0.076634
# 	 partial train loss (single batch): 0.076857
# 	 partial train loss (single batch): 0.075854
# 	 partial train loss (single batch): 0.075813
# 	 partial train loss (single batch): 0.076230
# 	 partial train loss (single batch): 0.076052
# 	 partial train loss (single batch): 0.076086
# 	 partial train loss (single batch): 0.076460
# 	 partial train loss (single batch): 0.076952
# 	 partial train loss (single batch): 0.076124
# 	 partial train loss (single batch): 0.075808
# 	 partial train loss (single batch): 0.076894
# 	 partial train loss (single batch): 0.075897
# 	 partial train loss (single batch): 0.075736
# 	 partial train loss (single batch): 0.076227
# 	 partial train loss (single batch): 0.075965
# 	 partial train loss (single batch): 0.075978
# 	 partial train loss (single batch): 0.075690
# 	 partial train loss (single batch): 0.075813
# 	 partial train loss (single batch): 0.075751
# 	 partial train loss (single batch): 0.075937
# 	 partial train loss (single batch): 0.075965
# 	 partial train loss (single batch): 0.074330
# 	 partial train loss (single batch): 0.074621
# 	 partial train loss (single batch): 0.075577
# 	 partial train loss (single batch): 0.075514
# 	 partial train loss (single batch): 0.076542
# 	 partial train loss (single batch): 0.075339
# 	 partial train loss (single batch): 0.074880
# 	 partial train loss (single batch): 0.075038
# 	 partial train loss (single batch): 0.075462
# 	 partial train loss (single batch): 0.075287
# 	 partial train loss (single batch): 0.075793
# 	 partial train loss (single batch): 0.075442
# 	 partial train loss (single batch): 0.074674
# 	 partial train loss (single batch): 0.076049
# 	 partial train loss (single batch): 0.075178
# 	 partial train loss (single batch): 0.075758
# 	 partial train loss (single batch): 0.076122
# 	 partial train loss (single batch): 0.075652
# 	 partial train loss (single batch): 0.075641
# 	 partial train loss (single batch): 0.075804
# 	 partial train loss (single batch): 0.076349
# 	 partial train loss (single batch): 0.076150
# 	 partial train loss (single batch): 0.076415
# 	 partial train loss (single batch): 0.075123
# 	 partial train loss (single batch): 0.074588
# 	 partial train loss (single batch): 0.075026
# 	 partial train loss (single batch): 0.075591
# 	 partial train loss (single batch): 0.075357
# 	 partial train loss (single batch): 0.075613
# 	 partial train loss (single batch): 0.074920
# 	 partial train loss (single batch): 0.075294
# 	 partial train loss (single batch): 0.074709
# 	 partial train loss (single batch): 0.074970
# 	 partial train loss (single batch): 0.075328
# 	 partial train loss (single batch): 0.075241
# 	 partial train loss (single batch): 0.075622
# 	 partial train loss (single batch): 0.074850
# 	 partial train loss (single batch): 0.074603
# 	 partial train loss (single batch): 0.075250
# 	 partial train loss (single batch): 0.074698
# 	 partial train loss (single batch): 0.075244
# 	 partial train loss (single batch): 0.074781
# 	 partial train loss (single batch): 0.074519
# 	 partial train loss (single batch): 0.075776
# 	 partial train loss (single batch): 0.074590
# 	 partial train loss (single batch): 0.074993
# 	 partial train loss (single batch): 0.074623
# 	 partial train loss (single batch): 0.074762
# 	 partial train loss (single batch): 0.074960
# 	 partial train loss (single batch): 0.074668
# 	 partial train loss (single batch): 0.074802
# 	 partial train loss (single batch): 0.073962
# 	 partial train loss (single batch): 0.074401
# 	 partial train loss (single batch): 0.074989
# 	 partial train loss (single batch): 0.074988
# 	 partial train loss (single batch): 0.074248
# 	 partial train loss (single batch): 0.073863
# 	 partial train loss (single batch): 0.073728
# 	 partial train loss (single batch): 0.074542
# 	 partial train loss (single batch): 0.074593
# 	 partial train loss (single batch): 0.074752
# 	 partial train loss (single batch): 0.075282
# 	 partial train loss (single batch): 0.077792
# 	 partial train loss (single batch): 0.078308
# 	 partial train loss (single batch): 0.077487
# 	 partial train loss (single batch): 0.074639
# 	 partial train loss (single batch): 0.076264
# 	 partial train loss (single batch): 0.078342
# 	 partial train loss (single batch): 0.074500
# 	 partial train loss (single batch): 0.077797
# 	 partial train loss (single batch): 0.077155
# 	 partial train loss (single batch): 0.076000
# 	 partial train loss (single batch): 0.079869
# 	 partial train loss (single batch): 0.075266
# 	 partial train loss (single batch): 0.076793
# 	 partial train loss (single batch): 0.075640
# 	 partial train loss (single batch): 0.074560
# 	 partial train loss (single batch): 0.075913
# 	 partial train loss (single batch): 0.075653
# 	 partial train loss (single batch): 0.075658
# 	 partial train loss (single batch): 0.075022
# 	 partial train loss (single batch): 0.075754
# 	 partial train loss (single batch): 0.075154
# 	 partial train loss (single batch): 0.074784
# 	 partial train loss (single batch): 0.074235
# 	 partial train loss (single batch): 0.075639
# 	 partial train loss (single batch): 0.075041
# 	 partial train loss (single batch): 0.075208
# 	 partial train loss (single batch): 0.075487
# 	 partial train loss (single batch): 0.074311
# 	 partial train loss (single batch): 0.075141
# 	 partial train loss (single batch): 0.074490
# 	 partial train loss (single batch): 0.074638
# 	 partial train loss (single batch): 0.074455
# 	 partial train loss (single batch): 0.074868
# 	 partial train loss (single batch): 0.074486
# 	 partial train loss (single batch): 0.075047
# 	 partial train loss (single batch): 0.073933
# 	 partial train loss (single batch): 0.074432
# 	 partial train loss (single batch): 0.073949
# 	 partial train loss (single batch): 0.075292
# 	 partial train loss (single batch): 0.074183
# 	 partial train loss (single batch): 0.074043
# 	 partial train loss (single batch): 0.073948
# 	 partial train loss (single batch): 0.074578
# 	 partial train loss (single batch): 0.073454
# 	 partial train loss (single batch): 0.074315
# 	 partial train loss (single batch): 0.074355
# 	 partial train loss (single batch): 0.073708
# 	 partial train loss (single batch): 0.075203
# 	 partial train loss (single batch): 0.073438
# 	 partial train loss (single batch): 0.074103
# 	 partial train loss (single batch): 0.073852
# 	 partial train loss (single batch): 0.074519
# 	 partial train loss (single batch): 0.074340
# 	 partial train loss (single batch): 0.073704
# 	 partial train loss (single batch): 0.074006
# 	 partial train loss (single batch): 0.074829
# 	 partial train loss (single batch): 0.074339
# 	 partial train loss (single batch): 0.074245
# 	 partial train loss (single batch): 0.074288
# 	 partial train loss (single batch): 0.074293
#
#  EPOCH 3/30 	 train loss 0.075 	 val loss 0.020
# EPOCH 4/30
# 	 partial train loss (single batch): 0.073380
# 	 partial train loss (single batch): 0.074270
# 	 partial train loss (single batch): 0.073565
# 	 partial train loss (single batch): 0.074349
# 	 partial train loss (single batch): 0.073271
# 	 partial train loss (single batch): 0.074450
# 	 partial train loss (single batch): 0.074090
# 	 partial train loss (single batch): 0.073635
# 	 partial train loss (single batch): 0.074005
# 	 partial train loss (single batch): 0.074386
# 	 partial train loss (single batch): 0.073885
# 	 partial train loss (single batch): 0.074160
# 	 partial train loss (single batch): 0.074198
# 	 partial train loss (single batch): 0.074435
# 	 partial train loss (single batch): 0.074784
# 	 partial train loss (single batch): 0.073618
# 	 partial train loss (single batch): 0.073667
# 	 partial train loss (single batch): 0.073984
# 	 partial train loss (single batch): 0.073907
# 	 partial train loss (single batch): 0.074004
# 	 partial train loss (single batch): 0.074514
# 	 partial train loss (single batch): 0.074646
# 	 partial train loss (single batch): 0.073860
# 	 partial train loss (single batch): 0.073678
# 	 partial train loss (single batch): 0.074831
# 	 partial train loss (single batch): 0.073629
# 	 partial train loss (single batch): 0.073336
# 	 partial train loss (single batch): 0.073938
# 	 partial train loss (single batch): 0.073875
# 	 partial train loss (single batch): 0.073805
# 	 partial train loss (single batch): 0.074018
# 	 partial train loss (single batch): 0.073790
# 	 partial train loss (single batch): 0.073472
# 	 partial train loss (single batch): 0.073822
# 	 partial train loss (single batch): 0.073851
# 	 partial train loss (single batch): 0.072651
# 	 partial train loss (single batch): 0.072738
# 	 partial train loss (single batch): 0.073388
# 	 partial train loss (single batch): 0.073646
# 	 partial train loss (single batch): 0.074753
# 	 partial train loss (single batch): 0.073612
# 	 partial train loss (single batch): 0.073219
# 	 partial train loss (single batch): 0.073292
# 	 partial train loss (single batch): 0.073856
# 	 partial train loss (single batch): 0.073526
# 	 partial train loss (single batch): 0.074010
# 	 partial train loss (single batch): 0.073491
# 	 partial train loss (single batch): 0.072982
# 	 partial train loss (single batch): 0.074344
# 	 partial train loss (single batch): 0.073580
# 	 partial train loss (single batch): 0.073854
# 	 partial train loss (single batch): 0.074089
# 	 partial train loss (single batch): 0.073971
# 	 partial train loss (single batch): 0.073494
# 	 partial train loss (single batch): 0.072948
# 	 partial train loss (single batch): 0.073637
# 	 partial train loss (single batch): 0.073607
# 	 partial train loss (single batch): 0.074283
# 	 partial train loss (single batch): 0.072960
# 	 partial train loss (single batch): 0.073054
# 	 partial train loss (single batch): 0.073080
# 	 partial train loss (single batch): 0.073537
# 	 partial train loss (single batch): 0.073103
# 	 partial train loss (single batch): 0.073566
# 	 partial train loss (single batch): 0.073045
# 	 partial train loss (single batch): 0.073569
# 	 partial train loss (single batch): 0.072636
# 	 partial train loss (single batch): 0.073111
# 	 partial train loss (single batch): 0.073286
# 	 partial train loss (single batch): 0.073382
# 	 partial train loss (single batch): 0.073906
# 	 partial train loss (single batch): 0.073310
# 	 partial train loss (single batch): 0.072991
# 	 partial train loss (single batch): 0.073529
# 	 partial train loss (single batch): 0.073013
# 	 partial train loss (single batch): 0.073879
# 	 partial train loss (single batch): 0.073165
# 	 partial train loss (single batch): 0.073031
# 	 partial train loss (single batch): 0.074169
# 	 partial train loss (single batch): 0.072986
# 	 partial train loss (single batch): 0.073414
# 	 partial train loss (single batch): 0.073202
# 	 partial train loss (single batch): 0.073266
# 	 partial train loss (single batch): 0.073516
# 	 partial train loss (single batch): 0.073234
# 	 partial train loss (single batch): 0.073386
# 	 partial train loss (single batch): 0.072526
# 	 partial train loss (single batch): 0.072681
# 	 partial train loss (single batch): 0.073374
# 	 partial train loss (single batch): 0.073392
# 	 partial train loss (single batch): 0.072759
# 	 partial train loss (single batch): 0.072344
# 	 partial train loss (single batch): 0.072328
# 	 partial train loss (single batch): 0.072667
# 	 partial train loss (single batch): 0.072860
# 	 partial train loss (single batch): 0.072651
# 	 partial train loss (single batch): 0.072884
# 	 partial train loss (single batch): 0.073248
# 	 partial train loss (single batch): 0.073820
# 	 partial train loss (single batch): 0.072727
# 	 partial train loss (single batch): 0.072785
# 	 partial train loss (single batch): 0.073465
# 	 partial train loss (single batch): 0.073732
# 	 partial train loss (single batch): 0.072648
# 	 partial train loss (single batch): 0.073136
# 	 partial train loss (single batch): 0.072659
# 	 partial train loss (single batch): 0.073701
# 	 partial train loss (single batch): 0.074251
# 	 partial train loss (single batch): 0.072834
# 	 partial train loss (single batch): 0.073186
# 	 partial train loss (single batch): 0.072906
# 	 partial train loss (single batch): 0.072121
# 	 partial train loss (single batch): 0.072733
# 	 partial train loss (single batch): 0.073881
# 	 partial train loss (single batch): 0.073038
# 	 partial train loss (single batch): 0.073203
# 	 partial train loss (single batch): 0.073327
# 	 partial train loss (single batch): 0.073699
# 	 partial train loss (single batch): 0.073200
# 	 partial train loss (single batch): 0.072923
# 	 partial train loss (single batch): 0.073859
# 	 partial train loss (single batch): 0.073329
# 	 partial train loss (single batch): 0.073608
# 	 partial train loss (single batch): 0.073359
# 	 partial train loss (single batch): 0.072928
# 	 partial train loss (single batch): 0.073529
# 	 partial train loss (single batch): 0.073132
# 	 partial train loss (single batch): 0.073273
# 	 partial train loss (single batch): 0.072894
# 	 partial train loss (single batch): 0.073372
# 	 partial train loss (single batch): 0.072768
# 	 partial train loss (single batch): 0.073122
# 	 partial train loss (single batch): 0.072282
# 	 partial train loss (single batch): 0.072648
# 	 partial train loss (single batch): 0.072249
# 	 partial train loss (single batch): 0.073638
# 	 partial train loss (single batch): 0.072624
# 	 partial train loss (single batch): 0.072735
# 	 partial train loss (single batch): 0.072417
# 	 partial train loss (single batch): 0.072861
# 	 partial train loss (single batch): 0.072043
# 	 partial train loss (single batch): 0.072875
# 	 partial train loss (single batch): 0.072861
# 	 partial train loss (single batch): 0.072326
# 	 partial train loss (single batch): 0.073681
# 	 partial train loss (single batch): 0.072059
# 	 partial train loss (single batch): 0.072629
# 	 partial train loss (single batch): 0.072353
# 	 partial train loss (single batch): 0.073034
# 	 partial train loss (single batch): 0.072776
# 	 partial train loss (single batch): 0.072223
# 	 partial train loss (single batch): 0.072612
# 	 partial train loss (single batch): 0.073296
# 	 partial train loss (single batch): 0.073054
# 	 partial train loss (single batch): 0.072917
# 	 partial train loss (single batch): 0.072853
# 	 partial train loss (single batch): 0.072930
#
#  EPOCH 4/30 	 train loss 0.073 	 val loss 0.019
# EPOCH 5/30
# 	 partial train loss (single batch): 0.072258
# 	 partial train loss (single batch): 0.072938
# 	 partial train loss (single batch): 0.072373
# 	 partial train loss (single batch): 0.073302
# 	 partial train loss (single batch): 0.072867
# 	 partial train loss (single batch): 0.074041
# 	 partial train loss (single batch): 0.073661
# 	 partial train loss (single batch): 0.072806
# 	 partial train loss (single batch): 0.072782
# 	 partial train loss (single batch): 0.073408
# 	 partial train loss (single batch): 0.072883
# 	 partial train loss (single batch): 0.073039
# 	 partial train loss (single batch): 0.073170
# 	 partial train loss (single batch): 0.073037
# 	 partial train loss (single batch): 0.073485
# 	 partial train loss (single batch): 0.072619
# 	 partial train loss (single batch): 0.072587
# 	 partial train loss (single batch): 0.072369
# 	 partial train loss (single batch): 0.072705
# 	 partial train loss (single batch): 0.072910
# 	 partial train loss (single batch): 0.073102
# 	 partial train loss (single batch): 0.073156
# 	 partial train loss (single batch): 0.072478
# 	 partial train loss (single batch): 0.072359
# 	 partial train loss (single batch): 0.073338
# 	 partial train loss (single batch): 0.072243
# 	 partial train loss (single batch): 0.071824
# 	 partial train loss (single batch): 0.072533
# 	 partial train loss (single batch): 0.072635
# 	 partial train loss (single batch): 0.072432
# 	 partial train loss (single batch): 0.072755
# 	 partial train loss (single batch): 0.072370
# 	 partial train loss (single batch): 0.072176
# 	 partial train loss (single batch): 0.072585
# 	 partial train loss (single batch): 0.072595
# 	 partial train loss (single batch): 0.071264
# 	 partial train loss (single batch): 0.071674
# 	 partial train loss (single batch): 0.072131
# 	 partial train loss (single batch): 0.072335
# 	 partial train loss (single batch): 0.073140
# 	 partial train loss (single batch): 0.072246
# 	 partial train loss (single batch): 0.072300
# 	 partial train loss (single batch): 0.071933
# 	 partial train loss (single batch): 0.072197
# 	 partial train loss (single batch): 0.072055
# 	 partial train loss (single batch): 0.072799
# 	 partial train loss (single batch): 0.071991
# 	 partial train loss (single batch): 0.071355
# 	 partial train loss (single batch): 0.073053
# 	 partial train loss (single batch): 0.072374
# 	 partial train loss (single batch): 0.072811
# 	 partial train loss (single batch): 0.073512
# 	 partial train loss (single batch): 0.074698
# 	 partial train loss (single batch): 0.075776
# 	 partial train loss (single batch): 0.077164
# 	 partial train loss (single batch): 0.072892
# 	 partial train loss (single batch): 0.074184
# 	 partial train loss (single batch): 0.077412
# 	 partial train loss (single batch): 0.072304
# 	 partial train loss (single batch): 0.075523
# 	 partial train loss (single batch): 0.075424
# 	 partial train loss (single batch): 0.074490
# 	 partial train loss (single batch): 0.076281
# 	 partial train loss (single batch): 0.073321
# 	 partial train loss (single batch): 0.074455
# 	 partial train loss (single batch): 0.073374
# 	 partial train loss (single batch): 0.073875
# 	 partial train loss (single batch): 0.073130
# 	 partial train loss (single batch): 0.073696
# 	 partial train loss (single batch): 0.073034
# 	 partial train loss (single batch): 0.073814
# 	 partial train loss (single batch): 0.072674
# 	 partial train loss (single batch): 0.072757
# 	 partial train loss (single batch): 0.073071
# 	 partial train loss (single batch): 0.072568
# 	 partial train loss (single batch): 0.073650
# 	 partial train loss (single batch): 0.072385
# 	 partial train loss (single batch): 0.072366
# 	 partial train loss (single batch): 0.073389
# 	 partial train loss (single batch): 0.072665
# 	 partial train loss (single batch): 0.072507
# 	 partial train loss (single batch): 0.072519
# 	 partial train loss (single batch): 0.072300
# 	 partial train loss (single batch): 0.072581
# 	 partial train loss (single batch): 0.072181
# 	 partial train loss (single batch): 0.072581
# 	 partial train loss (single batch): 0.071589
# 	 partial train loss (single batch): 0.071869
# 	 partial train loss (single batch): 0.072560
# 	 partial train loss (single batch): 0.072482
# 	 partial train loss (single batch): 0.071893
# 	 partial train loss (single batch): 0.071135
# 	 partial train loss (single batch): 0.071278
# 	 partial train loss (single batch): 0.071611
# 	 partial train loss (single batch): 0.071855
# 	 partial train loss (single batch): 0.071456
# 	 partial train loss (single batch): 0.071814
# 	 partial train loss (single batch): 0.072231
# 	 partial train loss (single batch): 0.072852
# 	 partial train loss (single batch): 0.071674
# 	 partial train loss (single batch): 0.071663
# 	 partial train loss (single batch): 0.072181
# 	 partial train loss (single batch): 0.072520
# 	 partial train loss (single batch): 0.071666
# 	 partial train loss (single batch): 0.072117
# 	 partial train loss (single batch): 0.071459
# 	 partial train loss (single batch): 0.072507
# 	 partial train loss (single batch): 0.072975
# 	 partial train loss (single batch): 0.071461
# 	 partial train loss (single batch): 0.071924
# 	 partial train loss (single batch): 0.071786
# 	 partial train loss (single batch): 0.071003
# 	 partial train loss (single batch): 0.071611
# 	 partial train loss (single batch): 0.072474
# 	 partial train loss (single batch): 0.071729
# 	 partial train loss (single batch): 0.071818
# 	 partial train loss (single batch): 0.071889
# 	 partial train loss (single batch): 0.072136
# 	 partial train loss (single batch): 0.071482
# 	 partial train loss (single batch): 0.071214
# 	 partial train loss (single batch): 0.072279
# 	 partial train loss (single batch): 0.071636
# 	 partial train loss (single batch): 0.072442
# 	 partial train loss (single batch): 0.072272
# 	 partial train loss (single batch): 0.071729
# 	 partial train loss (single batch): 0.072365
# 	 partial train loss (single batch): 0.071572
# 	 partial train loss (single batch): 0.071898
# 	 partial train loss (single batch): 0.071781
# 	 partial train loss (single batch): 0.072049
# 	 partial train loss (single batch): 0.071626
# 	 partial train loss (single batch): 0.071920
# 	 partial train loss (single batch): 0.070979
# 	 partial train loss (single batch): 0.071504
# 	 partial train loss (single batch): 0.071248
# 	 partial train loss (single batch): 0.072470
# 	 partial train loss (single batch): 0.071357
# 	 partial train loss (single batch): 0.071645
# 	 partial train loss (single batch): 0.071428
# 	 partial train loss (single batch): 0.071767
# 	 partial train loss (single batch): 0.071026
# 	 partial train loss (single batch): 0.071607
# 	 partial train loss (single batch): 0.071754
# 	 partial train loss (single batch): 0.071382
# 	 partial train loss (single batch): 0.072608
# 	 partial train loss (single batch): 0.071096
# 	 partial train loss (single batch): 0.071568
# 	 partial train loss (single batch): 0.071278
# 	 partial train loss (single batch): 0.072083
# 	 partial train loss (single batch): 0.071537
# 	 partial train loss (single batch): 0.071351
# 	 partial train loss (single batch): 0.071569
# 	 partial train loss (single batch): 0.072339
# 	 partial train loss (single batch): 0.071941
# 	 partial train loss (single batch): 0.071732
# 	 partial train loss (single batch): 0.071764
# 	 partial train loss (single batch): 0.072333
#
#  EPOCH 5/30 	 train loss 0.072 	 val loss 0.017
# EPOCH 6/30
# 	 partial train loss (single batch): 0.071249
# 	 partial train loss (single batch): 0.071717
# 	 partial train loss (single batch): 0.071230
# 	 partial train loss (single batch): 0.071595
# 	 partial train loss (single batch): 0.070931
# 	 partial train loss (single batch): 0.071827
# 	 partial train loss (single batch): 0.071768
# 	 partial train loss (single batch): 0.071357
# 	 partial train loss (single batch): 0.071677
# 	 partial train loss (single batch): 0.071944
# 	 partial train loss (single batch): 0.071782
# 	 partial train loss (single batch): 0.071653
# 	 partial train loss (single batch): 0.072072
# 	 partial train loss (single batch): 0.072093
# 	 partial train loss (single batch): 0.072460
# 	 partial train loss (single batch): 0.071390
# 	 partial train loss (single batch): 0.071466
# 	 partial train loss (single batch): 0.071337
# 	 partial train loss (single batch): 0.071703
# 	 partial train loss (single batch): 0.071857
# 	 partial train loss (single batch): 0.072141
# 	 partial train loss (single batch): 0.072014
# 	 partial train loss (single batch): 0.071528
# 	 partial train loss (single batch): 0.071544
# 	 partial train loss (single batch): 0.072628
# 	 partial train loss (single batch): 0.071429
# 	 partial train loss (single batch): 0.070936
# 	 partial train loss (single batch): 0.071665
# 	 partial train loss (single batch): 0.071705
# 	 partial train loss (single batch): 0.071545
# 	 partial train loss (single batch): 0.071738
# 	 partial train loss (single batch): 0.071319
# 	 partial train loss (single batch): 0.071216
# 	 partial train loss (single batch): 0.071631
# 	 partial train loss (single batch): 0.071854
# 	 partial train loss (single batch): 0.070403
# 	 partial train loss (single batch): 0.070845
# 	 partial train loss (single batch): 0.071274
# 	 partial train loss (single batch): 0.071394
# 	 partial train loss (single batch): 0.072311
# 	 partial train loss (single batch): 0.071344
# 	 partial train loss (single batch): 0.070980
# 	 partial train loss (single batch): 0.071014
# 	 partial train loss (single batch): 0.071288
# 	 partial train loss (single batch): 0.071338
# 	 partial train loss (single batch): 0.071806
# 	 partial train loss (single batch): 0.070997
# 	 partial train loss (single batch): 0.070571
# 	 partial train loss (single batch): 0.072134
# 	 partial train loss (single batch): 0.071378
# 	 partial train loss (single batch): 0.071788
# 	 partial train loss (single batch): 0.071753
# 	 partial train loss (single batch): 0.071718
# 	 partial train loss (single batch): 0.071516
# 	 partial train loss (single batch): 0.070854
# 	 partial train loss (single batch): 0.071452
# 	 partial train loss (single batch): 0.071284
# 	 partial train loss (single batch): 0.071947
# 	 partial train loss (single batch): 0.071195
# 	 partial train loss (single batch): 0.070723
# 	 partial train loss (single batch): 0.071175
# 	 partial train loss (single batch): 0.071579
# 	 partial train loss (single batch): 0.071091
# 	 partial train loss (single batch): 0.071688
# 	 partial train loss (single batch): 0.070958
# 	 partial train loss (single batch): 0.071646
# 	 partial train loss (single batch): 0.070708
# 	 partial train loss (single batch): 0.071089
# 	 partial train loss (single batch): 0.071256
# 	 partial train loss (single batch): 0.071515
# 	 partial train loss (single batch): 0.071798
# 	 partial train loss (single batch): 0.071092
# 	 partial train loss (single batch): 0.070832
# 	 partial train loss (single batch): 0.071471
# 	 partial train loss (single batch): 0.070962
# 	 partial train loss (single batch): 0.072149
# 	 partial train loss (single batch): 0.070792
# 	 partial train loss (single batch): 0.070756
# 	 partial train loss (single batch): 0.072348
# 	 partial train loss (single batch): 0.070973
# 	 partial train loss (single batch): 0.071297
# 	 partial train loss (single batch): 0.070898
# 	 partial train loss (single batch): 0.071188
# 	 partial train loss (single batch): 0.071323
# 	 partial train loss (single batch): 0.070930
# 	 partial train loss (single batch): 0.071140
# 	 partial train loss (single batch): 0.070397
# 	 partial train loss (single batch): 0.070834
# 	 partial train loss (single batch): 0.071547
# 	 partial train loss (single batch): 0.071777
# 	 partial train loss (single batch): 0.070875
# 	 partial train loss (single batch): 0.070281
# 	 partial train loss (single batch): 0.070190
# 	 partial train loss (single batch): 0.070715
# 	 partial train loss (single batch): 0.070684
# 	 partial train loss (single batch): 0.070387
# 	 partial train loss (single batch): 0.070980
# 	 partial train loss (single batch): 0.071388
# 	 partial train loss (single batch): 0.071782
# 	 partial train loss (single batch): 0.070818
# 	 partial train loss (single batch): 0.070789
# 	 partial train loss (single batch): 0.071211
# 	 partial train loss (single batch): 0.071704
# 	 partial train loss (single batch): 0.070677
# 	 partial train loss (single batch): 0.071237
# 	 partial train loss (single batch): 0.070902
# 	 partial train loss (single batch): 0.072115
# 	 partial train loss (single batch): 0.072488
# 	 partial train loss (single batch): 0.070927
# 	 partial train loss (single batch): 0.071012
# 	 partial train loss (single batch): 0.071007
# 	 partial train loss (single batch): 0.070265
# 	 partial train loss (single batch): 0.070846
# 	 partial train loss (single batch): 0.071904
# 	 partial train loss (single batch): 0.070918
# 	 partial train loss (single batch): 0.071282
# 	 partial train loss (single batch): 0.071172
# 	 partial train loss (single batch): 0.071350
# 	 partial train loss (single batch): 0.070890
# 	 partial train loss (single batch): 0.070406
# 	 partial train loss (single batch): 0.071613
# 	 partial train loss (single batch): 0.071185
# 	 partial train loss (single batch): 0.071782
# 	 partial train loss (single batch): 0.071505
# 	 partial train loss (single batch): 0.071106
# 	 partial train loss (single batch): 0.071413
# 	 partial train loss (single batch): 0.070690
# 	 partial train loss (single batch): 0.071233
# 	 partial train loss (single batch): 0.070987
# 	 partial train loss (single batch): 0.071406
# 	 partial train loss (single batch): 0.070856
# 	 partial train loss (single batch): 0.071175
# 	 partial train loss (single batch): 0.070405
# 	 partial train loss (single batch): 0.070740
# 	 partial train loss (single batch): 0.070412
# 	 partial train loss (single batch): 0.071868
# 	 partial train loss (single batch): 0.070827
# 	 partial train loss (single batch): 0.071306
# 	 partial train loss (single batch): 0.070923
# 	 partial train loss (single batch): 0.071080
# 	 partial train loss (single batch): 0.070368
# 	 partial train loss (single batch): 0.071016
# 	 partial train loss (single batch): 0.070936
# 	 partial train loss (single batch): 0.070554
# 	 partial train loss (single batch): 0.071842
# 	 partial train loss (single batch): 0.070307
# 	 partial train loss (single batch): 0.070830
# 	 partial train loss (single batch): 0.070839
# 	 partial train loss (single batch): 0.071135
# 	 partial train loss (single batch): 0.070854
# 	 partial train loss (single batch): 0.070640
# 	 partial train loss (single batch): 0.070904
# 	 partial train loss (single batch): 0.071584
# 	 partial train loss (single batch): 0.071138
# 	 partial train loss (single batch): 0.070958
# 	 partial train loss (single batch): 0.070869
# 	 partial train loss (single batch): 0.071545
#
#  EPOCH 6/30 	 train loss 0.071 	 val loss 0.017
# EPOCH 7/30
# 	 partial train loss (single batch): 0.070570
# 	 partial train loss (single batch): 0.071088
# 	 partial train loss (single batch): 0.070437
# 	 partial train loss (single batch): 0.071056
# 	 partial train loss (single batch): 0.070294
# 	 partial train loss (single batch): 0.071337
# 	 partial train loss (single batch): 0.071150
# 	 partial train loss (single batch): 0.070777
# 	 partial train loss (single batch): 0.071121
# 	 partial train loss (single batch): 0.071291
# 	 partial train loss (single batch): 0.070930
# 	 partial train loss (single batch): 0.070760
# 	 partial train loss (single batch): 0.071101
# 	 partial train loss (single batch): 0.071537
# 	 partial train loss (single batch): 0.071750
# 	 partial train loss (single batch): 0.070626
# 	 partial train loss (single batch): 0.070888
# 	 partial train loss (single batch): 0.070659
# 	 partial train loss (single batch): 0.071063
# 	 partial train loss (single batch): 0.071291
# 	 partial train loss (single batch): 0.071404
# 	 partial train loss (single batch): 0.071715
# 	 partial train loss (single batch): 0.071053
# 	 partial train loss (single batch): 0.071176
# 	 partial train loss (single batch): 0.072450
# 	 partial train loss (single batch): 0.071701
# 	 partial train loss (single batch): 0.070857
# 	 partial train loss (single batch): 0.071756
# 	 partial train loss (single batch): 0.071349
# 	 partial train loss (single batch): 0.070929
# 	 partial train loss (single batch): 0.071384
# 	 partial train loss (single batch): 0.071147
# 	 partial train loss (single batch): 0.071070
# 	 partial train loss (single batch): 0.071097
# 	 partial train loss (single batch): 0.071098
# 	 partial train loss (single batch): 0.069731
# 	 partial train loss (single batch): 0.070460
# 	 partial train loss (single batch): 0.070808
# 	 partial train loss (single batch): 0.071081
# 	 partial train loss (single batch): 0.071619
# 	 partial train loss (single batch): 0.070843
# 	 partial train loss (single batch): 0.070805
# 	 partial train loss (single batch): 0.070739
# 	 partial train loss (single batch): 0.070664
# 	 partial train loss (single batch): 0.070799
# 	 partial train loss (single batch): 0.071100
# 	 partial train loss (single batch): 0.070409
# 	 partial train loss (single batch): 0.070017
# 	 partial train loss (single batch): 0.071438
# 	 partial train loss (single batch): 0.070870
# 	 partial train loss (single batch): 0.071355
# 	 partial train loss (single batch): 0.071439
# 	 partial train loss (single batch): 0.071106
# 	 partial train loss (single batch): 0.070960
# 	 partial train loss (single batch): 0.070339
# 	 partial train loss (single batch): 0.070822
# 	 partial train loss (single batch): 0.070802
# 	 partial train loss (single batch): 0.071496
# 	 partial train loss (single batch): 0.070846
# 	 partial train loss (single batch): 0.070013
# 	 partial train loss (single batch): 0.070191
# 	 partial train loss (single batch): 0.070837
# 	 partial train loss (single batch): 0.070741
# 	 partial train loss (single batch): 0.070989
# 	 partial train loss (single batch): 0.070542
# 	 partial train loss (single batch): 0.071198
# 	 partial train loss (single batch): 0.070218
# 	 partial train loss (single batch): 0.070352
# 	 partial train loss (single batch): 0.070718
# 	 partial train loss (single batch): 0.070993
# 	 partial train loss (single batch): 0.071050
# 	 partial train loss (single batch): 0.070708
# 	 partial train loss (single batch): 0.070402
# 	 partial train loss (single batch): 0.071012
# 	 partial train loss (single batch): 0.070368
# 	 partial train loss (single batch): 0.071374
# 	 partial train loss (single batch): 0.070356
# 	 partial train loss (single batch): 0.070189
# 	 partial train loss (single batch): 0.071668
# 	 partial train loss (single batch): 0.070427
# 	 partial train loss (single batch): 0.070740
# 	 partial train loss (single batch): 0.070326
# 	 partial train loss (single batch): 0.070583
# 	 partial train loss (single batch): 0.070861
# 	 partial train loss (single batch): 0.070360
# 	 partial train loss (single batch): 0.070714
# 	 partial train loss (single batch): 0.070090
# 	 partial train loss (single batch): 0.070280
# 	 partial train loss (single batch): 0.071054
# 	 partial train loss (single batch): 0.071284
# 	 partial train loss (single batch): 0.070438
# 	 partial train loss (single batch): 0.069834
# 	 partial train loss (single batch): 0.069643
# ...
# 	 partial train loss (single batch): 0.063761
# 	 partial train loss (single batch): 0.063610
# 	 partial train loss (single batch): 0.063521
# 	 partial train loss (single batch): 0.063591
# 	 partial train loss (single batch): 0.063449
# 	 partial train loss (single batch): 0.062579
# 	 partial train loss (single batch): 0.062940
# 	 partial train loss (single batch): 0.062979
# 	 partial train loss (single batch): 0.063937
# 	 partial train loss (single batch): 0.063713
# 	 partial train loss (single batch): 0.063159
# 	 partial train loss (single batch): 0.062745
# 	 partial train loss (single batch): 0.063336
# 	 partial train loss (single batch): 0.062868
# 	 partial train loss (single batch): 0.063351
# 	 partial train loss (single batch): 0.063918
# 	 partial train loss (single batch): 0.063718
# 	 partial train loss (single batch): 0.064019
# 	 partial train loss (single batch): 0.063290
# 	 partial train loss (single batch): 0.063489
# 	 partial train loss (single batch): 0.063882
# 	 partial train loss (single batch): 0.064419
# 	 partial train loss (single batch): 0.063858
# 	 partial train loss (single batch): 0.063712
# 	 partial train loss (single batch): 0.063284
# 	 partial train loss (single batch): 0.063991
# 	 partial train loss (single batch): 0.064105
# 	 partial train loss (single batch): 0.063605
# 	 partial train loss (single batch): 0.063428
# 	 partial train loss (single batch): 0.064134
#
#  EPOCH 28/30 	 train loss 0.064 	 val loss 0.010
# EPOCH 29/30
# 	 partial train loss (single batch): 0.063314
# 	 partial train loss (single batch): 0.063433
# 	 partial train loss (single batch): 0.063230
# 	 partial train loss (single batch): 0.063826
# 	 partial train loss (single batch): 0.063283
# 	 partial train loss (single batch): 0.063854
# 	 partial train loss (single batch): 0.063369
# 	 partial train loss (single batch): 0.063434
# 	 partial train loss (single batch): 0.063442
# 	 partial train loss (single batch): 0.064188
# 	 partial train loss (single batch): 0.063770
# 	 partial train loss (single batch): 0.063622
# 	 partial train loss (single batch): 0.063588
# 	 partial train loss (single batch): 0.063879
# 	 partial train loss (single batch): 0.064161
# 	 partial train loss (single batch): 0.063113
# 	 partial train loss (single batch): 0.063428
# 	 partial train loss (single batch): 0.062994
# 	 partial train loss (single batch): 0.063929
# 	 partial train loss (single batch): 0.063558
# 	 partial train loss (single batch): 0.063365
# 	 partial train loss (single batch): 0.063628
# 	 partial train loss (single batch): 0.063265
# 	 partial train loss (single batch): 0.063372
# 	 partial train loss (single batch): 0.063497
# 	 partial train loss (single batch): 0.063206
# 	 partial train loss (single batch): 0.062414
# 	 partial train loss (single batch): 0.063789
# 	 partial train loss (single batch): 0.064318
# 	 partial train loss (single batch): 0.064121
# 	 partial train loss (single batch): 0.064612
# 	 partial train loss (single batch): 0.064347
# 	 partial train loss (single batch): 0.063118
# 	 partial train loss (single batch): 0.063781
# 	 partial train loss (single batch): 0.064001
# 	 partial train loss (single batch): 0.063406
# 	 partial train loss (single batch): 0.063245
# 	 partial train loss (single batch): 0.063543
# 	 partial train loss (single batch): 0.063891
# 	 partial train loss (single batch): 0.064135
# 	 partial train loss (single batch): 0.063724
# 	 partial train loss (single batch): 0.063712
# 	 partial train loss (single batch): 0.063342
# 	 partial train loss (single batch): 0.063733
# 	 partial train loss (single batch): 0.063868
# 	 partial train loss (single batch): 0.063612
# 	 partial train loss (single batch): 0.063158
# 	 partial train loss (single batch): 0.063213
# 	 partial train loss (single batch): 0.063794
# 	 partial train loss (single batch): 0.064042
# 	 partial train loss (single batch): 0.063413
# 	 partial train loss (single batch): 0.063752
# 	 partial train loss (single batch): 0.063384
# 	 partial train loss (single batch): 0.063334
# 	 partial train loss (single batch): 0.063482
# 	 partial train loss (single batch): 0.063566
# 	 partial train loss (single batch): 0.063221
# 	 partial train loss (single batch): 0.063026
# 	 partial train loss (single batch): 0.063241
# 	 partial train loss (single batch): 0.062747
# 	 partial train loss (single batch): 0.063214
# 	 partial train loss (single batch): 0.063143
# 	 partial train loss (single batch): 0.063156
# 	 partial train loss (single batch): 0.063475
# 	 partial train loss (single batch): 0.063122
# 	 partial train loss (single batch): 0.063709
# 	 partial train loss (single batch): 0.062960
# 	 partial train loss (single batch): 0.063247
# 	 partial train loss (single batch): 0.063102
# 	 partial train loss (single batch): 0.063742
# 	 partial train loss (single batch): 0.063502
# 	 partial train loss (single batch): 0.063325
# 	 partial train loss (single batch): 0.063006
# 	 partial train loss (single batch): 0.063551
# 	 partial train loss (single batch): 0.063462
# 	 partial train loss (single batch): 0.064164
# 	 partial train loss (single batch): 0.063222
# 	 partial train loss (single batch): 0.062467
# 	 partial train loss (single batch): 0.063957
# 	 partial train loss (single batch): 0.063231
# 	 partial train loss (single batch): 0.063326
# 	 partial train loss (single batch): 0.063077
# 	 partial train loss (single batch): 0.063126
# 	 partial train loss (single batch): 0.063461
# 	 partial train loss (single batch): 0.063273
# 	 partial train loss (single batch): 0.063120
# 	 partial train loss (single batch): 0.063270
# 	 partial train loss (single batch): 0.063531
# 	 partial train loss (single batch): 0.063978
# 	 partial train loss (single batch): 0.063426
# 	 partial train loss (single batch): 0.063129
# 	 partial train loss (single batch): 0.063058
# 	 partial train loss (single batch): 0.062875
# 	 partial train loss (single batch): 0.063097
# 	 partial train loss (single batch): 0.062920
# 	 partial train loss (single batch): 0.062789
# 	 partial train loss (single batch): 0.063437
# 	 partial train loss (single batch): 0.063308
# 	 partial train loss (single batch): 0.063769
# 	 partial train loss (single batch): 0.063064
# 	 partial train loss (single batch): 0.063200
# 	 partial train loss (single batch): 0.062988
# 	 partial train loss (single batch): 0.063707
# 	 partial train loss (single batch): 0.062871
# 	 partial train loss (single batch): 0.062908
# 	 partial train loss (single batch): 0.063433
# 	 partial train loss (single batch): 0.063767
# 	 partial train loss (single batch): 0.064136
# 	 partial train loss (single batch): 0.063332
# 	 partial train loss (single batch): 0.063500
# 	 partial train loss (single batch): 0.063107
# 	 partial train loss (single batch): 0.062538
# 	 partial train loss (single batch): 0.063230
# 	 partial train loss (single batch): 0.064032
# 	 partial train loss (single batch): 0.063162
# 	 partial train loss (single batch): 0.063660
# 	 partial train loss (single batch): 0.063850
# 	 partial train loss (single batch): 0.063504
# 	 partial train loss (single batch): 0.063194
# 	 partial train loss (single batch): 0.063430
# 	 partial train loss (single batch): 0.063613
# 	 partial train loss (single batch): 0.062766
# 	 partial train loss (single batch): 0.063820
# 	 partial train loss (single batch): 0.063411
# 	 partial train loss (single batch): 0.063607
# 	 partial train loss (single batch): 0.063768
# 	 partial train loss (single batch): 0.063274
# 	 partial train loss (single batch): 0.063598
# 	 partial train loss (single batch): 0.063343
# 	 partial train loss (single batch): 0.063290
# 	 partial train loss (single batch): 0.063564
# 	 partial train loss (single batch): 0.063323
# 	 partial train loss (single batch): 0.062472
# 	 partial train loss (single batch): 0.062690
# 	 partial train loss (single batch): 0.062788
# 	 partial train loss (single batch): 0.064009
# 	 partial train loss (single batch): 0.063469
# 	 partial train loss (single batch): 0.062776
# 	 partial train loss (single batch): 0.062604
# 	 partial train loss (single batch): 0.062911
# 	 partial train loss (single batch): 0.062833
# 	 partial train loss (single batch): 0.063176
# 	 partial train loss (single batch): 0.063858
# 	 partial train loss (single batch): 0.063836
# 	 partial train loss (single batch): 0.064817
# 	 partial train loss (single batch): 0.063421
# 	 partial train loss (single batch): 0.063515
# 	 partial train loss (single batch): 0.063549
# 	 partial train loss (single batch): 0.064362
# 	 partial train loss (single batch): 0.063675
# 	 partial train loss (single batch): 0.063585
# 	 partial train loss (single batch): 0.063070
# 	 partial train loss (single batch): 0.063775
# 	 partial train loss (single batch): 0.064075
# 	 partial train loss (single batch): 0.063429
# 	 partial train loss (single batch): 0.063307
# 	 partial train loss (single batch): 0.063955
#
#  EPOCH 29/30 	 train loss 0.063 	 val loss 0.010
# EPOCH 30/30
# 	 partial train loss (single batch): 0.063151
# 	 partial train loss (single batch): 0.063104
# 	 partial train loss (single batch): 0.063020
# 	 partial train loss (single batch): 0.063701
# 	 partial train loss (single batch): 0.063051
# 	 partial train loss (single batch): 0.063773
# 	 partial train loss (single batch): 0.063266
# 	 partial train loss (single batch): 0.063102
# 	 partial train loss (single batch): 0.063575
# 	 partial train loss (single batch): 0.063980
# 	 partial train loss (single batch): 0.063618
# 	 partial train loss (single batch): 0.063512
# 	 partial train loss (single batch): 0.063515
# 	 partial train loss (single batch): 0.063362
# 	 partial train loss (single batch): 0.064059
# 	 partial train loss (single batch): 0.062792
# 	 partial train loss (single batch): 0.063306
# 	 partial train loss (single batch): 0.062802
# 	 partial train loss (single batch): 0.063663
# 	 partial train loss (single batch): 0.063386
# 	 partial train loss (single batch): 0.063001
# 	 partial train loss (single batch): 0.063400
# 	 partial train loss (single batch): 0.062989
# 	 partial train loss (single batch): 0.063095
# 	 partial train loss (single batch): 0.063116
# 	 partial train loss (single batch): 0.063037
# 	 partial train loss (single batch): 0.062391
# 	 partial train loss (single batch): 0.063664
# 	 partial train loss (single batch): 0.063766
# 	 partial train loss (single batch): 0.063501
# 	 partial train loss (single batch): 0.063476
# 	 partial train loss (single batch): 0.063332
# 	 partial train loss (single batch): 0.062557
# 	 partial train loss (single batch): 0.063524
# 	 partial train loss (single batch): 0.063545
# 	 partial train loss (single batch): 0.062741
# 	 partial train loss (single batch): 0.062718
# 	 partial train loss (single batch): 0.063088
# 	 partial train loss (single batch): 0.063273
# 	 partial train loss (single batch): 0.063741
# 	 partial train loss (single batch): 0.063172
# 	 partial train loss (single batch): 0.063225
# 	 partial train loss (single batch): 0.063134
# 	 partial train loss (single batch): 0.063447
# 	 partial train loss (single batch): 0.063549
# 	 partial train loss (single batch): 0.063245
# 	 partial train loss (single batch): 0.062885
# 	 partial train loss (single batch): 0.062925
# 	 partial train loss (single batch): 0.063151
# 	 partial train loss (single batch): 0.063812
# 	 partial train loss (single batch): 0.063372
# 	 partial train loss (single batch): 0.063308
# 	 partial train loss (single batch): 0.063120
# 	 partial train loss (single batch): 0.062824
# 	 partial train loss (single batch): 0.063056
# 	 partial train loss (single batch): 0.063266
# 	 partial train loss (single batch): 0.063131
# 	 partial train loss (single batch): 0.062774
# 	 partial train loss (single batch): 0.063044
# 	 partial train loss (single batch): 0.062583
# 	 partial train loss (single batch): 0.063234
# 	 partial train loss (single batch): 0.063520
# 	 partial train loss (single batch): 0.063711
# 	 partial train loss (single batch): 0.064174
# 	 partial train loss (single batch): 0.063471
# 	 partial train loss (single batch): 0.063479
# 	 partial train loss (single batch): 0.063027
# 	 partial train loss (single batch): 0.063429
# 	 partial train loss (single batch): 0.063190
# 	 partial train loss (single batch): 0.063625
# 	 partial train loss (single batch): 0.063659
# 	 partial train loss (single batch): 0.063588
# 	 partial train loss (single batch): 0.063030
# 	 partial train loss (single batch): 0.063362
# 	 partial train loss (single batch): 0.063432
# 	 partial train loss (single batch): 0.064188
# 	 partial train loss (single batch): 0.063032
# 	 partial train loss (single batch): 0.062496
# 	 partial train loss (single batch): 0.063687
# 	 partial train loss (single batch): 0.063089
# 	 partial train loss (single batch): 0.063125
# 	 partial train loss (single batch): 0.062793
# 	 partial train loss (single batch): 0.063069
# 	 partial train loss (single batch): 0.063055
# 	 partial train loss (single batch): 0.062948
# 	 partial train loss (single batch): 0.062869
# 	 partial train loss (single batch): 0.062711
# 	 partial train loss (single batch): 0.062980
# 	 partial train loss (single batch): 0.063380
# 	 partial train loss (single batch): 0.063325
# 	 partial train loss (single batch): 0.063133
# 	 partial train loss (single batch): 0.063035
# 	 partial train loss (single batch): 0.062977
# 	 partial train loss (single batch): 0.063060
# 	 partial train loss (single batch): 0.062765
# 	 partial train loss (single batch): 0.062499
# 	 partial train loss (single batch): 0.063224
# 	 partial train loss (single batch): 0.062986
# 	 partial train loss (single batch): 0.063451
# 	 partial train loss (single batch): 0.063020
# 	 partial train loss (single batch): 0.062633
# 	 partial train loss (single batch): 0.062811
# 	 partial train loss (single batch): 0.063613
# 	 partial train loss (single batch): 0.062683
# 	 partial train loss (single batch): 0.062897
# 	 partial train loss (single batch): 0.063052
# 	 partial train loss (single batch): 0.063428
# 	 partial train loss (single batch): 0.063704
# 	 partial train loss (single batch): 0.062747
# 	 partial train loss (single batch): 0.062953
# 	 partial train loss (single batch): 0.062812
# 	 partial train loss (single batch): 0.062469
# 	 partial train loss (single batch): 0.062964
# 	 partial train loss (single batch): 0.063774
# 	 partial train loss (single batch): 0.062957
# 	 partial train loss (single batch): 0.063277
# 	 partial train loss (single batch): 0.063454
# 	 partial train loss (single batch): 0.063157
# 	 partial train loss (single batch): 0.062842
# 	 partial train loss (single batch): 0.063280
# 	 partial train loss (single batch): 0.063265
# 	 partial train loss (single batch): 0.062484
# 	 partial train loss (single batch): 0.063763
# 	 partial train loss (single batch): 0.063112
# 	 partial train loss (single batch): 0.063339
# 	 partial train loss (single batch): 0.063370
# 	 partial train loss (single batch): 0.062777
# 	 partial train loss (single batch): 0.063357
# 	 partial train loss (single batch): 0.063105
# 	 partial train loss (single batch): 0.063080
# 	 partial train loss (single batch): 0.063129
# 	 partial train loss (single batch): 0.063197
# 	 partial train loss (single batch): 0.062308
# 	 partial train loss (single batch): 0.062317
# 	 partial train loss (single batch): 0.062615
# 	 partial train loss (single batch): 0.063724
# 	 partial train loss (single batch): 0.063229
# 	 partial train loss (single batch): 0.062755
# 	 partial train loss (single batch): 0.062530
# 	 partial train loss (single batch): 0.063191
# 	 partial train loss (single batch): 0.063144
# 	 partial train loss (single batch): 0.063581
# 	 partial train loss (single batch): 0.063755
# 	 partial train loss (single batch): 0.063063
# 	 partial train loss (single batch): 0.063478
# 	 partial train loss (single batch): 0.062489
# 	 partial train loss (single batch): 0.062953
# 	 partial train loss (single batch): 0.063006
# 	 partial train loss (single batch): 0.063630
# 	 partial train loss (single batch): 0.062967
# 	 partial train loss (single batch): 0.062941
# 	 partial train loss (single batch): 0.062777
# 	 partial train loss (single batch): 0.063213
# 	 partial train loss (single batch): 0.063547
# 	 partial train loss (single batch): 0.063245
# 	 partial train loss (single batch): 0.063048
# 	 partial train loss (single batch): 0.063440
#
#  EPOCH 30/30 	 train loss 0.063 	 val loss 0.010

# %% [markdown]
# **Note that validation loss seems unusually lower than training loss!<br>
# The reason is that training loss is progressively calculated for every image in the batch,<br>
# whereas validation loss is calculated at the end of batch training, when the model performs best.**

# %%
# Plot training performance
test_epoch_den(encoder,decoder,device,test_loader,loss_fn).item()# Plot losses
plt.figure(figsize=(10,8))
plt.semilogy(history_da['train_loss'], label='Train')
plt.semilogy(history_da['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 4 Visualize latent space

# %%
def plot_results(encoder, decoder, data, rx=(-5, 5), ry=(-5, 5), model_name='VAE'):

    # Encode all data samples
    encoded_samples = []
    for sample in tqdm(data):
        
        # Separate image data from its label 
        img = sample[0].unsqueeze(0).to(device)
        label = sample[1]
        
        # Encode image
        encoder.eval()
        with torch.no_grad():
            encoded_img  = encoder(img)
        
        # Append to list
        encoded_img = encoded_img.flatten().cpu().numpy()
        encoded_sample = {f"Enc. Variable {i}": enc for i, enc in enumerate(encoded_img)}
        encoded_sample['label'] = label
        encoded_samples.append(encoded_sample)
        
        # Find latend dimension from decoded image
        latent_dim = len(encoded_img)
        
    encoded_samples = pd.DataFrame(encoded_samples)

    # Create a TSNE model and plot it
    tsne = TSNE(n_components=2)
    tsne_results = tsne.fit_transform(encoded_samples.drop(['label'],axis=1))
    
    plt.figure(figsize=(17, 9))
    plt.scatter(tsne_results[:,0], tsne_results[:,1], c=encoded_samples.label, cmap='tab10', s=3)
    plt.xlabel('tsne-2d-one')
    plt.ylabel('tsne-2d-two')
    plt.title(f'Digit separation produced by {model_name}')
    plt.colorbar()
    plt.show()
    return
    
    # Prepare a n x n 2D matrix of digits
    n = 30
    digit_size = 32
    figure = np.zeros((digit_size * n, digit_size * n))
    
    # Create a linearly spaced coordinates of 2D digit classes in latent space
    grid_x = np.linspace(*rx, n)
    grid_y = np.linspace(*ry, n)[::-1]

    # Populate the matrix with images decoded from latent space
    for i, yi in enumerate(grid_y):
        for j, xj in enumerate(grid_x):
            # coords = [xj, yi, 0, 0] # Use latent_dim
            coords = list(np.zeros(latent_dim))
            coords[0] = xj
            coords[1] = yi
            z = torch.Tensor([coords]).to(device)
            x_hat = decoder(z)
            digit = x_hat.reshape(digit_size, digit_size).to('cpu').detach().numpy()
            figure[i * digit_size: (i + 1) * digit_size,
                   j * digit_size: (j + 1) * digit_size] = digit

    # Plot the matrix of "fake" sample digits
    plt.figure(figsize=(8, 8))
    start_range = digit_size // 2
    end_range = (n - 1) * digit_size + start_range + 1
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.title(f'Sample of digits recovered from {model_name} latent space')
    plt.imshow(figure, cmap='Greys')
    # plt.savefig(filename)
    plt.show()

def plot_fakes(encoder, decoder, n, rx=(-5, 5), ry=(-5, 5), model_name='VAE'):

    channels = 3
    latent_dim = d
    digit_size = 32
    
    plt.figure(figsize=(10,4.5))
    for i in range(n):

        coords = [int(v*10) for v in np.random.rand(latent_dim)]
        # print(f'Vector from latent space: {coords}')
        z = torch.Tensor([coords]).to(device)
        x_hat = decoder(z)
        img = x_hat.reshape(channels, digit_size, digit_size).to('cpu').detach().numpy()

        ax = plt.subplot(3, n, i + 1 + n + n)
        img = img.swapaxes(0,1)
        img = img.swapaxes(1,2)
        plt.imshow(img)  

        if i == n//2:
            ax.set_title(f'{model_name}')
            
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.7, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)     
    plt.show()   
    
plot_results(encoder, decoder, test_dataset, rx=(-1, 1), ry=(-1, 1), model_name="Denoising Autoencoder")
plot_fakes(encoder, decoder, n=5, rx=(-1, 1), ry=(-1, 1), model_name="Fake Images from Denoising Autoencoder")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:05<00:00, 1945.29it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.24.1</td></tr><tr><td><code>qiskit-aer</code></td><td>0.12.1</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.20.2</td></tr><tr><td><code>qiskit</code></td><td>0.43.2</td></tr><tr><td><code>qiskit-nature</code></td><td>0.6.2</td></tr><tr><td><code>qiskit-finance</code></td><td>0.3.4</td></tr><tr><td><code>qiskit-optimization</code></td><td>0.5.0</td></tr><tr><td><code>qiskit-machine-learning</code></td><td>0.6.1</td></tr><tr><th>System information</th></tr><tr><td>Python version</td><td>3.9.17</td></tr><tr><td>Python compiler</td><td>GCC 11.2.0</td></tr><tr><td>Python build</td><td>main, Jul  5 2023 20:41:20</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>31.067867279052734</td></tr><tr><td colspan='2'>Mon Jul 17 01:52:29 2023 AEST</td></tr></table>
