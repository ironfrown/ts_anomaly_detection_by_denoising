# %% [markdown]
# # Demo: Building Autoencoders in Pytorch
#
# Adapted from: https://github.com/eugeniaring/Medium-Articles/blob/main/Pytorch/denAE.ipynb
#
# By: Jacob Cybulski<br>
# Date: July 2023<br>
# Comment: *Lots of bugs fixed, works with Torch 2, on both CPU and GPU*
#
# Adapted From: Eugenia Anello, Denoising Autoencoder in Pytorch on MNIST dataset, Dataseries (Medium)<br>
# Date: Jun 28, 2021

# %%
import matplotlib.pyplot as plt
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd # this module is useful to work with tabular data
import random # this module will be used to select random samples from a collection
import os # this module will be used just to create directories in the local filesystem
from tqdm import tqdm # this module is useful to plot progress bars

import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.manifold import TSNE
# Out:
# /home/jacob/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Prelims: Get data and create tensor data loaders

# %%
data_dir = 'dataset'
### With these commands the train and test datasets, respectively, are downloaded
### automatically and stored in the local "data_dir" directory.
# train_dataset = torchvision.datasets.CIFAR10(data_dir, train=True, download=True)
# test_dataset  = torchvision.datasets.CIFAR10(data_dir, train=False, download=True)
train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)

print('Training data shape:', train_dataset.data.shape)
print('Test data shape:', test_dataset.data.shape)
# Out:
# Training data shape: torch.Size([60000, 28, 28])
# Test data shape: torch.Size([10000, 28, 28])

# %%
fig, axs = plt.subplots(5, 5, figsize=(10,10))
for ax in axs.flatten():
    # random.choice allows to randomly sample from a list-like object (basically anything that can be accessed with an index, like our dataset)
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img))
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
train_transform = transforms.Compose([
    transforms.ToTensor(),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Set the train transform
train_dataset.transform = train_transform

# Set the test transform
test_dataset.transform = test_transform

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)])

batch_size=256

# The dataloaders handle shuffling, batching, etc...
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %% [markdown]
# ## 1 Define Encoder and Decoder classes

# %%
class Encoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        
        # Input size: [batch, 3, 32, 32]
        # Output size: [batch, 3, 32, 32]

        ### Convolutional section
        self.encoder_cnn = nn.Sequential(
            
            nn.Conv2d(3, 12, 4, stride=2, padding=1),            # [batch, 12, 16, 16]
            nn.ReLU(True),
            nn.Conv2d(12, 24, 4, stride=2, padding=1),           # [batch, 24, 8, 8]
            nn.ReLU(True),
            nn.Conv2d(24, 48, 4, stride=2, padding=1),           # [batch, 48, 4, 4]
            nn.ReLU(True),
            nn.Conv2d(48, 96, 4, stride=2, padding=1),           # [batch, 96, 2, 2]
            nn.ReLU(True),
        )
        
        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        ### Linear section
        self.encoder_lin = nn.Sequential(
            
            # First linear layer
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            
            # Second linear layer
            nn.Linear(128, encoded_space_dim)
        )
        
    def forward(self, x):
        
        # Apply convolutions
        x = self.encoder_cnn(x)
        
        # Flatten
        x = self.flatten(x)
        
        # Apply linear layers
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()

        ### Linear section
        self.decoder_lin = nn.Sequential(
            
            # First linear layer
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            
            # Second linear layer
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        ### Unflatten
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))

        ### Convolutional section
        self.decoder_conv = nn.Sequential(
            
            # First transposed convolution
            nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            
            # Second transposed convolution
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            
            # Third transposed convolution
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )
        
    def forward(self, x):
        
        # Apply linear layers
        x = self.decoder_lin(x)
        
        # Unflatten
        x = self.unflatten(x)
        
        # Apply transposed convolutions
        x = self.decoder_conv(x)
        
        # Apply a sigmoid to force the output to be between 0 and 1 (valid pixel values)
        x = torch.sigmoid(x)
        return x

# %% [markdown]
# ## 2 initialize models, loss and optimizer
# *Note that "d" is the size of a latent space*

# %%
### Set the random seed for reproducible results
torch.manual_seed(0)

### Initialize the two networks
d = 4

encoder = Encoder(encoded_space_dim=d,fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=d,fc2_input_dim=128)

# %%
### Define the loss function
loss_fn = torch.nn.MSELoss()

### Define an optimizer (both for the encoder and the decoder!)
lr= 0.001 # Learning rate


params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

optim = torch.optim.Adam(params_to_optimize, lr=lr)

# Move both the encoder and the decoder to the selected device
encoder.to(device)
decoder.to(device)
print(encoder)
print(decoder)
# Out:
# Selected device: cuda
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %% [markdown]
# ## 3 Train model

# %%
im = test_dataset[0][0].unsqueeze(0)
a = im + torch.randn_like(im)*0.3
print(a)
# Out:
# tensor([[[[-2.6186e-01, -5.2741e-01,  1.4207e-01, -3.4364e-02, -8.2293e-01,
#            -3.7285e-01, -1.8820e-01,  4.0052e-01, -1.9379e-01,  1.9511e-01,
#             5.5844e-02,  1.5201e-01, -2.4522e-01, -1.7641e-01, -2.5315e-01,
#            -1.7867e-01, -2.1425e-01, -1.4516e-01, -4.0096e-01,  7.6207e-02,
#             2.9988e-01,  3.7973e-01, -1.2842e-03,  5.4212e-01,  4.1303e-01,
#            -2.4690e-01, -3.0636e-01,  4.5861e-01],
#           [-6.7076e-02, -1.4981e-01, -5.0485e-02,  4.1239e-02,  5.7786e-02,
#            -4.0090e-02,  1.7192e-01,  5.4917e-01,  4.0920e-01,  4.1377e-01,
#            -7.3474e-01,  1.7478e-01,  2.6263e-01,  2.3820e-01,  4.0751e-01,
#            -2.1979e-02, -1.1016e-01,  3.2486e-01,  2.2441e-01,  1.3555e-01,
#             8.9648e-02,  5.4989e-01, -2.0372e-01,  7.9197e-03,  2.4757e-01,
#             1.2877e-01,  4.0095e-01,  4.0813e-02],
#           [ 2.8814e-01,  5.3218e-01, -2.7910e-01, -9.0633e-03,  1.3595e-01,
#            -8.3562e-02,  4.1258e-01,  2.7265e-01, -4.4007e-01, -6.4523e-02,
#             7.6248e-02, -7.4228e-01,  9.1430e-02, -1.7635e-01,  5.1759e-01,
#             2.5020e-01,  2.3402e-02,  3.3008e-01,  3.1474e-01,  1.1642e-01,
#            -3.7376e-01,  5.3011e-01,  7.2140e-02, -2.8760e-01, -3.9452e-01,
#            -3.9308e-01,  1.2560e-01, -1.9912e-02],
#           [ 1.7887e-01,  2.8238e-01, -5.6227e-01,  2.2989e-01, -1.9243e-01,
#             6.9751e-01, -7.5933e-01, -2.5750e-01, -3.5065e-01, -4.7100e-02,
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader:
        
        # Move tensor to the proper device
        image_noisy = add_noise(image_batch,noise_factor)
        image_noisy = image_noisy.to(device)    
        
        # Encode data
        encoded_data = encoder(image_noisy)
        
        # Decode data
        decoded_data = decoder(encoded_data)
        
        # Evaluate loss
        loss = loss_fn(decoded_data, image_noisy)
        
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Print batch loss
        print('\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)

# %%
### Testing function
def test_epoch_den(encoder, decoder, device, dataloader, loss_fn,noise_factor=0.3):
    
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    
    with torch.no_grad(): # No need to track the gradients
        
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        
        for image_batch, _ in dataloader:
            
            # Move tensor to the proper device
            image_noisy = add_noise(image_batch,noise_factor)
            image_noisy = image_noisy.to(device)
            
            # Encode data
            encoded_data = encoder(image_noisy)
            
            # Decode data
            decoded_data = decoder(encoded_data)
            
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
            
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
        
    return val_loss.data

# %%
def plot_ae_outputs_den(encoder,decoder,n=5,noise_factor=0.3):
    plt.figure(figsize=(10,4.5))
    for i in range(n):

        ax = plt.subplot(3,n,i+1)
        img = test_dataset[i][0].unsqueeze(0)
        image_noisy = add_noise(img,noise_factor)     
        image_noisy = image_noisy.to(device)

        encoder.eval()
        decoder.eval()

        with torch.no_grad():
            rec_img  = decoder(encoder(image_noisy))

        plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Original images')
            
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(image_noisy.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Corrupted images')

        ax = plt.subplot(3, n, i + 1 + n + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')  
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Reconstructed images')
            
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.7, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)     
    plt.show()

# %%
### Training cycle
noise_factor = 0.3
num_epochs = 30
history_da={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    print('EPOCH %d/%d' % (epoch + 1, num_epochs))
    
    ### Training (use the training function)
    train_loss=train_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=train_loader, 
        loss_fn=loss_fn, 
        optimizer=optim,noise_factor=noise_factor)
    
    ### Validation  (use the testing function)
    val_loss = test_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=valid_loader, 
        loss_fn=loss_fn,noise_factor=noise_factor)
    
    # Print Validationloss
    history_da['train_loss'].append(train_loss)
    history_da['val_loss'].append(val_loss)
    print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
    plot_ae_outputs_den(encoder,decoder,noise_factor=noise_factor)
# Out:
# EPOCH 1/30
# 	 partial train loss (single batch): 0.189429
# 	 partial train loss (single batch): 0.184176
# 	 partial train loss (single batch): 0.179412
# 	 partial train loss (single batch): 0.175866
# 	 partial train loss (single batch): 0.172643
# 	 partial train loss (single batch): 0.169912
# 	 partial train loss (single batch): 0.167755
# 	 partial train loss (single batch): 0.165482
# 	 partial train loss (single batch): 0.163508
# 	 partial train loss (single batch): 0.161698
# 	 partial train loss (single batch): 0.159980
# 	 partial train loss (single batch): 0.158857
# 	 partial train loss (single batch): 0.157366
# 	 partial train loss (single batch): 0.155821
# 	 partial train loss (single batch): 0.154138
# 	 partial train loss (single batch): 0.152638
# 	 partial train loss (single batch): 0.151396
# 	 partial train loss (single batch): 0.149771
# 	 partial train loss (single batch): 0.148771
# 	 partial train loss (single batch): 0.147055
# 	 partial train loss (single batch): 0.145252
# 	 partial train loss (single batch): 0.144764
# 	 partial train loss (single batch): 0.143098
# 	 partial train loss (single batch): 0.141834
# 	 partial train loss (single batch): 0.140316
# 	 partial train loss (single batch): 0.139748
# 	 partial train loss (single batch): 0.138527
# 	 partial train loss (single batch): 0.136972
# 	 partial train loss (single batch): 0.135665
# 	 partial train loss (single batch): 0.134562
# 	 partial train loss (single batch): 0.133465
# 	 partial train loss (single batch): 0.132706
# 	 partial train loss (single batch): 0.131868
# 	 partial train loss (single batch): 0.130374
# 	 partial train loss (single batch): 0.129756
# 	 partial train loss (single batch): 0.128673
# 	 partial train loss (single batch): 0.127844
# 	 partial train loss (single batch): 0.127199
# 	 partial train loss (single batch): 0.126201
# 	 partial train loss (single batch): 0.124823
# 	 partial train loss (single batch): 0.123336
# 	 partial train loss (single batch): 0.123138
# 	 partial train loss (single batch): 0.121879
# 	 partial train loss (single batch): 0.121260
# 	 partial train loss (single batch): 0.119940
# 	 partial train loss (single batch): 0.119484
# 	 partial train loss (single batch): 0.118466
# 	 partial train loss (single batch): 0.117950
# 	 partial train loss (single batch): 0.116321
# 	 partial train loss (single batch): 0.116423
# 	 partial train loss (single batch): 0.115573
# 	 partial train loss (single batch): 0.114849
# 	 partial train loss (single batch): 0.114238
# 	 partial train loss (single batch): 0.113264
# 	 partial train loss (single batch): 0.111884
# 	 partial train loss (single batch): 0.111634
# 	 partial train loss (single batch): 0.111058
# 	 partial train loss (single batch): 0.110242
# 	 partial train loss (single batch): 0.109495
# 	 partial train loss (single batch): 0.108475
# 	 partial train loss (single batch): 0.108201
# 	 partial train loss (single batch): 0.106915
# 	 partial train loss (single batch): 0.106173
# 	 partial train loss (single batch): 0.105695
# 	 partial train loss (single batch): 0.105059
# 	 partial train loss (single batch): 0.104851
# 	 partial train loss (single batch): 0.103278
# 	 partial train loss (single batch): 0.102964
# 	 partial train loss (single batch): 0.103201
# 	 partial train loss (single batch): 0.101855
# 	 partial train loss (single batch): 0.100540
# 	 partial train loss (single batch): 0.100698
# 	 partial train loss (single batch): 0.099288
# 	 partial train loss (single batch): 0.098884
# 	 partial train loss (single batch): 0.098940
# 	 partial train loss (single batch): 0.097516
# 	 partial train loss (single batch): 0.097710
# 	 partial train loss (single batch): 0.097113
# 	 partial train loss (single batch): 0.096160
# 	 partial train loss (single batch): 0.095793
# 	 partial train loss (single batch): 0.094972
# 	 partial train loss (single batch): 0.094494
# 	 partial train loss (single batch): 0.094092
# 	 partial train loss (single batch): 0.093506
# 	 partial train loss (single batch): 0.093089
# 	 partial train loss (single batch): 0.093027
# 	 partial train loss (single batch): 0.092363
# 	 partial train loss (single batch): 0.090750
# 	 partial train loss (single batch): 0.090709
# 	 partial train loss (single batch): 0.090712
# 	 partial train loss (single batch): 0.090299
# 	 partial train loss (single batch): 0.089602
# 	 partial train loss (single batch): 0.088921
# 	 partial train loss (single batch): 0.088053
# 	 partial train loss (single batch): 0.088343
# 	 partial train loss (single batch): 0.087930
# 	 partial train loss (single batch): 0.087444
# 	 partial train loss (single batch): 0.087049
# 	 partial train loss (single batch): 0.086387
# 	 partial train loss (single batch): 0.086118
# 	 partial train loss (single batch): 0.085944
# 	 partial train loss (single batch): 0.084957
# 	 partial train loss (single batch): 0.085538
# 	 partial train loss (single batch): 0.084454
# 	 partial train loss (single batch): 0.083978
# 	 partial train loss (single batch): 0.084383
# 	 partial train loss (single batch): 0.083044
# 	 partial train loss (single batch): 0.083437
# 	 partial train loss (single batch): 0.082172
# 	 partial train loss (single batch): 0.082639
# 	 partial train loss (single batch): 0.082496
# 	 partial train loss (single batch): 0.081428
# 	 partial train loss (single batch): 0.081394
# 	 partial train loss (single batch): 0.080827
# 	 partial train loss (single batch): 0.080713
# 	 partial train loss (single batch): 0.080223
# 	 partial train loss (single batch): 0.080607
# 	 partial train loss (single batch): 0.080128
# 	 partial train loss (single batch): 0.079868
# 	 partial train loss (single batch): 0.079471
# 	 partial train loss (single batch): 0.079783
# 	 partial train loss (single batch): 0.079024
# 	 partial train loss (single batch): 0.078898
# 	 partial train loss (single batch): 0.078263
# 	 partial train loss (single batch): 0.077276
# 	 partial train loss (single batch): 0.078448
# 	 partial train loss (single batch): 0.077587
# 	 partial train loss (single batch): 0.077355
# 	 partial train loss (single batch): 0.077919
# 	 partial train loss (single batch): 0.076514
# 	 partial train loss (single batch): 0.077116
# 	 partial train loss (single batch): 0.076742
# 	 partial train loss (single batch): 0.075601
# 	 partial train loss (single batch): 0.075928
# 	 partial train loss (single batch): 0.076148
# 	 partial train loss (single batch): 0.076040
# 	 partial train loss (single batch): 0.075026
# 	 partial train loss (single batch): 0.074882
# 	 partial train loss (single batch): 0.073992
# 	 partial train loss (single batch): 0.074014
# 	 partial train loss (single batch): 0.074051
# 	 partial train loss (single batch): 0.074158
# 	 partial train loss (single batch): 0.074240
# 	 partial train loss (single batch): 0.073413
# 	 partial train loss (single batch): 0.074443
# 	 partial train loss (single batch): 0.073660
# 	 partial train loss (single batch): 0.072531
# 	 partial train loss (single batch): 0.073080
# 	 partial train loss (single batch): 0.072067
# 	 partial train loss (single batch): 0.072110
# 	 partial train loss (single batch): 0.072409
# 	 partial train loss (single batch): 0.072100
# 	 partial train loss (single batch): 0.072356
# 	 partial train loss (single batch): 0.072015
# 	 partial train loss (single batch): 0.071697
# 	 partial train loss (single batch): 0.071541
# 	 partial train loss (single batch): 0.071897
# 	 partial train loss (single batch): 0.070368
# 	 partial train loss (single batch): 0.071227
# 	 partial train loss (single batch): 0.070795
# 	 partial train loss (single batch): 0.070851
# 	 partial train loss (single batch): 0.070032
# 	 partial train loss (single batch): 0.070306
# 	 partial train loss (single batch): 0.070294
# 	 partial train loss (single batch): 0.071181
# 	 partial train loss (single batch): 0.070095
# 	 partial train loss (single batch): 0.069549
# 	 partial train loss (single batch): 0.070202
# 	 partial train loss (single batch): 0.069491
# 	 partial train loss (single batch): 0.069438
# 	 partial train loss (single batch): 0.069364
# 	 partial train loss (single batch): 0.069596
# 	 partial train loss (single batch): 0.068948
# 	 partial train loss (single batch): 0.068508
# 	 partial train loss (single batch): 0.068836
# 	 partial train loss (single batch): 0.068265
# 	 partial train loss (single batch): 0.068474
# 	 partial train loss (single batch): 0.068522
# 	 partial train loss (single batch): 0.067393
# 	 partial train loss (single batch): 0.068271
# 	 partial train loss (single batch): 0.067534
# 	 partial train loss (single batch): 0.068512
# 	 partial train loss (single batch): 0.068369
# 	 partial train loss (single batch): 0.067208
# 	 partial train loss (single batch): 0.068346
# 	 partial train loss (single batch): 0.067841
# 	 partial train loss (single batch): 0.066846
# 	 partial train loss (single batch): 0.067844
#
#  EPOCH 1/30 	 train loss 0.099 	 val loss 0.072
# EPOCH 2/30
# 	 partial train loss (single batch): 0.067382
# 	 partial train loss (single batch): 0.067239
# 	 partial train loss (single batch): 0.067245
# 	 partial train loss (single batch): 0.066947
# 	 partial train loss (single batch): 0.067487
# 	 partial train loss (single batch): 0.066728
# 	 partial train loss (single batch): 0.066962
# 	 partial train loss (single batch): 0.067042
# 	 partial train loss (single batch): 0.066702
# 	 partial train loss (single batch): 0.066516
# 	 partial train loss (single batch): 0.067466
# 	 partial train loss (single batch): 0.066494
# 	 partial train loss (single batch): 0.066877
# 	 partial train loss (single batch): 0.066116
# 	 partial train loss (single batch): 0.065976
# 	 partial train loss (single batch): 0.066870
# 	 partial train loss (single batch): 0.065826
# 	 partial train loss (single batch): 0.065545
# 	 partial train loss (single batch): 0.065840
# 	 partial train loss (single batch): 0.065632
# 	 partial train loss (single batch): 0.066410
# 	 partial train loss (single batch): 0.065507
# 	 partial train loss (single batch): 0.066049
# 	 partial train loss (single batch): 0.065527
# 	 partial train loss (single batch): 0.065120
# 	 partial train loss (single batch): 0.065733
# 	 partial train loss (single batch): 0.066260
# 	 partial train loss (single batch): 0.065153
# 	 partial train loss (single batch): 0.065483
# 	 partial train loss (single batch): 0.066039
# 	 partial train loss (single batch): 0.065371
# 	 partial train loss (single batch): 0.065506
# 	 partial train loss (single batch): 0.064884
# 	 partial train loss (single batch): 0.065000
# 	 partial train loss (single batch): 0.064448
# 	 partial train loss (single batch): 0.065106
# 	 partial train loss (single batch): 0.065298
# 	 partial train loss (single batch): 0.066094
# 	 partial train loss (single batch): 0.065149
# 	 partial train loss (single batch): 0.063919
# 	 partial train loss (single batch): 0.064047
# 	 partial train loss (single batch): 0.064697
# 	 partial train loss (single batch): 0.064319
# 	 partial train loss (single batch): 0.063999
# 	 partial train loss (single batch): 0.063925
# 	 partial train loss (single batch): 0.063994
# 	 partial train loss (single batch): 0.063593
# 	 partial train loss (single batch): 0.064751
# 	 partial train loss (single batch): 0.063359
# 	 partial train loss (single batch): 0.065938
# 	 partial train loss (single batch): 0.064393
# 	 partial train loss (single batch): 0.063652
# 	 partial train loss (single batch): 0.063725
# 	 partial train loss (single batch): 0.063743
# 	 partial train loss (single batch): 0.063770
# 	 partial train loss (single batch): 0.064206
# 	 partial train loss (single batch): 0.063637
# 	 partial train loss (single batch): 0.064244
# 	 partial train loss (single batch): 0.063699
# 	 partial train loss (single batch): 0.063770
# 	 partial train loss (single batch): 0.063937
# 	 partial train loss (single batch): 0.062884
# 	 partial train loss (single batch): 0.063439
# 	 partial train loss (single batch): 0.063306
# 	 partial train loss (single batch): 0.064375
# 	 partial train loss (single batch): 0.063794
# 	 partial train loss (single batch): 0.063457
# 	 partial train loss (single batch): 0.063332
# 	 partial train loss (single batch): 0.065213
# 	 partial train loss (single batch): 0.063854
# 	 partial train loss (single batch): 0.062429
# 	 partial train loss (single batch): 0.063182
# 	 partial train loss (single batch): 0.062700
# 	 partial train loss (single batch): 0.062149
# 	 partial train loss (single batch): 0.062531
# 	 partial train loss (single batch): 0.063006
# 	 partial train loss (single batch): 0.063587
# 	 partial train loss (single batch): 0.063438
# 	 partial train loss (single batch): 0.063492
# 	 partial train loss (single batch): 0.063617
# 	 partial train loss (single batch): 0.061800
# 	 partial train loss (single batch): 0.062489
# 	 partial train loss (single batch): 0.062960
# 	 partial train loss (single batch): 0.062942
# 	 partial train loss (single batch): 0.062832
# 	 partial train loss (single batch): 0.063984
# 	 partial train loss (single batch): 0.062963
# 	 partial train loss (single batch): 0.061764
# 	 partial train loss (single batch): 0.062399
# 	 partial train loss (single batch): 0.062022
# 	 partial train loss (single batch): 0.063017
# 	 partial train loss (single batch): 0.061910
# 	 partial train loss (single batch): 0.062021
# 	 partial train loss (single batch): 0.061514
# 	 partial train loss (single batch): 0.061854
# 	 partial train loss (single batch): 0.061981
# 	 partial train loss (single batch): 0.062602
# 	 partial train loss (single batch): 0.062770
# 	 partial train loss (single batch): 0.062022
# 	 partial train loss (single batch): 0.061475
# 	 partial train loss (single batch): 0.062342
# 	 partial train loss (single batch): 0.061973
# 	 partial train loss (single batch): 0.062793
# 	 partial train loss (single batch): 0.061869
# 	 partial train loss (single batch): 0.061627
# 	 partial train loss (single batch): 0.062572
# 	 partial train loss (single batch): 0.061855
# 	 partial train loss (single batch): 0.062114
# 	 partial train loss (single batch): 0.061131
# 	 partial train loss (single batch): 0.061609
# 	 partial train loss (single batch): 0.061625
# 	 partial train loss (single batch): 0.061373
# 	 partial train loss (single batch): 0.061118
# 	 partial train loss (single batch): 0.060601
# 	 partial train loss (single batch): 0.061216
# 	 partial train loss (single batch): 0.060899
# 	 partial train loss (single batch): 0.061650
# 	 partial train loss (single batch): 0.061371
# 	 partial train loss (single batch): 0.060976
# 	 partial train loss (single batch): 0.061107
# 	 partial train loss (single batch): 0.061444
# 	 partial train loss (single batch): 0.061365
# 	 partial train loss (single batch): 0.061739
# 	 partial train loss (single batch): 0.061172
# 	 partial train loss (single batch): 0.060580
# 	 partial train loss (single batch): 0.061668
# 	 partial train loss (single batch): 0.061222
# 	 partial train loss (single batch): 0.060911
# 	 partial train loss (single batch): 0.061527
# 	 partial train loss (single batch): 0.060875
# 	 partial train loss (single batch): 0.061156
# 	 partial train loss (single batch): 0.061467
# 	 partial train loss (single batch): 0.060208
# 	 partial train loss (single batch): 0.060993
# 	 partial train loss (single batch): 0.061662
# 	 partial train loss (single batch): 0.061793
# 	 partial train loss (single batch): 0.060611
# 	 partial train loss (single batch): 0.060448
# 	 partial train loss (single batch): 0.059674
# 	 partial train loss (single batch): 0.059949
# 	 partial train loss (single batch): 0.060193
# 	 partial train loss (single batch): 0.060704
# 	 partial train loss (single batch): 0.061005
# 	 partial train loss (single batch): 0.060392
# 	 partial train loss (single batch): 0.061548
# 	 partial train loss (single batch): 0.060479
# 	 partial train loss (single batch): 0.059682
# 	 partial train loss (single batch): 0.060051
# 	 partial train loss (single batch): 0.059727
# 	 partial train loss (single batch): 0.060214
# 	 partial train loss (single batch): 0.060777
# 	 partial train loss (single batch): 0.060221
# 	 partial train loss (single batch): 0.060815
# 	 partial train loss (single batch): 0.060507
# 	 partial train loss (single batch): 0.060347
# 	 partial train loss (single batch): 0.060575
# 	 partial train loss (single batch): 0.060823
# 	 partial train loss (single batch): 0.059539
# 	 partial train loss (single batch): 0.060518
# 	 partial train loss (single batch): 0.059493
# 	 partial train loss (single batch): 0.060007
# 	 partial train loss (single batch): 0.059314
# 	 partial train loss (single batch): 0.059769
# 	 partial train loss (single batch): 0.059517
# 	 partial train loss (single batch): 0.061044
# 	 partial train loss (single batch): 0.060107
# 	 partial train loss (single batch): 0.059613
# 	 partial train loss (single batch): 0.060398
# 	 partial train loss (single batch): 0.059592
# 	 partial train loss (single batch): 0.059001
# 	 partial train loss (single batch): 0.059501
# 	 partial train loss (single batch): 0.060118
# 	 partial train loss (single batch): 0.059519
# 	 partial train loss (single batch): 0.058900
# 	 partial train loss (single batch): 0.058956
# 	 partial train loss (single batch): 0.059381
# 	 partial train loss (single batch): 0.059273
# 	 partial train loss (single batch): 0.059475
# 	 partial train loss (single batch): 0.058734
# 	 partial train loss (single batch): 0.059237
# 	 partial train loss (single batch): 0.058625
# 	 partial train loss (single batch): 0.059688
# 	 partial train loss (single batch): 0.059496
# 	 partial train loss (single batch): 0.058857
# 	 partial train loss (single batch): 0.060010
# 	 partial train loss (single batch): 0.059571
# 	 partial train loss (single batch): 0.058910
# 	 partial train loss (single batch): 0.059697
#
#  EPOCH 2/30 	 train loss 0.063 	 val loss 0.055
# EPOCH 3/30
# 	 partial train loss (single batch): 0.059195
# 	 partial train loss (single batch): 0.058925
# 	 partial train loss (single batch): 0.059214
# 	 partial train loss (single batch): 0.058685
# 	 partial train loss (single batch): 0.058989
# 	 partial train loss (single batch): 0.058693
# 	 partial train loss (single batch): 0.059258
# 	 partial train loss (single batch): 0.058769
# 	 partial train loss (single batch): 0.058520
# 	 partial train loss (single batch): 0.058277
# 	 partial train loss (single batch): 0.059169
# 	 partial train loss (single batch): 0.058896
# 	 partial train loss (single batch): 0.059461
# 	 partial train loss (single batch): 0.058655
# 	 partial train loss (single batch): 0.058444
# 	 partial train loss (single batch): 0.059019
# 	 partial train loss (single batch): 0.058139
# 	 partial train loss (single batch): 0.058168
# 	 partial train loss (single batch): 0.057968
# 	 partial train loss (single batch): 0.058178
# 	 partial train loss (single batch): 0.058904
# 	 partial train loss (single batch): 0.057539
# 	 partial train loss (single batch): 0.058614
# 	 partial train loss (single batch): 0.058439
# 	 partial train loss (single batch): 0.058192
# 	 partial train loss (single batch): 0.059197
# 	 partial train loss (single batch): 0.059268
# 	 partial train loss (single batch): 0.058087
# 	 partial train loss (single batch): 0.058050
# 	 partial train loss (single batch): 0.058532
# 	 partial train loss (single batch): 0.058470
# 	 partial train loss (single batch): 0.057898
# 	 partial train loss (single batch): 0.058078
# 	 partial train loss (single batch): 0.057597
# 	 partial train loss (single batch): 0.057912
# 	 partial train loss (single batch): 0.058381
# 	 partial train loss (single batch): 0.058535
# 	 partial train loss (single batch): 0.059156
# 	 partial train loss (single batch): 0.058325
# 	 partial train loss (single batch): 0.057920
# 	 partial train loss (single batch): 0.057275
# 	 partial train loss (single batch): 0.058123
# 	 partial train loss (single batch): 0.057933
# 	 partial train loss (single batch): 0.056993
# 	 partial train loss (single batch): 0.057310
# 	 partial train loss (single batch): 0.057226
# 	 partial train loss (single batch): 0.057149
# 	 partial train loss (single batch): 0.058103
# 	 partial train loss (single batch): 0.056960
# 	 partial train loss (single batch): 0.059475
# 	 partial train loss (single batch): 0.057466
# 	 partial train loss (single batch): 0.057380
# 	 partial train loss (single batch): 0.057394
# 	 partial train loss (single batch): 0.057160
# 	 partial train loss (single batch): 0.057679
# 	 partial train loss (single batch): 0.057375
# 	 partial train loss (single batch): 0.057424
# 	 partial train loss (single batch): 0.058337
# 	 partial train loss (single batch): 0.056916
# 	 partial train loss (single batch): 0.057788
# 	 partial train loss (single batch): 0.057293
# 	 partial train loss (single batch): 0.056703
# 	 partial train loss (single batch): 0.056575
# 	 partial train loss (single batch): 0.056747
# 	 partial train loss (single batch): 0.057997
# 	 partial train loss (single batch): 0.057204
# 	 partial train loss (single batch): 0.057851
# 	 partial train loss (single batch): 0.056790
# 	 partial train loss (single batch): 0.058805
# 	 partial train loss (single batch): 0.057578
# 	 partial train loss (single batch): 0.056089
# 	 partial train loss (single batch): 0.057248
# 	 partial train loss (single batch): 0.056943
# 	 partial train loss (single batch): 0.056233
# 	 partial train loss (single batch): 0.056276
# 	 partial train loss (single batch): 0.056487
# 	 partial train loss (single batch): 0.057493
# 	 partial train loss (single batch): 0.057064
# 	 partial train loss (single batch): 0.057447
# 	 partial train loss (single batch): 0.057513
# 	 partial train loss (single batch): 0.055746
# 	 partial train loss (single batch): 0.056710
# 	 partial train loss (single batch): 0.057243
# 	 partial train loss (single batch): 0.057103
# 	 partial train loss (single batch): 0.056706
# 	 partial train loss (single batch): 0.058109
# 	 partial train loss (single batch): 0.056644
# 	 partial train loss (single batch): 0.055620
# 	 partial train loss (single batch): 0.056923
# 	 partial train loss (single batch): 0.056269
# 	 partial train loss (single batch): 0.057472
# 	 partial train loss (single batch): 0.056438
# 	 partial train loss (single batch): 0.056595
# 	 partial train loss (single batch): 0.056222
# 	 partial train loss (single batch): 0.056459
# 	 partial train loss (single batch): 0.056494
# 	 partial train loss (single batch): 0.057038
# 	 partial train loss (single batch): 0.056899
# 	 partial train loss (single batch): 0.056080
# 	 partial train loss (single batch): 0.055753
# 	 partial train loss (single batch): 0.056629
# 	 partial train loss (single batch): 0.056669
# 	 partial train loss (single batch): 0.057413
# 	 partial train loss (single batch): 0.056600
# 	 partial train loss (single batch): 0.056332
# 	 partial train loss (single batch): 0.057042
# 	 partial train loss (single batch): 0.056218
# 	 partial train loss (single batch): 0.056281
# 	 partial train loss (single batch): 0.056367
# 	 partial train loss (single batch): 0.055560
# 	 partial train loss (single batch): 0.056736
# 	 partial train loss (single batch): 0.055782
# 	 partial train loss (single batch): 0.055707
# 	 partial train loss (single batch): 0.055211
# 	 partial train loss (single batch): 0.055622
# 	 partial train loss (single batch): 0.055386
# 	 partial train loss (single batch): 0.056529
# 	 partial train loss (single batch): 0.056286
# 	 partial train loss (single batch): 0.055937
# 	 partial train loss (single batch): 0.055905
# 	 partial train loss (single batch): 0.055944
# 	 partial train loss (single batch): 0.055924
# 	 partial train loss (single batch): 0.057206
# 	 partial train loss (single batch): 0.055756
# 	 partial train loss (single batch): 0.055266
# 	 partial train loss (single batch): 0.056139
# 	 partial train loss (single batch): 0.055968
# 	 partial train loss (single batch): 0.055955
# 	 partial train loss (single batch): 0.055727
# 	 partial train loss (single batch): 0.055536
# 	 partial train loss (single batch): 0.055865
# 	 partial train loss (single batch): 0.056195
# 	 partial train loss (single batch): 0.055169
# 	 partial train loss (single batch): 0.056022
# 	 partial train loss (single batch): 0.056273
# 	 partial train loss (single batch): 0.056328
# 	 partial train loss (single batch): 0.055208
# 	 partial train loss (single batch): 0.055758
# 	 partial train loss (single batch): 0.054552
# 	 partial train loss (single batch): 0.054931
# 	 partial train loss (single batch): 0.054800
# 	 partial train loss (single batch): 0.055323
# 	 partial train loss (single batch): 0.055553
# 	 partial train loss (single batch): 0.055310
# 	 partial train loss (single batch): 0.056525
# 	 partial train loss (single batch): 0.055354
# 	 partial train loss (single batch): 0.054412
# 	 partial train loss (single batch): 0.055410
# 	 partial train loss (single batch): 0.054891
# 	 partial train loss (single batch): 0.055044
# 	 partial train loss (single batch): 0.055790
# 	 partial train loss (single batch): 0.055197
# 	 partial train loss (single batch): 0.056040
# 	 partial train loss (single batch): 0.055337
# 	 partial train loss (single batch): 0.055662
# 	 partial train loss (single batch): 0.055599
# 	 partial train loss (single batch): 0.055915
# 	 partial train loss (single batch): 0.054406
# 	 partial train loss (single batch): 0.055290
# 	 partial train loss (single batch): 0.055161
# 	 partial train loss (single batch): 0.055234
# 	 partial train loss (single batch): 0.053960
# 	 partial train loss (single batch): 0.054961
# 	 partial train loss (single batch): 0.055165
# 	 partial train loss (single batch): 0.055892
# 	 partial train loss (single batch): 0.055266
# 	 partial train loss (single batch): 0.054762
# 	 partial train loss (single batch): 0.055679
# 	 partial train loss (single batch): 0.055127
# 	 partial train loss (single batch): 0.054255
# 	 partial train loss (single batch): 0.055187
# 	 partial train loss (single batch): 0.055411
# 	 partial train loss (single batch): 0.054702
# 	 partial train loss (single batch): 0.054618
# 	 partial train loss (single batch): 0.055038
# 	 partial train loss (single batch): 0.054865
# 	 partial train loss (single batch): 0.055175
# 	 partial train loss (single batch): 0.055402
# 	 partial train loss (single batch): 0.054327
# 	 partial train loss (single batch): 0.054633
# 	 partial train loss (single batch): 0.054105
# 	 partial train loss (single batch): 0.055763
# 	 partial train loss (single batch): 0.055611
# 	 partial train loss (single batch): 0.054234
# 	 partial train loss (single batch): 0.055521
# 	 partial train loss (single batch): 0.055244
# 	 partial train loss (single batch): 0.054952
# 	 partial train loss (single batch): 0.055435
#
#  EPOCH 3/30 	 train loss 0.057 	 val loss 0.047
# EPOCH 4/30
# 	 partial train loss (single batch): 0.054751
# 	 partial train loss (single batch): 0.055266
# 	 partial train loss (single batch): 0.054759
# 	 partial train loss (single batch): 0.054552
# 	 partial train loss (single batch): 0.055491
# 	 partial train loss (single batch): 0.054770
# 	 partial train loss (single batch): 0.055260
# 	 partial train loss (single batch): 0.054650
# 	 partial train loss (single batch): 0.054885
# 	 partial train loss (single batch): 0.053826
# 	 partial train loss (single batch): 0.054981
# 	 partial train loss (single batch): 0.055415
# 	 partial train loss (single batch): 0.055483
# 	 partial train loss (single batch): 0.055144
# 	 partial train loss (single batch): 0.054208
# 	 partial train loss (single batch): 0.055443
# 	 partial train loss (single batch): 0.053942
# 	 partial train loss (single batch): 0.054521
# 	 partial train loss (single batch): 0.054698
# 	 partial train loss (single batch): 0.054510
# 	 partial train loss (single batch): 0.054627
# 	 partial train loss (single batch): 0.053880
# 	 partial train loss (single batch): 0.054509
# 	 partial train loss (single batch): 0.055033
# 	 partial train loss (single batch): 0.054408
# 	 partial train loss (single batch): 0.055278
# 	 partial train loss (single batch): 0.055195
# 	 partial train loss (single batch): 0.055073
# 	 partial train loss (single batch): 0.054550
# 	 partial train loss (single batch): 0.054550
# 	 partial train loss (single batch): 0.054713
# 	 partial train loss (single batch): 0.054556
# 	 partial train loss (single batch): 0.054070
# 	 partial train loss (single batch): 0.054056
# 	 partial train loss (single batch): 0.054378
# 	 partial train loss (single batch): 0.054957
# 	 partial train loss (single batch): 0.054462
# 	 partial train loss (single batch): 0.055499
# 	 partial train loss (single batch): 0.054765
# 	 partial train loss (single batch): 0.054611
# 	 partial train loss (single batch): 0.053734
# 	 partial train loss (single batch): 0.054411
# 	 partial train loss (single batch): 0.054514
# 	 partial train loss (single batch): 0.053213
# 	 partial train loss (single batch): 0.053995
# 	 partial train loss (single batch): 0.053414
# 	 partial train loss (single batch): 0.054068
# 	 partial train loss (single batch): 0.054837
# 	 partial train loss (single batch): 0.053239
# 	 partial train loss (single batch): 0.056213
# 	 partial train loss (single batch): 0.053839
# 	 partial train loss (single batch): 0.053904
# 	 partial train loss (single batch): 0.054167
# 	 partial train loss (single batch): 0.053810
# 	 partial train loss (single batch): 0.054754
# 	 partial train loss (single batch): 0.054047
# 	 partial train loss (single batch): 0.054520
# 	 partial train loss (single batch): 0.054711
# 	 partial train loss (single batch): 0.053631
# 	 partial train loss (single batch): 0.054626
# 	 partial train loss (single batch): 0.054013
# 	 partial train loss (single batch): 0.053651
# 	 partial train loss (single batch): 0.053679
# 	 partial train loss (single batch): 0.053499
# 	 partial train loss (single batch): 0.055017
# 	 partial train loss (single batch): 0.053885
# 	 partial train loss (single batch): 0.054724
# 	 partial train loss (single batch): 0.053742
# 	 partial train loss (single batch): 0.055873
# 	 partial train loss (single batch): 0.053814
# 	 partial train loss (single batch): 0.053329
# 	 partial train loss (single batch): 0.054105
# 	 partial train loss (single batch): 0.053634
# 	 partial train loss (single batch): 0.053369
# 	 partial train loss (single batch): 0.053224
# 	 partial train loss (single batch): 0.053452
# 	 partial train loss (single batch): 0.054774
# 	 partial train loss (single batch): 0.054051
# 	 partial train loss (single batch): 0.054222
# 	 partial train loss (single batch): 0.054335
# 	 partial train loss (single batch): 0.053405
# 	 partial train loss (single batch): 0.053604
# 	 partial train loss (single batch): 0.054494
# 	 partial train loss (single batch): 0.054121
# 	 partial train loss (single batch): 0.053476
# 	 partial train loss (single batch): 0.055163
# 	 partial train loss (single batch): 0.054364
# 	 partial train loss (single batch): 0.053208
# 	 partial train loss (single batch): 0.054494
# 	 partial train loss (single batch): 0.053827
# 	 partial train loss (single batch): 0.054558
# 	 partial train loss (single batch): 0.054089
# 	 partial train loss (single batch): 0.053834
# 	 partial train loss (single batch): 0.053700
# 	 partial train loss (single batch): 0.053212
# 	 partial train loss (single batch): 0.054008
# 	 partial train loss (single batch): 0.054173
# 	 partial train loss (single batch): 0.054352
# 	 partial train loss (single batch): 0.053400
# 	 partial train loss (single batch): 0.053017
# 	 partial train loss (single batch): 0.054085
# 	 partial train loss (single batch): 0.054341
# 	 partial train loss (single batch): 0.054689
# 	 partial train loss (single batch): 0.053910
# 	 partial train loss (single batch): 0.053340
# 	 partial train loss (single batch): 0.054413
# 	 partial train loss (single batch): 0.053545
# 	 partial train loss (single batch): 0.054408
# 	 partial train loss (single batch): 0.053474
# 	 partial train loss (single batch): 0.053362
# 	 partial train loss (single batch): 0.053964
# 	 partial train loss (single batch): 0.053251
# 	 partial train loss (single batch): 0.053496
# 	 partial train loss (single batch): 0.052470
# 	 partial train loss (single batch): 0.053036
# 	 partial train loss (single batch): 0.052997
# 	 partial train loss (single batch): 0.054286
# 	 partial train loss (single batch): 0.053815
# 	 partial train loss (single batch): 0.053678
# 	 partial train loss (single batch): 0.053415
# 	 partial train loss (single batch): 0.053396
# 	 partial train loss (single batch): 0.053683
# 	 partial train loss (single batch): 0.054753
# 	 partial train loss (single batch): 0.053828
# 	 partial train loss (single batch): 0.052619
# 	 partial train loss (single batch): 0.054025
# 	 partial train loss (single batch): 0.053971
# 	 partial train loss (single batch): 0.053674
# 	 partial train loss (single batch): 0.053336
# 	 partial train loss (single batch): 0.053146
# 	 partial train loss (single batch): 0.053587
# 	 partial train loss (single batch): 0.054180
# 	 partial train loss (single batch): 0.052809
# 	 partial train loss (single batch): 0.053586
# 	 partial train loss (single batch): 0.054267
# 	 partial train loss (single batch): 0.054010
# 	 partial train loss (single batch): 0.052717
# 	 partial train loss (single batch): 0.053574
# 	 partial train loss (single batch): 0.052680
# 	 partial train loss (single batch): 0.053224
# 	 partial train loss (single batch): 0.053098
# 	 partial train loss (single batch): 0.052806
# 	 partial train loss (single batch): 0.053256
# 	 partial train loss (single batch): 0.053277
# 	 partial train loss (single batch): 0.053994
# 	 partial train loss (single batch): 0.053624
# 	 partial train loss (single batch): 0.052774
# 	 partial train loss (single batch): 0.052950
# 	 partial train loss (single batch): 0.052562
# 	 partial train loss (single batch): 0.053276
# 	 partial train loss (single batch): 0.053642
# 	 partial train loss (single batch): 0.053335
# 	 partial train loss (single batch): 0.054277
# 	 partial train loss (single batch): 0.053340
# 	 partial train loss (single batch): 0.053527
# 	 partial train loss (single batch): 0.053947
# 	 partial train loss (single batch): 0.054052
# 	 partial train loss (single batch): 0.052845
# 	 partial train loss (single batch): 0.054040
# 	 partial train loss (single batch): 0.053402
# 	 partial train loss (single batch): 0.053850
# 	 partial train loss (single batch): 0.052467
# 	 partial train loss (single batch): 0.052966
# 	 partial train loss (single batch): 0.053443
# 	 partial train loss (single batch): 0.053621
# 	 partial train loss (single batch): 0.053876
# 	 partial train loss (single batch): 0.053183
# 	 partial train loss (single batch): 0.053784
# 	 partial train loss (single batch): 0.053112
# 	 partial train loss (single batch): 0.052458
# 	 partial train loss (single batch): 0.053620
# 	 partial train loss (single batch): 0.053744
# 	 partial train loss (single batch): 0.052839
# 	 partial train loss (single batch): 0.053012
# 	 partial train loss (single batch): 0.053355
# 	 partial train loss (single batch): 0.053431
# 	 partial train loss (single batch): 0.053614
# 	 partial train loss (single batch): 0.053569
# 	 partial train loss (single batch): 0.052352
# 	 partial train loss (single batch): 0.053391
# 	 partial train loss (single batch): 0.052831
# 	 partial train loss (single batch): 0.054016
# 	 partial train loss (single batch): 0.053559
# 	 partial train loss (single batch): 0.052679
# 	 partial train loss (single batch): 0.053788
# 	 partial train loss (single batch): 0.053192
# 	 partial train loss (single batch): 0.053153
# 	 partial train loss (single batch): 0.053555
#
#  EPOCH 4/30 	 train loss 0.054 	 val loss 0.044
# EPOCH 5/30
# 	 partial train loss (single batch): 0.052826
# 	 partial train loss (single batch): 0.053546
# 	 partial train loss (single batch): 0.052725
# 	 partial train loss (single batch): 0.052831
# 	 partial train loss (single batch): 0.053548
# 	 partial train loss (single batch): 0.052990
# 	 partial train loss (single batch): 0.053514
# 	 partial train loss (single batch): 0.053244
# 	 partial train loss (single batch): 0.053043
# 	 partial train loss (single batch): 0.051928
# 	 partial train loss (single batch): 0.053700
# 	 partial train loss (single batch): 0.053723
# 	 partial train loss (single batch): 0.053621
# 	 partial train loss (single batch): 0.053481
# 	 partial train loss (single batch): 0.052871
# 	 partial train loss (single batch): 0.053941
# 	 partial train loss (single batch): 0.052272
# 	 partial train loss (single batch): 0.053181
# 	 partial train loss (single batch): 0.052799
# 	 partial train loss (single batch): 0.053088
# 	 partial train loss (single batch): 0.052971
# 	 partial train loss (single batch): 0.052482
# 	 partial train loss (single batch): 0.053430
# 	 partial train loss (single batch): 0.053337
# 	 partial train loss (single batch): 0.053380
# 	 partial train loss (single batch): 0.053780
# 	 partial train loss (single batch): 0.054162
# 	 partial train loss (single batch): 0.053393
# 	 partial train loss (single batch): 0.053211
# 	 partial train loss (single batch): 0.053090
# 	 partial train loss (single batch): 0.053493
# 	 partial train loss (single batch): 0.053558
# 	 partial train loss (single batch): 0.052632
# 	 partial train loss (single batch): 0.052759
# 	 partial train loss (single batch): 0.052943
# 	 partial train loss (single batch): 0.053711
# 	 partial train loss (single batch): 0.053031
# 	 partial train loss (single batch): 0.053840
# 	 partial train loss (single batch): 0.053585
# 	 partial train loss (single batch): 0.052995
# 	 partial train loss (single batch): 0.052411
# 	 partial train loss (single batch): 0.053018
# 	 partial train loss (single batch): 0.053048
# 	 partial train loss (single batch): 0.051970
# 	 partial train loss (single batch): 0.052813
# 	 partial train loss (single batch): 0.052380
# 	 partial train loss (single batch): 0.052608
# 	 partial train loss (single batch): 0.053357
# 	 partial train loss (single batch): 0.052336
# 	 partial train loss (single batch): 0.054785
# 	 partial train loss (single batch): 0.052235
# 	 partial train loss (single batch): 0.052516
# 	 partial train loss (single batch): 0.052880
# 	 partial train loss (single batch): 0.053067
# 	 partial train loss (single batch): 0.053864
# 	 partial train loss (single batch): 0.052663
# 	 partial train loss (single batch): 0.053434
# 	 partial train loss (single batch): 0.053887
# 	 partial train loss (single batch): 0.052145
# 	 partial train loss (single batch): 0.053463
# 	 partial train loss (single batch): 0.053062
# 	 partial train loss (single batch): 0.052438
# 	 partial train loss (single batch): 0.052374
# 	 partial train loss (single batch): 0.051915
# 	 partial train loss (single batch): 0.053484
# 	 partial train loss (single batch): 0.052275
# 	 partial train loss (single batch): 0.053581
# 	 partial train loss (single batch): 0.052602
# 	 partial train loss (single batch): 0.054464
# 	 partial train loss (single batch): 0.053031
# 	 partial train loss (single batch): 0.052145
# 	 partial train loss (single batch): 0.053140
# 	 partial train loss (single batch): 0.052926
# 	 partial train loss (single batch): 0.052409
# 	 partial train loss (single batch): 0.052447
# 	 partial train loss (single batch): 0.052355
# 	 partial train loss (single batch): 0.053406
# 	 partial train loss (single batch): 0.052908
# 	 partial train loss (single batch): 0.053169
# 	 partial train loss (single batch): 0.053212
# 	 partial train loss (single batch): 0.052026
# 	 partial train loss (single batch): 0.052362
# 	 partial train loss (single batch): 0.053614
# 	 partial train loss (single batch): 0.053327
# 	 partial train loss (single batch): 0.052513
# 	 partial train loss (single batch): 0.054182
# 	 partial train loss (single batch): 0.053380
# 	 partial train loss (single batch): 0.052170
# 	 partial train loss (single batch): 0.053639
# 	 partial train loss (single batch): 0.052423
# 	 partial train loss (single batch): 0.053806
# 	 partial train loss (single batch): 0.052854
# 	 partial train loss (single batch): 0.052687
# 	 partial train loss (single batch): 0.053064
# 	 partial train loss (single batch): 0.052065
# 	 partial train loss (single batch): 0.052569
# 	 partial train loss (single batch): 0.053351
# 	 partial train loss (single batch): 0.053587
# 	 partial train loss (single batch): 0.052504
# 	 partial train loss (single batch): 0.051777
# 	 partial train loss (single batch): 0.053115
# 	 partial train loss (single batch): 0.053043
# 	 partial train loss (single batch): 0.053850
# 	 partial train loss (single batch): 0.053012
# 	 partial train loss (single batch): 0.052809
# 	 partial train loss (single batch): 0.052921
# 	 partial train loss (single batch): 0.052595
# 	 partial train loss (single batch): 0.053563
# 	 partial train loss (single batch): 0.052401
# 	 partial train loss (single batch): 0.052010
# 	 partial train loss (single batch): 0.053379
# 	 partial train loss (single batch): 0.052595
# 	 partial train loss (single batch): 0.052692
# 	 partial train loss (single batch): 0.052172
# 	 partial train loss (single batch): 0.052357
# 	 partial train loss (single batch): 0.052052
# 	 partial train loss (single batch): 0.052833
# 	 partial train loss (single batch): 0.052776
# 	 partial train loss (single batch): 0.052462
# 	 partial train loss (single batch): 0.052564
# 	 partial train loss (single batch): 0.052729
# 	 partial train loss (single batch): 0.052948
# 	 partial train loss (single batch): 0.053291
# 	 partial train loss (single batch): 0.052811
# 	 partial train loss (single batch): 0.052173
# 	 partial train loss (single batch): 0.053200
# 	 partial train loss (single batch): 0.053049
# 	 partial train loss (single batch): 0.052904
# 	 partial train loss (single batch): 0.052690
# 	 partial train loss (single batch): 0.052547
# 	 partial train loss (single batch): 0.052373
# 	 partial train loss (single batch): 0.053152
# 	 partial train loss (single batch): 0.052270
# 	 partial train loss (single batch): 0.052934
# 	 partial train loss (single batch): 0.053358
# 	 partial train loss (single batch): 0.053253
# 	 partial train loss (single batch): 0.052218
# 	 partial train loss (single batch): 0.052349
# 	 partial train loss (single batch): 0.051700
# 	 partial train loss (single batch): 0.052380
# 	 partial train loss (single batch): 0.052122
# 	 partial train loss (single batch): 0.052088
# 	 partial train loss (single batch): 0.052077
# 	 partial train loss (single batch): 0.052424
# 	 partial train loss (single batch): 0.053289
# 	 partial train loss (single batch): 0.052935
# 	 partial train loss (single batch): 0.051739
# 	 partial train loss (single batch): 0.052241
# 	 partial train loss (single batch): 0.051781
# 	 partial train loss (single batch): 0.052121
# 	 partial train loss (single batch): 0.052995
# 	 partial train loss (single batch): 0.052261
# 	 partial train loss (single batch): 0.053595
# 	 partial train loss (single batch): 0.052768
# 	 partial train loss (single batch): 0.052738
# 	 partial train loss (single batch): 0.052913
# 	 partial train loss (single batch): 0.053156
# 	 partial train loss (single batch): 0.051904
# 	 partial train loss (single batch): 0.053079
# 	 partial train loss (single batch): 0.052495
# 	 partial train loss (single batch): 0.052579
# 	 partial train loss (single batch): 0.051567
# 	 partial train loss (single batch): 0.052211
# 	 partial train loss (single batch): 0.052815
# 	 partial train loss (single batch): 0.052539
# 	 partial train loss (single batch): 0.053153
# 	 partial train loss (single batch): 0.052067
# 	 partial train loss (single batch): 0.052949
# 	 partial train loss (single batch): 0.052621
# 	 partial train loss (single batch): 0.051921
# 	 partial train loss (single batch): 0.052567
# 	 partial train loss (single batch): 0.053127
# 	 partial train loss (single batch): 0.051697
# 	 partial train loss (single batch): 0.052128
# 	 partial train loss (single batch): 0.052515
# 	 partial train loss (single batch): 0.052461
# 	 partial train loss (single batch): 0.052756
# 	 partial train loss (single batch): 0.052585
# 	 partial train loss (single batch): 0.051619
# 	 partial train loss (single batch): 0.052217
# 	 partial train loss (single batch): 0.051999
# 	 partial train loss (single batch): 0.053155
# 	 partial train loss (single batch): 0.053065
# 	 partial train loss (single batch): 0.051999
# 	 partial train loss (single batch): 0.052895
# 	 partial train loss (single batch): 0.052360
# 	 partial train loss (single batch): 0.053018
# 	 partial train loss (single batch): 0.053008
#
#  EPOCH 5/30 	 train loss 0.053 	 val loss 0.043
# EPOCH 6/30
# 	 partial train loss (single batch): 0.052562
# 	 partial train loss (single batch): 0.052806
# 	 partial train loss (single batch): 0.052251
# 	 partial train loss (single batch): 0.052235
# 	 partial train loss (single batch): 0.052676
# 	 partial train loss (single batch): 0.052250
# 	 partial train loss (single batch): 0.053139
# 	 partial train loss (single batch): 0.052370
# 	 partial train loss (single batch): 0.052462
# 	 partial train loss (single batch): 0.051086
# 	 partial train loss (single batch): 0.052558
# 	 partial train loss (single batch): 0.053096
# 	 partial train loss (single batch): 0.053245
# 	 partial train loss (single batch): 0.053248
# 	 partial train loss (single batch): 0.052213
# 	 partial train loss (single batch): 0.053113
# 	 partial train loss (single batch): 0.051186
# 	 partial train loss (single batch): 0.052152
# 	 partial train loss (single batch): 0.052135
# 	 partial train loss (single batch): 0.052005
# 	 partial train loss (single batch): 0.052592
# 	 partial train loss (single batch): 0.051887
# 	 partial train loss (single batch): 0.052360
# 	 partial train loss (single batch): 0.052819
# 	 partial train loss (single batch): 0.052558
# 	 partial train loss (single batch): 0.052995
# 	 partial train loss (single batch): 0.053307
# 	 partial train loss (single batch): 0.053057
# 	 partial train loss (single batch): 0.052476
# 	 partial train loss (single batch): 0.052437
# 	 partial train loss (single batch): 0.053198
# 	 partial train loss (single batch): 0.052860
# 	 partial train loss (single batch): 0.052085
# 	 partial train loss (single batch): 0.052267
# 	 partial train loss (single batch): 0.052287
# 	 partial train loss (single batch): 0.053114
# 	 partial train loss (single batch): 0.052398
# 	 partial train loss (single batch): 0.053110
# 	 partial train loss (single batch): 0.052954
# 	 partial train loss (single batch): 0.052324
# 	 partial train loss (single batch): 0.051588
# 	 partial train loss (single batch): 0.052613
# 	 partial train loss (single batch): 0.052700
# 	 partial train loss (single batch): 0.051596
# 	 partial train loss (single batch): 0.052021
# 	 partial train loss (single batch): 0.051271
# 	 partial train loss (single batch): 0.051946
# 	 partial train loss (single batch): 0.052778
# 	 partial train loss (single batch): 0.051396
# 	 partial train loss (single batch): 0.054025
# 	 partial train loss (single batch): 0.051585
# 	 partial train loss (single batch): 0.052022
# 	 partial train loss (single batch): 0.052319
# 	 partial train loss (single batch): 0.051917
# 	 partial train loss (single batch): 0.053360
# 	 partial train loss (single batch): 0.052035
# 	 partial train loss (single batch): 0.052934
# 	 partial train loss (single batch): 0.053279
# 	 partial train loss (single batch): 0.051961
# 	 partial train loss (single batch): 0.052966
# 	 partial train loss (single batch): 0.052467
# 	 partial train loss (single batch): 0.052122
# 	 partial train loss (single batch): 0.052044
# 	 partial train loss (single batch): 0.051398
# 	 partial train loss (single batch): 0.053662
# 	 partial train loss (single batch): 0.051977
# 	 partial train loss (single batch): 0.053161
# 	 partial train loss (single batch): 0.051947
# 	 partial train loss (single batch): 0.054172
# 	 partial train loss (single batch): 0.051967
# 	 partial train loss (single batch): 0.051703
# 	 partial train loss (single batch): 0.052244
# 	 partial train loss (single batch): 0.052204
# 	 partial train loss (single batch): 0.051605
# 	 partial train loss (single batch): 0.051261
# 	 partial train loss (single batch): 0.052462
# 	 partial train loss (single batch): 0.053007
# 	 partial train loss (single batch): 0.051970
# 	 partial train loss (single batch): 0.052788
# 	 partial train loss (single batch): 0.052698
# 	 partial train loss (single batch): 0.051122
# 	 partial train loss (single batch): 0.051914
# 	 partial train loss (single batch): 0.052870
# 	 partial train loss (single batch): 0.052551
# 	 partial train loss (single batch): 0.052019
# 	 partial train loss (single batch): 0.053708
# 	 partial train loss (single batch): 0.052270
# 	 partial train loss (single batch): 0.051806
# 	 partial train loss (single batch): 0.053052
# 	 partial train loss (single batch): 0.052156
# 	 partial train loss (single batch): 0.052959
# 	 partial train loss (single batch): 0.052299
# 	 partial train loss (single batch): 0.052267
# 	 partial train loss (single batch): 0.052271
# 	 partial train loss (single batch): 0.051804
# 	 partial train loss (single batch): 0.051997
# ...
# 	 partial train loss (single batch): 0.049940
# 	 partial train loss (single batch): 0.049347
# 	 partial train loss (single batch): 0.049190
# 	 partial train loss (single batch): 0.049515
# 	 partial train loss (single batch): 0.049645
# 	 partial train loss (single batch): 0.049207
# 	 partial train loss (single batch): 0.050307
# 	 partial train loss (single batch): 0.050132
# 	 partial train loss (single batch): 0.049902
# 	 partial train loss (single batch): 0.048632
# 	 partial train loss (single batch): 0.049203
# 	 partial train loss (single batch): 0.049783
# 	 partial train loss (single batch): 0.048548
# 	 partial train loss (single batch): 0.049313
# 	 partial train loss (single batch): 0.048995
# 	 partial train loss (single batch): 0.049145
# 	 partial train loss (single batch): 0.049603
# 	 partial train loss (single batch): 0.048560
# 	 partial train loss (single batch): 0.050950
# 	 partial train loss (single batch): 0.048739
# 	 partial train loss (single batch): 0.049351
# 	 partial train loss (single batch): 0.048825
# 	 partial train loss (single batch): 0.049405
# 	 partial train loss (single batch): 0.050439
# 	 partial train loss (single batch): 0.048494
# 	 partial train loss (single batch): 0.050007
# 	 partial train loss (single batch): 0.050379
# 	 partial train loss (single batch): 0.048999
# 	 partial train loss (single batch): 0.049870
# 	 partial train loss (single batch): 0.049552
# 	 partial train loss (single batch): 0.049063
# 	 partial train loss (single batch): 0.049199
# 	 partial train loss (single batch): 0.048850
# 	 partial train loss (single batch): 0.050481
# 	 partial train loss (single batch): 0.049032
# 	 partial train loss (single batch): 0.050534
# 	 partial train loss (single batch): 0.049406
# 	 partial train loss (single batch): 0.051419
# 	 partial train loss (single batch): 0.048980
# 	 partial train loss (single batch): 0.048590
# 	 partial train loss (single batch): 0.049913
# 	 partial train loss (single batch): 0.050123
# 	 partial train loss (single batch): 0.049257
# 	 partial train loss (single batch): 0.048960
# 	 partial train loss (single batch): 0.049253
# 	 partial train loss (single batch): 0.050005
# 	 partial train loss (single batch): 0.049234
# 	 partial train loss (single batch): 0.049528
# 	 partial train loss (single batch): 0.049919
# 	 partial train loss (single batch): 0.048841
# 	 partial train loss (single batch): 0.048986
# 	 partial train loss (single batch): 0.049781
# 	 partial train loss (single batch): 0.049530
# 	 partial train loss (single batch): 0.048988
# 	 partial train loss (single batch): 0.050914
# 	 partial train loss (single batch): 0.049633
# 	 partial train loss (single batch): 0.049209
# 	 partial train loss (single batch): 0.049901
# 	 partial train loss (single batch): 0.048952
# 	 partial train loss (single batch): 0.050166
# 	 partial train loss (single batch): 0.049761
# 	 partial train loss (single batch): 0.049607
# 	 partial train loss (single batch): 0.049805
# 	 partial train loss (single batch): 0.049276
# 	 partial train loss (single batch): 0.049412
# 	 partial train loss (single batch): 0.050130
# 	 partial train loss (single batch): 0.049850
# 	 partial train loss (single batch): 0.049476
# 	 partial train loss (single batch): 0.049141
# 	 partial train loss (single batch): 0.049757
# 	 partial train loss (single batch): 0.049863
# 	 partial train loss (single batch): 0.050312
# 	 partial train loss (single batch): 0.049983
# 	 partial train loss (single batch): 0.049602
# 	 partial train loss (single batch): 0.049949
# 	 partial train loss (single batch): 0.049639
# 	 partial train loss (single batch): 0.050059
# 	 partial train loss (single batch): 0.049453
# 	 partial train loss (single batch): 0.048963
# 	 partial train loss (single batch): 0.049978
# 	 partial train loss (single batch): 0.049229
# 	 partial train loss (single batch): 0.048955
# 	 partial train loss (single batch): 0.049191
# 	 partial train loss (single batch): 0.048772
# 	 partial train loss (single batch): 0.048981
# 	 partial train loss (single batch): 0.049851
# 	 partial train loss (single batch): 0.049229
# 	 partial train loss (single batch): 0.049970
# 	 partial train loss (single batch): 0.049690
# 	 partial train loss (single batch): 0.049609
# 	 partial train loss (single batch): 0.049322
# 	 partial train loss (single batch): 0.050977
# 	 partial train loss (single batch): 0.049599
# 	 partial train loss (single batch): 0.048812
# 	 partial train loss (single batch): 0.050439
# 	 partial train loss (single batch): 0.050253
# 	 partial train loss (single batch): 0.049271
# 	 partial train loss (single batch): 0.049863
# 	 partial train loss (single batch): 0.049444
# 	 partial train loss (single batch): 0.049214
# 	 partial train loss (single batch): 0.049898
# 	 partial train loss (single batch): 0.049163
# 	 partial train loss (single batch): 0.049357
# 	 partial train loss (single batch): 0.050264
# 	 partial train loss (single batch): 0.049929
# 	 partial train loss (single batch): 0.049085
# 	 partial train loss (single batch): 0.049419
# 	 partial train loss (single batch): 0.048807
# 	 partial train loss (single batch): 0.049550
# 	 partial train loss (single batch): 0.049487
# 	 partial train loss (single batch): 0.048721
# 	 partial train loss (single batch): 0.048884
# 	 partial train loss (single batch): 0.049125
# 	 partial train loss (single batch): 0.050450
# 	 partial train loss (single batch): 0.049111
# 	 partial train loss (single batch): 0.048952
# 	 partial train loss (single batch): 0.049330
# 	 partial train loss (single batch): 0.048162
# 	 partial train loss (single batch): 0.048674
# 	 partial train loss (single batch): 0.049541
# 	 partial train loss (single batch): 0.049653
# 	 partial train loss (single batch): 0.050257
# 	 partial train loss (single batch): 0.049494
# 	 partial train loss (single batch): 0.049844
# 	 partial train loss (single batch): 0.049796
# 	 partial train loss (single batch): 0.049993
# 	 partial train loss (single batch): 0.048938
# 	 partial train loss (single batch): 0.049927
# 	 partial train loss (single batch): 0.049849
# 	 partial train loss (single batch): 0.049587
# 	 partial train loss (single batch): 0.048687
# 	 partial train loss (single batch): 0.048974
# 	 partial train loss (single batch): 0.049697
# 	 partial train loss (single batch): 0.049718
# 	 partial train loss (single batch): 0.050003
# 	 partial train loss (single batch): 0.049311
# 	 partial train loss (single batch): 0.050453
# 	 partial train loss (single batch): 0.048938
# 	 partial train loss (single batch): 0.049006
# 	 partial train loss (single batch): 0.049488
# 	 partial train loss (single batch): 0.050304
# 	 partial train loss (single batch): 0.048472
# 	 partial train loss (single batch): 0.048937
# 	 partial train loss (single batch): 0.049728
# 	 partial train loss (single batch): 0.049522
# 	 partial train loss (single batch): 0.049740
# 	 partial train loss (single batch): 0.049693
# 	 partial train loss (single batch): 0.048902
# 	 partial train loss (single batch): 0.049388
# 	 partial train loss (single batch): 0.048575
# 	 partial train loss (single batch): 0.049814
# 	 partial train loss (single batch): 0.049868
# 	 partial train loss (single batch): 0.048835
# 	 partial train loss (single batch): 0.049247
# 	 partial train loss (single batch): 0.049410
# 	 partial train loss (single batch): 0.049169
# 	 partial train loss (single batch): 0.049735
#
#  EPOCH 29/30 	 train loss 0.050 	 val loss 0.038
# EPOCH 30/30
# 	 partial train loss (single batch): 0.049386
# 	 partial train loss (single batch): 0.049873
# 	 partial train loss (single batch): 0.049420
# 	 partial train loss (single batch): 0.049634
# 	 partial train loss (single batch): 0.050032
# 	 partial train loss (single batch): 0.049102
# 	 partial train loss (single batch): 0.049926
# 	 partial train loss (single batch): 0.049589
# 	 partial train loss (single batch): 0.049492
# 	 partial train loss (single batch): 0.048605
# 	 partial train loss (single batch): 0.049755
# 	 partial train loss (single batch): 0.050568
# 	 partial train loss (single batch): 0.050153
# 	 partial train loss (single batch): 0.049966
# 	 partial train loss (single batch): 0.048544
# 	 partial train loss (single batch): 0.049595
# 	 partial train loss (single batch): 0.048471
# 	 partial train loss (single batch): 0.049534
# 	 partial train loss (single batch): 0.048932
# 	 partial train loss (single batch): 0.048721
# 	 partial train loss (single batch): 0.049485
# 	 partial train loss (single batch): 0.048716
# 	 partial train loss (single batch): 0.049971
# 	 partial train loss (single batch): 0.049610
# 	 partial train loss (single batch): 0.049746
# 	 partial train loss (single batch): 0.049530
# 	 partial train loss (single batch): 0.050247
# 	 partial train loss (single batch): 0.050525
# 	 partial train loss (single batch): 0.050114
# 	 partial train loss (single batch): 0.049403
# 	 partial train loss (single batch): 0.050166
# 	 partial train loss (single batch): 0.049353
# 	 partial train loss (single batch): 0.049385
# 	 partial train loss (single batch): 0.049228
# 	 partial train loss (single batch): 0.049630
# 	 partial train loss (single batch): 0.049539
# 	 partial train loss (single batch): 0.049256
# 	 partial train loss (single batch): 0.050466
# 	 partial train loss (single batch): 0.049951
# 	 partial train loss (single batch): 0.049937
# 	 partial train loss (single batch): 0.048559
# 	 partial train loss (single batch): 0.049242
# 	 partial train loss (single batch): 0.049628
# 	 partial train loss (single batch): 0.048329
# 	 partial train loss (single batch): 0.049317
# 	 partial train loss (single batch): 0.048855
# 	 partial train loss (single batch): 0.048711
# 	 partial train loss (single batch): 0.050123
# 	 partial train loss (single batch): 0.048933
# 	 partial train loss (single batch): 0.051264
# 	 partial train loss (single batch): 0.049065
# 	 partial train loss (single batch): 0.049743
# 	 partial train loss (single batch): 0.049201
# 	 partial train loss (single batch): 0.049203
# 	 partial train loss (single batch): 0.049949
# 	 partial train loss (single batch): 0.048774
# 	 partial train loss (single batch): 0.050248
# 	 partial train loss (single batch): 0.050221
# 	 partial train loss (single batch): 0.049012
# 	 partial train loss (single batch): 0.049729
# 	 partial train loss (single batch): 0.049591
# 	 partial train loss (single batch): 0.048986
# 	 partial train loss (single batch): 0.049436
# 	 partial train loss (single batch): 0.048736
# 	 partial train loss (single batch): 0.050171
# 	 partial train loss (single batch): 0.049239
# 	 partial train loss (single batch): 0.050599
# 	 partial train loss (single batch): 0.049418
# 	 partial train loss (single batch): 0.051357
# 	 partial train loss (single batch): 0.048995
# 	 partial train loss (single batch): 0.048678
# 	 partial train loss (single batch): 0.050111
# 	 partial train loss (single batch): 0.049638
# 	 partial train loss (single batch): 0.049450
# 	 partial train loss (single batch): 0.049452
# 	 partial train loss (single batch): 0.049327
# 	 partial train loss (single batch): 0.049955
# 	 partial train loss (single batch): 0.049436
# 	 partial train loss (single batch): 0.049710
# 	 partial train loss (single batch): 0.049679
# 	 partial train loss (single batch): 0.048379
# 	 partial train loss (single batch): 0.049196
# 	 partial train loss (single batch): 0.049911
# 	 partial train loss (single batch): 0.049454
# 	 partial train loss (single batch): 0.048630
# 	 partial train loss (single batch): 0.050798
# 	 partial train loss (single batch): 0.049889
# 	 partial train loss (single batch): 0.049138
# 	 partial train loss (single batch): 0.049736
# 	 partial train loss (single batch): 0.049313
# 	 partial train loss (single batch): 0.049965
# 	 partial train loss (single batch): 0.049685
# 	 partial train loss (single batch): 0.049190
# 	 partial train loss (single batch): 0.049809
# 	 partial train loss (single batch): 0.049070
# 	 partial train loss (single batch): 0.049124
# 	 partial train loss (single batch): 0.050231
# 	 partial train loss (single batch): 0.049907
# 	 partial train loss (single batch): 0.049464
# 	 partial train loss (single batch): 0.048926
# 	 partial train loss (single batch): 0.049793
# 	 partial train loss (single batch): 0.049550
# 	 partial train loss (single batch): 0.050278
# 	 partial train loss (single batch): 0.049821
# 	 partial train loss (single batch): 0.049934
# 	 partial train loss (single batch): 0.050087
# 	 partial train loss (single batch): 0.049385
# 	 partial train loss (single batch): 0.049838
# 	 partial train loss (single batch): 0.049260
# 	 partial train loss (single batch): 0.048817
# 	 partial train loss (single batch): 0.049615
# 	 partial train loss (single batch): 0.049258
# 	 partial train loss (single batch): 0.049482
# 	 partial train loss (single batch): 0.048810
# 	 partial train loss (single batch): 0.048874
# 	 partial train loss (single batch): 0.049196
# 	 partial train loss (single batch): 0.049853
# 	 partial train loss (single batch): 0.049119
# 	 partial train loss (single batch): 0.049639
# 	 partial train loss (single batch): 0.049658
# 	 partial train loss (single batch): 0.049554
# 	 partial train loss (single batch): 0.049421
# 	 partial train loss (single batch): 0.050722
# 	 partial train loss (single batch): 0.049379
# 	 partial train loss (single batch): 0.048700
# 	 partial train loss (single batch): 0.050106
# 	 partial train loss (single batch): 0.049917
# 	 partial train loss (single batch): 0.049436
# 	 partial train loss (single batch): 0.049878
# 	 partial train loss (single batch): 0.049282
# 	 partial train loss (single batch): 0.049345
# 	 partial train loss (single batch): 0.050078
# 	 partial train loss (single batch): 0.048759
# 	 partial train loss (single batch): 0.049904
# 	 partial train loss (single batch): 0.049647
# 	 partial train loss (single batch): 0.050086
# 	 partial train loss (single batch): 0.049119
# 	 partial train loss (single batch): 0.049482
# 	 partial train loss (single batch): 0.048544
# 	 partial train loss (single batch): 0.049671
# 	 partial train loss (single batch): 0.048988
# 	 partial train loss (single batch): 0.048775
# 	 partial train loss (single batch): 0.048883
# 	 partial train loss (single batch): 0.049046
# 	 partial train loss (single batch): 0.050288
# 	 partial train loss (single batch): 0.049101
# 	 partial train loss (single batch): 0.048861
# 	 partial train loss (single batch): 0.049569
# 	 partial train loss (single batch): 0.048573
# 	 partial train loss (single batch): 0.048930
# 	 partial train loss (single batch): 0.049668
# 	 partial train loss (single batch): 0.049938
# 	 partial train loss (single batch): 0.050181
# 	 partial train loss (single batch): 0.049177
# 	 partial train loss (single batch): 0.049614
# 	 partial train loss (single batch): 0.049621
# 	 partial train loss (single batch): 0.050369
# 	 partial train loss (single batch): 0.048898
# 	 partial train loss (single batch): 0.049741
# 	 partial train loss (single batch): 0.050053
# 	 partial train loss (single batch): 0.049708
# 	 partial train loss (single batch): 0.048476
# 	 partial train loss (single batch): 0.048923
# 	 partial train loss (single batch): 0.049495
# 	 partial train loss (single batch): 0.049977
# 	 partial train loss (single batch): 0.050198
# 	 partial train loss (single batch): 0.048910
# 	 partial train loss (single batch): 0.050427
# 	 partial train loss (single batch): 0.049031
# 	 partial train loss (single batch): 0.048843
# 	 partial train loss (single batch): 0.049202
# 	 partial train loss (single batch): 0.050133
# 	 partial train loss (single batch): 0.048884
# 	 partial train loss (single batch): 0.049273
# 	 partial train loss (single batch): 0.049404
# 	 partial train loss (single batch): 0.049770
# 	 partial train loss (single batch): 0.049495
# 	 partial train loss (single batch): 0.049269
# 	 partial train loss (single batch): 0.049102
# 	 partial train loss (single batch): 0.049174
# 	 partial train loss (single batch): 0.048851
# 	 partial train loss (single batch): 0.049946
# 	 partial train loss (single batch): 0.049852
# 	 partial train loss (single batch): 0.048305
# 	 partial train loss (single batch): 0.049281
# 	 partial train loss (single batch): 0.049761
# 	 partial train loss (single batch): 0.049679
# 	 partial train loss (single batch): 0.049575
#
#  EPOCH 30/30 	 train loss 0.049 	 val loss 0.038

# %%
# Plot training performance
test_epoch_den(encoder,decoder,device,test_loader,loss_fn).item()# Plot losses
plt.figure(figsize=(10,8))
plt.semilogy(history_da['train_loss'], label='Train')
plt.semilogy(history_da['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 4 Visualize latent space

# %%
def plot_results(encoder, decoder, data, rx=(-5, 5), ry=(-5, 5), model_name='VAE'):

    # Encode all data samples
    encoded_samples = []
    for sample in tqdm(data):
        
        # Separate image data from its label 
        img = sample[0].unsqueeze(0).to(device)
        label = sample[1]
        
        # Encode image
        encoder.eval()
        with torch.no_grad():
            encoded_img  = encoder(img)
        
        # Append to list
        encoded_img = encoded_img.flatten().cpu().numpy()
        encoded_sample = {f"Enc. Variable {i}": enc for i, enc in enumerate(encoded_img)}
        encoded_sample['label'] = label
        encoded_samples.append(encoded_sample)
        
        # Find latend dimension from decoded image
        latent_dim = len(encoded_img)
        
    encoded_samples = pd.DataFrame(encoded_samples)

    # Create a TSNE model and plot it
    tsne = TSNE(n_components=2)
    tsne_results = tsne.fit_transform(encoded_samples.drop(['label'],axis=1))
    
    plt.figure(figsize=(17, 9))
    plt.scatter(tsne_results[:,0], tsne_results[:,1], c=encoded_samples.label, cmap='tab10', s=3)
    plt.xlabel('tsne-2d-one')
    plt.ylabel('tsne-2d-two')
    plt.title(f'Digit separation produced by {model_name}')
    plt.colorbar()
    plt.show()
    
    # Prepare a n x n 2D matrix of digits
    n = 30
    digit_size = 28
    figure = np.zeros((digit_size * n, digit_size * n))
    
    # Create a linearly spaced coordinates of 2D digit classes in latent space
    grid_x = np.linspace(*rx, n)
    grid_y = np.linspace(*ry, n)[::-1]

    # Populate the matrix with images decoded from latent space
    for i, yi in enumerate(grid_y):
        for j, xj in enumerate(grid_x):
            # coords = [xj, yi, 0, 0] # Use latent_dim
            coords = list(np.zeros(latent_dim))
            coords[0] = xj
            coords[1] = yi
            z = torch.Tensor([coords]).to(device)
            x_hat = decoder(z)
            digit = x_hat.reshape(digit_size, digit_size).to('cpu').detach().numpy()
            figure[i * digit_size: (i + 1) * digit_size,
                   j * digit_size: (j + 1) * digit_size] = digit

    # Plot the matrix of "fake" sample digits
    plt.figure(figsize=(8, 8))
    start_range = digit_size // 2
    end_range = (n - 1) * digit_size + start_range + 1
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.title(f'Sample of digits recovered from {model_name} latent space')
    plt.imshow(figure, cmap='Greys')
    # plt.savefig(filename)
    plt.show()

plot_results(encoder, decoder, test_dataset, rx=(-1, 1), ry=(-1, 1), model_name="Noisy Autoencoder")
# Out:
# 100%|███████████████████████████████████| 10000/10000 [00:05<00:00, 1972.74it/s]

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.23.1</td></tr><tr><td><code>qiskit-aer</code></td><td>0.11.2</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.20.0</td></tr><tr><td><code>qiskit</code></td><td>0.41.0</td></tr><tr><td><code>qiskit-nature</code></td><td>0.5.2</td></tr><tr><td><code>qiskit-finance</code></td><td>0.3.4</td></tr><tr><td><code>qiskit-optimization</code></td><td>0.5.0</td></tr><tr><td><code>qiskit-machine-learning</code></td><td>0.5.0</td></tr><tr><th>System information</th></tr><tr><td>Python version</td><td>3.8.15</td></tr><tr><td>Python compiler</td><td>GCC 11.3.0</td></tr><tr><td>Python build</td><td>default, Jan 26 2023 10:47:49</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>6</td></tr><tr><td>Memory (Gb)</td><td>62.48039245605469</td></tr><tr><td colspan='2'>Sun Jul 16 00:30:55 2023 AEST</td></tr></table>
